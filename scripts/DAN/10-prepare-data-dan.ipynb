# %% [markdown]
# # 10. Prepare dataset for DAN training

# %% [markdown]
# This notebook lists the steps to create a dataset from a SQLITE database (exported from Arkindex) into the correct DAN training dataset format. It is assumed that the training set is already filled with images.
#
# *NB: It is preferable to run these commands in the terminal rather than in the notebook.*

# %% [markdown]
# Documentation:
# - [Arkindex API](https://doc.arkindex.org/overview/api/)
# - [Arkindex Python](https://pypi.org/project/arkindex-client/)
# - [Arkindex CLI](https://cli.arkindex.org/)

# %% [markdown]
# ## 1. Extract dataset entities
# Extract the list of entity types.</br>
# In : SQLite database</br>
# Out : entries.yaml

# %% [raw]
# teklia-dan dataset entities /home/STual/DAN-cadastre/data/DAN/epita-ign-registre-napoleonien-20241217-140446.sqlite \
#     --output-file /home/STual/DAN-cadastre/dataset2/entities.yml

# %% [markdown]
# ### 1.1 Dataset tokens
# Generate a YAML file containing entity types and their special tokens used to train DAN.</br>
# In : entries.yaml</br>
# Out : tokens.yaml

# %% [raw]
# teklia-dan dataset tokens /home/STual/DAN-cadastre/dataset2/entities.yml \
#     --output-file /home/STual/DAN-cadastre/dataset2/tokens.yml

# %% [markdown]
# ### 1.2 Dataset extraction
# Extract annotations from the SQLITE database to JSON.</br>
# In : SQLite database</br>
# Out : JSON text annotation dataset
#
# *Subsets names have to be "train", "val", "test" (which differs from the name they have in Arkindex => "training", "validation", "test". They have to be renamed in the SQLite export.*

# %% [raw]
# teklia-dan dataset extract /home/STual/DAN-cadastre/data/DAN/epita-ign-registre-napoleonien-20241217-140446.sqlite \
#     --dataset-id 032ae384-77dd-4ec8-868a-4348dd74897f \
#     --element-type page \
#     --output /home/STual/DAN-cadastre/dataset2/page_dataset \
#     --tokens /home/STual/DAN-cadastre/dataset2/tokens.yml

# %% [markdown]
# ### 1.3 Download IIIF images

# %% [raw]
# teklia-dan dataset download \
#     --output /home/STual/DAN-cadastre/dataset2/page_dataset

# %% [markdown]
# ## 2. Compute statistics for HTR-NER

# %% [markdown]
# These statistics are helpful to set the training parameters in the configuration json.

# %%
teklia-dan dataset analyze \
    --labels /home/STual/DAN-cadastre/dataset2/page_dataset/labels.json \
    --tokens /home/STual/DAN-cadastre/dataset2/tokens.yml \
    --output-file /home/STual/DAN-cadastre/dataset2/statistics.md
# Out:
# 2025-03-12 13:56:03,021 INFO/dan.datasets.analyze.statistics: Images statistics
#
# | Metric |  Width  |  Height |
# |:-------|:-------:|:-------:|
# | Count  |    27   |    27   |
# | Min    |   2272  |   3264  |
# | Max    |   3939  |   5810  |
# | Mean   | 2948.56 | 4372.04 |
# | Median |  2973.0 |  4542.0 |
#
# 2025-03-12 13:56:03,023 INFO/dan.datasets.analyze.statistics: Labels statistics
#
# | Metric | Chars  | Words  | Lines |
# |:-------|:------:|:------:|:-----:|
# | Min    |  119   |   22   |   3   |
# | Max    |  1514  |  251   |   31  |
# | Mean   | 719.33 | 121.22 | 17.33 |
# | Median | 685.0  | 118.0  |  16.0 |
# | Total  | 19422  |  3273  |  468  |
#
# 2025-03-12 13:56:03,025 INFO/dan.datasets.analyze.statistics: Characters statistics
#
# | Character | Occurrence |
# |:----------|-----------:|
# |           |       2805 |
# | e         |       1361 |
# | i         |        969 |
# | r         |        846 |
# | a         |        796 |
# | n         |        669 |
# | o         |        629 |
# | s         |        516 |
# | Ⓔ         |        468 |
# | Ⓕ         |        467 |
# | Ⓒ         |        466 |
# |           |        441 |
# |           |            |
# | d         |        427 |
# | l         |        427 |
# | u         |        427 |
# | t         |        409 |
# | 1         |        408 |
# | 2         |        344 |
# | Ⓖ         |        339 |
# | 4         |        316 |
# | Ⓓ         |        310 |
# | m         |        297 |
# | 3         |        293 |
# | §         |        271 |
# | →         |        245 |
# | 7         |        242 |
# | p         |        217 |
# | 6         |        213 |
# | g         |        193 |
# | c         |        180 |
# | v         |        162 |
# | ↑         |        161 |
# | ↓         |        160 |
# | h         |        155 |
# | 5         |        153 |
# | 9         |        149 |
# | 8         |        147 |
# | J         |        133 |
# | 0         |        133 |
# | Ⓐ         |        132 |
# | V         |        125 |
# | b         |        117 |
# | T         |        116 |
# | M         |        111 |
# | Ⓑ         |        109 |
# | C         |        108 |
# | à         |        105 |
# | L         |         90 |
# | P         |         89 |
# | B         |         83 |
# | é         |         77 |
# | G         |         59 |
# | y         |         59 |
# | ×         |         58 |
# | ±         |         58 |
# | Ø         |         56 |
# | D         |         53 |
# | f         |         43 |
# | S         |         39 |
# | R         |         35 |
# | x         |         34 |
# | .         |         30 |
# | j         |         29 |
# | ⁇         |         29 |
# | q         |         23 |
# | I         |         20 |
# | A         |         17 |
# | ç         |         16 |
# | â         |         15 |
# | F         |         14 |
# | è         |         14 |
# | ê         |         12 |
# | N         |         12 |
# | ,         |         12 |
# | (         |         11 |
# | )         |         11 |
# | E         |         10 |
# | ☼         |          8 |
# | -         |          6 |
# | O         |          6 |
# | z         |          6 |
# | ❌        |          5 |
# | H         |          5 |
# | '         |          3 |
# | î         |          2 |
# | W         |          1 |
# | ø         |          1 |
# | k         |          1 |
# | &         |          1 |
# | ô         |          1 |
# | Q         |          1 |
#
# 2025-03-12 13:56:03,027 INFO/dan.datasets.analyze.statistics: NER tokens statistics
#
# | Metric | ancien_numero_parcelle | ancienne_nature | identite | lieu-dit | nature | numero_parcelle | numero_proprietaire |
# |:-------|:----------------------:|:---------------:|:--------:|:--------:|:------:|:---------------:|:-------------------:|
# | Min    |           0            |        0        |    3     |    0     |   3    |        3        |          0          |
# | Max    |           22           |        16       |    31    |    31    |   31   |        31       |          21         |
# | Mean   |          4.89          |       4.04      |  17.26   |  11.48   | 17.33  |       17.3      |        12.56        |
# | Median |          0.0           |       0.0       |   16.0   |   14.0   |  16.0  |       16.0      |         15.0        |
# | Total  |          132           |       109       |   466    |   310    |  468   |       467       |         339         |
#
# 2025-03-12 13:56:03,030 INFO/dan.datasets.analyze.statistics: Images statistics
#
# | Metric |  Width  |  Height |
# |:-------|:-------:|:-------:|
# | Count  |    95   |    95   |
# | Min    |   2272  |   3200  |
# | Max    |   3775  |   5661  |
# | Mean   | 3141.21 | 4632.27 |
# | Median |  3243.0 |  4580.0 |
#
# 2025-03-12 13:56:03,035 INFO/dan.datasets.analyze.statistics: Labels statistics
#
# | Metric | Chars  | Words  | Lines |
# |:-------|:------:|:------:|:-----:|
# | Min    |  109   |   22   |   2   |
# | Max    |  1489  |  237   |   29  |
# | Mean   | 786.05 | 132.14 | 19.11 |
# | Median | 772.0  | 130.0  |  16.0 |
# | Total  | 74675  | 12553  |  1815 |
#
# 2025-03-12 13:56:03,037 INFO/dan.datasets.analyze.statistics: Characters statistics
#
# | Character | Occurrence |
# |:----------|-----------:|
# |           |      10738 |
# | e         |       5260 |
# | i         |       3595 |
# | r         |       3322 |
# | a         |       2687 |
# | n         |       2521 |
# | o         |       2172 |
# | s         |       1937 |
# | §         |       1931 |
# | t         |       1835 |
# | Ⓒ         |       1814 |
# | Ⓕ         |       1814 |
# | 1         |       1812 |
# | Ⓔ         |       1811 |
# | u         |       1742 |
# |           |       1720 |
# |           |            |
# | l         |       1687 |
# | Ⓓ         |       1511 |
# | d         |       1329 |
# | 2         |       1308 |
# | Ⓖ         |        997 |
# | T         |        957 |
# | 3         |        897 |
# | 4         |        890 |
# | ↑         |        864 |
# | ↓         |        852 |
# | 6         |        843 |
# | 5         |        819 |
# | 7         |        816 |
# | 0         |        803 |
# | m         |        757 |
# | →         |        706 |
# | c         |        661 |
# | 9         |        651 |
# | 8         |        643 |
# | p         |        634 |
# | g         |        613 |
# | h         |        609 |
# | v         |        451 |
# | Ⓐ         |        444 |
# | Ⓑ         |        432 |
# | J         |        425 |
# | b         |        415 |
# | é         |        378 |
# | L         |        353 |
# | V         |        351 |
# | f         |        347 |
# | B         |        343 |
# | C         |        336 |
# | P         |        316 |
# | M         |        291 |
# | ×         |        271 |
# | ±         |        264 |
# | y         |        254 |
# | j         |        199 |
# | D         |        195 |
# | .         |        144 |
# | x         |        142 |
# | R         |        139 |
# | G         |        135 |
# | S         |        130 |
# | q         |        123 |
# | à         |        103 |
# | ,         |         96 |
# | A         |         94 |
# | F         |         93 |
# | Ø         |         87 |
# | è         |         82 |
# | ç         |         75 |
# | z         |         75 |
# | E         |         59 |
# | N         |         58 |
# | °         |         53 |
# | '         |         47 |
# | ❌        |         47 |
# | H         |         37 |
# | â         |         31 |
# | )         |         23 |
# | I         |         23 |
# | (         |         22 |
# | ☼         |         18 |
# | ë         |         18 |
# | K         |         14 |
# | ô         |         13 |
# | Q         |          9 |
# | ê         |          9 |
# | -         |          8 |
# | O         |          8 |
# | "         |          7 |
# | \         |          6 |
# | ï         |          5 |
# | k         |          4 |
# | =         |          3 |
# | w         |          2 |
# | ­          |          2 |
# | W         |          2 |
# | &         |          2 |
# | ø         |          2 |
# | +         |          1 |
# | î         |          1 |
#
# 2025-03-12 13:56:03,040 INFO/dan.datasets.analyze.statistics: NER tokens statistics
#
# | Metric | ancien_numero_parcelle | ancienne_nature | identite | lieu-dit | nature | numero_parcelle | numero_proprietaire |
# |:-------|:----------------------:|:---------------:|:--------:|:--------:|:------:|:---------------:|:-------------------:|
# | Min    |           0            |        0        |    2     |    0     |   2    |        2        |          0          |
# | Max    |           16           |        16       |    29    |    29    |   29   |        29       |          25         |
# | Mean   |          4.67          |       4.55      |  19.09   |  15.91   | 19.06  |      19.09      |        10.49        |
# | Median |          0.0           |       0.0       |   16.0   |   14.0   |  16.0  |       16.0      |         14.0        |
# | Total  |          444           |       432       |   1814   |   1511   |  1811  |       1814      |         997         |
#
# 2025-03-12 13:56:03,041 INFO/dan.datasets.analyze.statistics: Images statistics
#
# | Metric |  Width  |  Height |
# |:-------|:-------:|:-------:|
# | Count  |    19   |    19   |
# | Min    |   2271  |   3200  |
# | Max    |   3554  |   5305  |
# | Mean   | 3187.63 | 4485.32 |
# | Median |  3264.0 |  4544.0 |
#
# 2025-03-12 13:56:03,043 INFO/dan.datasets.analyze.statistics: Labels statistics
#
# | Metric | Chars  | Words  | Lines |
# |:-------|:------:|:------:|:-----:|
# | Min    |   50   |   9    |   1   |
# | Max    |  1224  |  216   |   34  |
# | Mean   | 756.11 | 130.11 | 18.47 |
# | Median | 848.0  | 134.0  |  15.0 |
# | Total  | 14366  |  2472  |  351  |
#
# 2025-03-12 13:56:03,045 INFO/dan.datasets.analyze.statistics: Characters statistics
#
# | Character | Occurrence |
# |:----------|-----------:|
# |           |       2121 |
# | e         |       1076 |
# | r         |        702 |
# | i         |        665 |
# | n         |        503 |
# | a         |        464 |
# | o         |        373 |
# | t         |        371 |
# | Ⓒ         |        351 |
# | Ⓕ         |        350 |
# | Ⓔ         |        350 |
# | s         |        344 |
# |           |        332 |
# |           |            |
# | Ⓓ         |        318 |
# | §         |        290 |
# | d         |        284 |
# | 2         |        278 |
# | u         |        261 |
# | 4         |        252 |
# | Ⓖ         |        250 |
# | 1         |        247 |
# | l         |        222 |
# | 6         |        212 |
# | 7         |        206 |
# | ↑         |        201 |
# | ↓         |        199 |
# | 3         |        196 |
# | 5         |        191 |
# | p         |        160 |
# | c         |        130 |
# | T         |        127 |
# | 0         |        126 |
# | 9         |        125 |
# | J         |        119 |
# | 8         |        118 |
# | →         |        110 |
# | m         |        110 |
# | h         |        100 |
# | P         |         94 |
# | Ø         |         89 |
# | Ⓐ         |         85 |
# | V         |         85 |
# | Ⓑ         |         84 |
# | v         |         79 |
# | B         |         76 |
# | L         |         73 |
# | g         |         72 |
# | M         |         69 |
# | b         |         60 |
# | f         |         59 |
# | C         |         59 |
# | é         |         56 |
# | D         |         45 |
# | .         |         44 |
# | à         |         43 |
# | y         |         37 |
# | G         |         33 |
# | I         |         26 |
# | q         |         23 |
# | ,         |         23 |
# | -         |         21 |
# | ☼         |         17 |
# | "         |         16 |
# | è         |         15 |
# | ç         |         14 |
# | E         |         13 |
# | x         |         13 |
# | R         |         13 |
# | S         |         12 |
# | j         |         12 |
# | F         |         10 |
# | z         |          9 |
# | '         |          9 |
# | H         |          8 |
# | A         |          7 |
# | (         |          6 |
# | )         |          6 |
# | N         |          4 |
# | ×         |          3 |
# | ±         |          3 |
# | â         |          2 |
# | î         |          1 |
# | ⁇         |          1 |
# | W         |          1 |
# | k         |          1 |
# | K         |          1 |
#
# 2025-03-12 13:56:03,047 INFO/dan.datasets.analyze.statistics: NER tokens statistics
#
# | Metric | ancien_numero_parcelle | ancienne_nature | identite | lieu-dit | nature | numero_parcelle | numero_proprietaire |
# |:-------|:----------------------:|:---------------:|:--------:|:--------:|:------:|:---------------:|:-------------------:|
# | Min    |           0            |        0        |    1     |    0     |   1    |        1        |          0          |
# | Max    |           14           |        14       |    34    |    34    |   34   |        34       |          34         |
# | Mean   |          4.47          |       4.42      |  18.47   |  16.74   | 18.42  |      18.42      |        13.16        |
# | Median |          0.0           |       0.0       |   15.0   |   14.0   |  15.0  |       15.0      |         14.0        |
# | Total  |           85           |        84       |   351    |   318    |  350   |       350       |         250         |
