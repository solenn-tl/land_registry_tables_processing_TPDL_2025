# %% [markdown]
# # 30 - Evaluation DAN

# %% [markdown]
# The aim of this notebook is to provide a detailed evaluation of the performance of the fine-tuned model.
#
# Some requirements:
# * It's better to do the evaluation on a single GPU to avoid parallelization drawbacks.
# * Don't use the configuration file (JSON) used for training. Prefer an adapted version dedicated to the evaluation, with the following parameters:
#     * *batch size* : 1 (if > 1, the metrics are those of the whole batch and not of each independent image)
#     * *load_epoch* : best (we want to evaluate the best model, not the last)
# * As we have used the character **§** in the training dataset, be sure to replace § with £ (or any other character not present in the dataset) in *nerval/parse.py* (this was normally done to train the model).

# %%
import glob
import pandas as pd
import sys
import os
# Access to the utils directory
current_dir = os.getcwd()
utils_dir = os.path.join(current_dir, '..', 'utils')
sys.path.append(utils_dir)

# %%
ROOT = "/home/STual/DAN-cadastre"

# %% [markdown]
# ## 1. Global evaluation
# The global evaluation is performed with the teklia-dan dedicated command.

# %% [raw]
# teklia-dan evaluate --config /home/STual/DAN-cadastre/scripts/DAN/configs/config2025-prodeval.json --output-json /home/STual/DAN-cadastre/scripts/DAN/metrics/training-12-03-2025-2000epochs.json

# %% [markdown]
# #### DAN evaluation
#
# | Split | CER (HTR-NER) | CER (HTR) | WER (HTR-NER) | WER (HTR) | WER (HTR no punct) |  NER  |
# |:-----:|:-------------:|:---------:|:-------------:|:---------:|:------------------:|:-----:|
# | train |      2.05     |    2.13   |      2.93     |    2.89   |        2.89        |  1.38 |
# |  val  |     39.68     |   40.17   |     64.44     |   63.78   |       63.78        | 32.61 |
# |  test |     33.67     |    35.3   |     54.78     |   54.36   |       54.36        | 16.19 |
#
# #### Nerval evaluation
#
# Distance threshold for the match between gold and predicted entity during Nerval evaluation is set to 0 : impose perfect matches.
#
# ##### train
#
# | tag                    | predicted | matched | Precision | Recall |    F1 | Support |
# |:-----------------------|----------:|--------:|----------:|-------:|------:|--------:|
# | ancien_numero_parcelle |       441 |     429 |     97.28 |  96.62 | 96.95 |     444 |
# | ancienne_nature        |       427 |     419 |     98.13 |  96.99 | 97.56 |     432 |
# | identite               |      1817 |    1796 |     98.84 |  99.01 | 98.93 |    1814 |
# | lieu-dit               |      1515 |    1498 |     98.88 |  99.14 | 99.01 |    1511 |
# | nature                 |      1813 |    1799 |     99.23 |  99.34 | 99.28 |    1811 |
# | numero_parcelle        |      1817 |    1786 |     98.29 |  98.46 | 98.38 |    1814 |
# | numero_proprietaire    |       996 |     977 |     98.09 |  97.99 | 98.04 |     997 |
# | ALL                    |      8826 |    8704 |     98.62 |  98.65 | 98.63 |    8823 |
#
# ##### val
#
# | tag                    | predicted | matched | Precision | Recall |    F1 | Support |
# |:-----------------------|----------:|--------:|----------:|-------:|------:|--------:|
# | ancien_numero_parcelle |        78 |      40 |     51.28 |  47.06 | 49.08 |      85 |
# | ancienne_nature        |        80 |      35 |     43.75 |  41.67 | 42.68 |      84 |
# | identite               |       347 |     206 |     59.37 |  58.69 | 59.03 |     351 |
# | lieu-dit               |       289 |     155 |     53.63 |  48.74 | 51.07 |     318 |
# | nature                 |       364 |     189 |     51.92 |   54.0 | 52.94 |     350 |
# | numero_parcelle        |       363 |     204 |      56.2 |  58.29 | 57.22 |     350 |
# | numero_proprietaire    |       232 |     118 |     50.86 |   47.2 | 48.96 |     250 |
# | ALL                    |      1753 |     947 |     54.02 |  52.96 | 53.49 |    1788 |
#
# ##### test
#
# | tag                    | predicted | matched | Precision | Recall |    F1 | Support |
# |:-----------------------|----------:|--------:|----------:|-------:|------:|--------:|
# | ancien_numero_parcelle |        95 |      49 |     51.58 |  37.12 | 43.17 |     132 |
# | ancienne_nature        |        93 |      41 |     44.09 |  37.61 | 40.59 |     109 |
# | identite               |       485 |     301 |     62.06 |  64.59 |  63.3 |     466 |
# | lieu-dit               |       328 |     178 |     54.27 |  57.42 |  55.8 |     310 |
# | nature                 |       490 |     335 |     68.37 |  71.58 | 69.94 |     468 |
# | numero_parcelle        |       487 |     341 |     70.02 |  73.02 | 71.49 |     467 |
# | numero_proprietaire    |       384 |     251 |     65.36 |  74.04 | 69.43 |     339 |
# | ALL                    |      2362 |    1496 |     63.34 |   65.3 |  64.3 |    2291 |

# %% [markdown]
# ## 2. Additionnal evaluation
#
# * Ranking by page
# * CER/WER by entity types
# * CER/WER on full transcription without the layout tokens
# * Refaire l'évaluation après avoir fait la détection d'hallucinations ?
# * Stats par pages (avec communes etc)

# %% [markdown]
# ### 2.1 Ranking by pages

# %%
import json
import pandas as pd

PAGES_EVAL = ROOT + "/scripts/DAN/metrics/training-12-03-2025-2000epochs.json"

with open(PAGES_EVAL, 'r') as file:
    data = json.load(file)

train = data["train"]
val = data["val"]
test = data["test"]

# %% [markdown]
# #### Test set ranking

# %%
test_df = pd.DataFrame(test,columns=["element","gt","pred","?","score"])
test_df.sort_values(by=['score'])
# Out:
#                                      element  \
# 6   9f05c03f-8178-4c88-8260-7934b59a1722.jpg
# 24  ebb6c2e5-3e89-4fcf-9120-41fadf75cc02.jpg
# 17  0864252b-1fc6-4fa4-b71f-0d7813d1f8e0.jpg
# 8   11f414bb-4f41-4a46-812e-07fd5d29cb80.jpg
# 23  dedb479b-00cd-486e-94c7-e2eb4b04bd0b.jpg
# 21  d4ecb57d-1863-4a0e-9d4e-4c6675c39404.jpg
# 13  29761c35-dd25-477c-beb6-60fe0cac7917.jpg
# 25  f11fae21-c23b-46d5-9324-26c52cc2f6e8.jpg
# 15  43534ab4-6452-4c18-8ffe-d135cfcfc99f.jpg
# 26  f25edeaf-de9b-4adc-a558-7405d57ee89c.jpg
# 3   5c9e20bc-339e-41cb-b495-86b5be9342e3.jpg
# 14  43526c6f-f49b-48f8-a442-d5543033ea7e.jpg
# 19  48366964-b8c5-449d-b92a-21307d5ece13.jpg
# 4   5c9f66e3-8df0-40ec-8991-5a8331391ca5.jpg
# 16  96442d8e-602c-4211-9c4f-e2bba123479e.jpg
# 18  33526574-34c4-465b-92b7-e7290dab78ce.jpg
# 10  322f3ab8-cf41-448b-9c4c-392409383358.jpg
# 12  1741effa-4421-417b-8f76-95108fe49c10.jpg
# 0   0d98a470-fd41-4a59-a6de-696c8fc51b97.jpg
# 2   4fbce0df-983e-4202-8d1e-a628fd95c1b1.jpg
# 11  758c8f14-76b3-4ad3-a40c-857e6e848876.jpg
# 9   148e89fa-ba57-4821-8121-79834766f13f.jpg
# 7   9f7402d1-0c1a-4f50-93b8-f4f5bbb1c662.jpg
# 1   4a669607-caf4-43da-965b-885a5c0f0c2e.jpg
# 20  a5400273-8704-444a-bcb8-74b3a21a1675.jpg
# 5   6a323399-6932-4af1-b54c-f02e610d7b97.jpg
# 22  dda7ced2-28cc-4ed3-8b10-afc82df60634.jpg
#
#                                                    gt  \
# 6   ⒹLes Garennes Ⓖ47 ⒸBourgeot N↑as↓ Denis Ⓕ373 Ⓔ...
# 24  Ⓖ70 ⒸNolo Louis Ⓕ402 ⒺTerre\nⒼ74 ⒸPetit P↑re↓ ...
# 17  Ⓖ67 ⒸMomet Ⓕ16 ⒺTerre\nⒼ83 ⒸSamson Jean Ⓕ17 Ⓔi...
# 8   Ⓖ42 ⒸGevaudan Ⓕ134 ⒺTerre\nⒼ23 Ⓒdame De Chavag...
# 23  Ⓖ58 ⒸLe Gouvernement Ⓕ461 Ⓔéquediere\nⒼ58 ⒸLe ...
# 21  ⒹRue de→ Ⓖ35 ⒸDestouches louis Ⓕ153 ⒺMaison→et...
# 13  Ⓖ62 ⒸMarmontel Veuve Ⓕ24 ⒺTerre\nⒼ22 ⒸChasselo...
# 25  ⒹLe Village ⒸPithois Jean baptiste charles à P...
# 15  Ⓖ50 ⒸFoulon Veuve Ⓕ256 ⒺJardin\nⒼ124 ⒸPessoux ...
# 26  Ⓓles larris ⒸPatureau hubert marie Ⓕ432 Ⓔjardi...
# 3   ⒹLes previeux ⒸDominique Michel Ⓕ6p ⒺTerre Ⓐ17...
# 14  ⒹCréteil Ⓖ240 ⒸLanglois Mathieu veuve Ⓕ435 ⒺMa...
# 19  ⒹRue de→ Ⓖ22 ⒸChauvai pierre Ⓕ167 ⒺCour→Com↑ne...
# 4   ⒹLa basse→mache prunelle Ⓖ198 ⒸPain - et - Vin...
# 16  Ⓖ91 ⒸThibout Joseph→bourgeois à paris Ⓕ1 ⒺTerr...
# 18  ⒹLes tales Ⓖ93 ⒸDesgranges p↑re↓→maire d'Ormes...
# 10  Ⓓles papillons Ⓖ16 ⒸBerson nicolas J↑h↓ Ⓕ309 Ⓔ...
# 12  ⒹLes mamies Ⓖ196 ⒸLion J↑n↓-Michel Ⓕ71 ⒺVigne ...
# 0   Ⓖ146 ⒸTremelet lainé Ⓕ256 ⒺTerre\nⒼ147 ⒸBerthi...
# 2   ⒹDu Village ⒸMotheau h↑ers↓ Germain→et Consors...
# 11  ⒹDu Village ⒸHuguet Louis→Vig↑on↓ à id Ⓕ81 ⒺCo...
# 9   Ⓖ70 ⒸNolo Louis Ⓕ1 ⒺTerre\nⒼ37 ⒸDiache Philipp...
# 7   ⒹChemin de Mesly Ⓖ258 ⒸLe couteux, Cl↑de↓ Simo...
# 1   ⒹChamptier→ Ⓖ34 ⒸDelanoue les→heritiers à Vers...
# 20  ⒹLa→ Ⓖ62 ⒸHediard Blaise la V↑e↓→vigneron à Mo...
# 5   ⒹLes Epinettes Ⓖ54 ⒸBronzac pierre Ⓕ337 ⒺT pl ...
# 22  ⒹPrès de Presle ⒸSociété des saune d usines Ⓕ4...
#
#                                                  pred ?   score
# 6   ⒹLes Garennes Ⓖ47 ⒸBourgeot n↑as↓ denis Ⓕ373 Ⓔ...    0.1967
# 24  Ⓖ70 ⒸMolo Louis Ⓕ402 ⒺTerre\nⒼ74 ⒸPetit P↑re↓ ...    0.2347
# 17  Ⓖ67 ⒸMomet Ⓕ16 ⒺTerre\nⒼ83 ⒸSamson Jean Ⓕ17 Ⓔi...    0.2500
# 8   Ⓖ42 ⒸGievaudan→Ⓕ134 ⒺTerre\nⒼ23 ⒸCainé De Chav...    0.2673
# 23  Ⓖ58 ⒸLe gouvernement Ⓕ461 ⒺCigne\nⒼ58 ⒸLe même...    0.3077
# 21  ⒹRue de→ Cour Ⓖ35 ⒸDestouches louis Ⓕ153 Ⓔmais...    0.3305
# 13  Ⓖ62 ⒸMarmontet Veuve Ⓕ24 ⒺTerre\nⒼ22 ⒸChapelou...    0.3895
# 25  ⒹLe Village ⒸPithois Jean baptiste charles à P...    0.4223
# 15  Ⓖ124 ⒸPe Moux Père Ⓕ257 Ⓔid\nⒼ57 ⒸGiot Veuve Ⓕ...    0.4353
# 26  ⒹLes Larris ⒸPatureau hubert marie Ⓕ432 ⒺJardi...    0.4383
# 3   ⒹLes previeux ⒸDominique Michel Ⓕ67 ⒺTerre\nⒹ§...    0.4810
# 14  ⒹCretel Ⓖ240 ⒸLanglois Mathieu veuve Ⓕ435 ⒺMai...    0.4833
# 19  ⒹRue de→Commen Ⓖ47 ⒸChauvai pierre Ⓕ167 ⒺCerre...    0.5191
# 4   ⒹLes Casse→mache prenvelle Ⓕ226 ⒺTerre\nⒹ§ Ⓖ31...    0.5192
# 16  Ⓖ91 ⒸChilout Joseph Ⓕ91 ⒺTerre\nⒼ91 ⒸCourgeou ...    0.5238
# 18  ⒹLes tates Ⓖ93 ⒸDesgrange, p↑re↓ se la→marie Ⓕ...    0.5339
# 10  Ⓓles papillons Ⓖ16 ⒸBerson nicolas J↑h↓ Ⓕ309 Ⓔ...    0.5373
# 12  ⒹLes mamies Ⓖ196 ⒸLiou J↑h↓ michel Ⓕ71 ⒺVignet...    0.6111
# 0   Ⓖ146 ⒸTremelet laimé Ⓕ256 ⒺTerre\nⒼ147 ⒸDerthi...    0.6212
# 2   ⒹDu Village Ⓖ165 ⒸMotheau hens↓ermein joseph Ⓕ...    0.6556
# 11  ⒹDu Villaye Ⓖ81 ⒸDuguet Louis C81 ⒺCour→Commun...    0.6739
# 9   Ⓖ70 ⒸNolo Louis Ⓕ1 ⒺTerre\nⒼ37 ⒸDiache Philiph...    0.6897
# 7   ⒹChemin de Merty Ⓖ258 ⒸLecouteur, (l↑re↓ simon...    0.7076
# 1   ⒹRe Champhier Ⓕ34 Ⓔterre\nⒼ145 Ⓒheretiere à Ve...    0.7688
# 20  ⒹLes Ⓖ62 ⒸDedeard Blaise la Vigne Ⓕ292 ⒺVigne\...    0.8308
# 5   ⒹRue→ Ⓖ374 ⒸSelinte aulanne Ⓕ343 Ⓔserre Ⓐ874→8...    0.9846
# 22  ⒹPrès de Presle ⒸSouiété des Laure stusines Ⓕ4...    3.1364

# %% [markdown]
# #### Val set ranking

# %%
val_df = pd.DataFrame(val,columns=["element","gt","pred","?","score"])
val_df.sort_values(by=['score'])
# Out:
#                                      element  \
# 0   3bf5614d-9110-4b17-a136-1f89aafe668c.jpg
# 4   26a1a247-6ff1-453e-a8fe-16658a829ce2.jpg
# 13  a47dc560-9b5a-44e0-b59c-94b7a95c06ba.jpg
# 3   8d10f2cd-870d-44c9-b1c0-2f9963af6d55.jpg
# 14  aee0a32e-378b-4103-aee8-319f918cb85e.jpg
# 8   679b6507-cec7-422f-8605-e1671d95fba3.jpg
# 10  81411b1c-9ab7-48a6-a641-194048d39d80.jpg
# 7   668fb164-96be-4c84-99d9-1927808e9ec6.jpg
# 6   346be28d-98a8-4831-95f8-54d527c7c64c.jpg
# 5   89edf51e-a836-4359-adc8-efd759991e5f.jpg
# 11  90007216-49f8-434f-8dc9-6038d102429c.jpg
# 17  f28fdaec-4e49-46ec-9d59-3604fdc9823c.jpg
# 15  b2ee5d2a-65af-42d1-8212-7ed1d0a8594a.jpg
# 2   7df7d16d-f8d1-42bf-b337-c6706159df92.jpg
# 1   6bad100e-69ee-4247-a662-23f0b147380b.jpg
# 9   39410aa4-2169-4ccc-a13b-4c46f42be70e.jpg
# 16  b639929c-28e0-4533-b374-36173c224f6b.jpg
# 18  fe2fdfcc-6de5-4412-828b-6f0270d4ae7b.jpg
# 12  95553353-8ff7-436c-a926-4fa7f7bf5bd6.jpg
#
#                                                    gt  \
# 0   ⒹLa Jarry ⒸPréaus denis vincent Ⓕ1634 Ⓔterre\n...
# 4   ⒹEntre les deux→ruelles Ⓖ243 ⒸDefresne pierre ...
# 13  ⒹLes Saint Méry→id Ⓖ708 ⒸThevenard louis marie...
# 3   ⒹLe Bordiau ⒸPitou Pierre fils à fontenay Ⓕ101...
# 14  Ⓓport de la→varenne Ⓖ90 ⒸKretz Ⓕ364 Ⓔpavillon ...
# 8   ⒹLa tombe Ⓖ666 ⒸTalon gendarme Ⓕ841 Ⓔterre Ⓐ42...
# 10  Ⓓle h champ des→moines Ⓖ32 ⒸCassin Ⓕ392 ⒺT. pl...
# 7   ⒹRut Grand Ⓖ154 ⒸCoulombier J↑ques↓ H↑ers↓ Ⓕ40...
# 6   ⒹVacher Ⓖ186 ⒸCretté J↑n↓ Cadet Prompt Ⓕ1732 Ⓔ...
# 5   Ⓓchemin→de Brie→ Ⓖ95 ⒸLefevre Ⓕ166 Ⓔterre\nⒹsu...
# 11  ⒹRue S↑t↓ Vincent ⒸWilcke Louis Chrétien→à Bel...
# 17  Ⓖ60 ⒸBlos Et↑ne↓ Ⓕ231 ⒺT↑re↓\nⒼ404 ⒸHuard J↑ue...
# 15  Ⓓ☼ Ⓖ319 ⒸFontaine, V↑e↓ Ⓕ1 ⒺTerre\nⒹ☼ Ⓖ267 Ⓒhu...
# 2   ⒹRue notre Dame ⒸViviard Jean françois Ⓕ964 ⒺM...
# 1   ⒹLa plaine du→Plessis Ⓖ69 ⒸPierreloth Ⓕ41 Ⓔmar...
# 9   Ⓓle bois des champs ⒸDelage Bourgeois Ⓕ19 ⒺBoi...
# 16  ⒹLe Petit→Parc Ⓖ234 ⒸPierlot→Banquier à Paris ...
# 18  Ⓓle petit parc ⒸPierlot banquier à Paris Ⓕ16↑b...
# 12  ⒹLa plaine du→Plessis Ⓖ69 ⒸPierre loth Ⓕ61 ⒺBo...
#
#                                                  pred ?    score
# 0   ⒹLa Jarrig ⒸPréauf denis vincent Ⓕ1634 ⒺTerre\...     0.3293
# 4   ⒹCutre les denx→Ruelles Ⓖ38 ⒸDefresne pierre J...     0.3413
# 13  ⒹLes saint Méry Ⓖ704 ⒸThevenard louis marie a ...     0.3936
# 3   ⒹLe Bordiau ⒸPilon Pierre fils à Fontenay Ⓕ101...     0.4021
# 14  Ⓓport de la→varenne Ⓖ90 ⒸHretz Ⓕ364 Ⓔpavillon ...     0.4286
# 8   ⒹLa tombe terre ⒸCalon Gendarnie Ⓕ841 Ⓔterre Ⓐ...     0.5000
# 10  Ⓓle th champ des→moiher Ⓖ32 ⒸCaffin Ⓕ392 ⒺT. p...     0.5672
# 7   ⒹRue GGrand Ⓖ154 ⒸCoulombier J↑ques↓ Ⓕ409 ⒺTer...     0.5787
# 6   Ⓖ306 ⒸCretté J↑n↓ Caset P1732 ⒺTer\nⒸ×77± ⒸBou...     0.5879
# 5   ⒹChemin→de Brie Ⓖ95 ⒸLefevte Ⓕ95 Ⓔterre\nⒹØ Ⓖ2...     0.5921
# 11  ⒹRue de Vincent→g97 ⒸAilette Louis chétien,→à ...     0.6000
# 17  Ⓖ60 ⒸBlos h231 ⒺTerre\nⒼ404 Ⓒhuard Ⓕ232 Ⓔmaiso...     0.6329
# 15  ⒹLe Conte dubois Ⓖ267 ⒸLe Coute Dubois Ⓕ496 ⒺT...     0.6854
# 2   ⒹRue notre dame de louteur Ⓖ196 ⒸPidiard Jean ...     0.6908
# 1   ⒹLa plaine du→Plessis Ⓖ69 ⒸPierredlalbith Ⓕ138...     0.7768
# 9   Ⓓle bois des champs Ⓖ324 ⒸDelaage Bourgeois Ⓕ1...     0.8723
# 16  ⒹLe Petit Ⓖ234 ⒸPierlot Banguis Ⓕ234 ⒺPotager\...     0.9255
# 18  Ⓓle petit pare Ⓖ72 Ⓒid Ⓕ16 ↑bis↓ ⒺGagon d'agt\...     3.7308
# 12  ⒹLa plaine gue→Reppe du peillis Ⓕ61 ⒺBois tt\n...    15.2222

# %% [markdown]
# ### 2.2 ie-eval evaluation
# This is a test using the ie-eval lib. Not mandatory. Requires a dedicated virtual environnement with ie-eval package.
# Required to convert data in IOB format.

# %%
import os
import subprocess
import json
import pandas as pd
from dan.bio import convert
from dan.utils import EntityType

ner_tokens = {
        "ancien_numero_parcelle": EntityType(start="Ⓐ"),
        "ancienne_nature": EntityType(start="Ⓑ"),
        "identite": EntityType(start="Ⓒ"),
        "lieu-dit": EntityType(start="Ⓓ"),
        "nature": EntityType(start="Ⓔ"),
        "numero_parcelle": EntityType(start="Ⓕ"),
        "numero_proprietaire": EntityType(start="Ⓖ"),
    }

GT_JSON = ROOT + "/dataset2/page_dataset/split.json"
GT_IOB_FOLDER = ROOT + "/scripts/DAN/iob/labels"
PRED_DAN_FOLDER = "/home/STual/DAN-cadastre/inference/training120325_config2025_prod_2000epochs"
PRED_IOB_FOLDER = "/home/STual/DAN-cadastre/inference/iob/predictions/test"
DAN_TOKENS = "/home/STual/DAN-cadastre/dataset2/tokens.yml"

CONVERT = False

def convert_danlabels_to_iob(split_json_path, save_dir, ner_tokens, subsets=["train","val","test"]):
    """
    :param split_json_path: Path to the split.json file of a DAN dataset produced with teklia dan
    :param save_dir: Path to the folder where to save the data in iob format
    :param ner_tokens: Dict of the entity and their corresponding special token
    :param subsets: List of the subsets to convert to iob format. Default = ["train","val","test"]
    """

    with open(split_json_path, 'r') as file:
        data = json.load(file)
        
    if not os.path.exists(save_dir):
            os.makedirs(save_dir)
        
    for subset in subsets:
        if not os.path.exists(save_dir + '/' + subset):
            os.makedirs(save_dir + '/' + subset)
        gt = data[subset]
        
        ls = []
        for elem in gt:
            uuid = elem
            image = gt[elem]["image"]["iiif_url"]
            text = gt[elem]["text"]
            row = [uuid,image,text]
            ls.append(row)
        df_gt = pd.DataFrame(ls,columns=["uuid","image","text"])
        
        #for _, row in df_gt.iterrows():
            #page_convert = convert(row["text"], ner_tokens).split("\n")
            #with open(save_dir + '/' + subset + '/' + row["uuid"] + '.bio','w',encoding='utf8') as f:
                #f.write("\n".join(page_convert))
                
if __name__ == "__main__":
    if CONVERT:
        # Convert DAN labels in IOB
        convert_danlabels_to_iob(GT_JSON, GT_IOB_FOLDER, ner_tokens)
        # Convert DAN predictions as IOB
        command_pred_test = f"teklia-dan convert {PRED_DAN_FOLDER} --output {PRED_IOB_FOLDER} --tokens {DAN_TOKENS}"
        result = subprocess.run(command_pred_test, capture_output=True, text=True)
        print("Output:", result.stdout)
        print("Error:", result.stderr)

# %%
for _, row in test_df_gt.iterrows():
    page_convert = convert(row["text"], ner_tokens).split("\n")
    with open(""row["uuid"] + '.bio','w',encoding='utf8') as f:
        f.write("\n".join(page_convert))

# %% [markdown]
# | Category | BoW-F1 (%) | BoTW-F1 (%) | BoE-F1 (%) | N documents |
# |:---------|:----------:|:-----------:|:----------:|------------:|
# | total    |   59.45    |    57.86    |   58.83    |          27 |
#
# | Category               | BoW-F1 (%) | BoTW-F1 (%) | BoE-F1 (%) | N documents |
# |:-----------------------|:----------:|:-----------:|:----------:|------------:|
# | total                  |   59.45    |    57.86    |   58.83    |          27 |
# | nature                 |   64.22    |    64.22    |   65.48    |          27 |
# | numero_proprietaire    |   71.41    |    71.41    |   73.04    |          22 |
# | numero_parcelle        |   76.67    |    76.67    |   76.97    |          27 |
# | identite               |   46.59    |    46.59    |   31.58    |          27 |
# | lieu-dit               |   60.17    |    60.17    |   59.56    |          20 |
# | ancien_numero_parcelle |   35.42    |    35.42    |   38.77    |           9 |
# | ancienne_nature        |   48.15    |    48.15    |   47.29    |           8 |
