# %% [markdown]
# # 31 - Visualisation
#
# This is an additionnal notebook to visualize the annotations produced by DAN.

# %%
import sys
import os
# Access to the utils directory
current_dir = os.getcwd()
utils_dir = os.path.join(current_dir, '..', 'utils')
sys.path.append(utils_dir)

# %%
from viz import load_and_display_page_level

# %%
ROOT = '/home/STual/DAN-cadastre/'
UUID = "dda7ced2-28cc-4ed3-8b10-afc82df60634"
JSON_FOLDER = ROOT + "inference/training120325_config2025_prod_2000epochs"
IMAGE_FOLDER = ROOT + "dataset2/page_dataset/images/test/032ae384-77dd-4ec8-868a-4348dd74897f"

# %%
print("The rectangles correspond to the area to which the model paid the most attention.")
load_and_display_page_level(JSON_FOLDER,IMAGE_FOLDER,UUID,2000,3000,False)
# Out:
# The rectangles correspond to the area to which the model paid the most attention.
# Number of lines in image: 18
# <PIL.Image.Image image mode=RGB size=1200x1068>
