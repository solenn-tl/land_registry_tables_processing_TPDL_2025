# %% [markdown]
# # 40 - Inference
#
# This notebook details the guidelines to use the fine-tuned DAN on new data. If you don't use Arkindex, use only the command line in part 2.

# %%
import sys
import os
import re
import pandas as pd
import glob
import json
import plotly.express as px
import json
from arkindex import ArkindexClient
from dan.datasets.download.images import ImageDownloader
from apistar.exceptions import ErrorResponse
import uuid

# Access to the utils directory
current_dir = os.getcwd()
utils_dir = os.path.join(current_dir, '..', 'utils')
sys.path.append(utils_dir)

# %%
from arkindex_utils import listelementschildren_to_df
from download_utils import download_images_from_list
from viz import restore_polygon_to_original_size

# %%
ROOT = "/home/STual/DAN-cadastre"
SAVE_DIR = ROOT + "/data/LHAY/ets_tab_p1"

# %% [markdown]
# ## 1 Download IIIF images from Arkindex
# If you already have downloaded the images, you can skip this step.

# %%
cli = ArkindexClient('cdf9b285c9da6e82cddbf18aa070dc471a13facb')

# %%
# L'hay section b folder : ccc0c979-d7d8-468f-bc1b-38d4dadbb80c
# Retrieve ets_tab_p1 only (51b9743b-3300-4a12-be69-e69395a2efbc)
elements = cli.request('ListElementChildren',
                       id="2ec47da6-116b-4f53-bd93-da7aac699a4a",
                       type="page",class_id="51b9743b-3300-4a12-be69-e69395a2efbc",
                       recursive=True,folder=False,page_size=500,page=1
                    )

elements2 = cli.request('ListElementChildren',
                       id="2ec47da6-116b-4f53-bd93-da7aac699a4a",
                       type="page_add_to_cor",class_id="51b9743b-3300-4a12-be69-e69395a2efbc",
                       recursive=True,folder=False,page_size=500,page=1
                       )

# %%
dfelem1 = pd.DataFrame.from_dict(listelementschildren_to_df(elements))
dfelem2 = pd.DataFrame.from_dict(listelementschildren_to_df(elements2))
df = pd.concat([dfelem1,dfelem2])
df = df.reset_index()
df = df.drop('index', axis=1)
display(df)
# Out:
#                                       id                       name  \
# 0   eb4fc8e4-abb6-4b61-b3cc-3b244611e66f  FRAD094_3P_000275_01_0133
# 1   26d52fc2-aafc-4e58-91f8-68bd6851ad37  FRAD094_3P_000275_01_0134
# 2   f937f814-1950-48e0-a095-bb61ee89b2f3  FRAD094_3P_000275_01_0135
# 3   b5e51a0b-23e8-4b63-a074-3ad00f40ecda  FRAD094_3P_000275_01_0136
# 4   c8299489-3750-499c-a924-7f3365401c75  FRAD094_3P_000275_01_0137
# 5   683e7c3e-e537-44ba-8a02-3c4678d86b2f  FRAD094_3P_000275_01_0138
# 6   d7b0141b-7950-4d9b-a947-92728f613d8d  FRAD094_3P_000275_01_0139
# 7   8d60076b-985d-4374-acb8-c8f17db50d76  FRAD094_3P_000275_01_0140
# 8   acb5c0fb-1901-405f-862e-f0726e867e7d  FRAD094_3P_000275_01_0141
# 9   92fb30f9-6891-46e0-adb0-ad396a3ad2dc  FRAD094_3P_000275_01_0142
# 10  79ee0e05-59c0-4770-a20e-326574627577  FRAD094_3P_000275_01_0143
# 11  2c59c9c6-5ed5-4fc1-85cd-4d162c324239  FRAD094_3P_000275_01_0144
# 12  9d6d69fc-cc55-4007-acbc-4ec375bec1b3  FRAD094_3P_000275_01_0145
# 13  b9996140-18ce-4374-8a66-01c4acdcbb2f  FRAD094_3P_000275_01_0146
# 14  f10c1378-c307-4b24-95f8-1c016610d4af  FRAD094_3P_000275_01_0147
# 15  2e198618-c734-4d73-a67f-79fda49504f5  FRAD094_3P_000275_01_0148
# 16  ad913b91-539f-4645-bcde-69dee0c09bb3  FRAD094_3P_000275_01_0149
# 17  b38e1412-734c-423a-8abc-6758bff52e19  FRAD094_3P_000275_01_0150
# 18  064cc4ee-9d5e-4922-a6dc-954aaf38fab2  FRAD094_3P_000275_01_0151
# 19  724852d2-464c-4364-a051-8a4505d6cbea  FRAD094_3P_000275_01_0152
# 20  d674fbbe-3b26-4e9d-8a6f-c8c8533d3123  FRAD094_3P_000275_01_0153
# 21  9fde8f6c-f4bd-400c-9710-94f268917bf8  FRAD094_3P_000275_01_0154
# 22  7cc717f5-4612-45f0-8181-7e341e937880  FRAD094_3P_000275_01_0155
# 23  ba86e3f2-7bb6-49a8-a2c2-0773e0a79626  FRAD094_3P_000275_01_0156
# 24  3435dedc-ddc0-4dfd-b834-d04148e44ddf  FRAD094_3P_000275_01_0157
# 25  9e52f7f9-0e66-4753-bcf3-d3cb0916678c  FRAD094_3P_000275_01_0158
# 26  eb6486bb-623d-4ddf-a704-7cebf29e730c  FRAD094_3P_000275_01_0159
# 27  0d2dbad9-68dd-4c66-a44d-87980720bc14  FRAD094_3P_000275_01_0160
# 28  d9678cb5-6ee1-4fda-9963-83108030d9b8  FRAD094_3P_000275_01_0161
#
#                                                coords  \
# 0   [[0, 0], [0, 5656], [3565, 5656], [3565, 0], [...
# 1   [[0, 0], [0, 5664], [3624, 5664], [3624, 0], [...
# 2   [[0, 0], [0, 5664], [3668, 5664], [3668, 0], [...
# 3   [[0, 0], [0, 5663], [3610, 5663], [3610, 0], [...
# 4   [[0, 0], [0, 5656], [3668, 5656], [3668, 0], [...
# 5   [[0, 0], [0, 5663], [3618, 5663], [3618, 0], [...
# 6   [[0, 0], [0, 5664], [3668, 5664], [3668, 0], [...
# 7   [[0, 0], [0, 5656], [3604, 5656], [3604, 0], [...
# 8   [[0, 0], [0, 5664], [3674, 5664], [3674, 0], [...
# 9   [[0, 0], [0, 5656], [3604, 5656], [3604, 0], [...
# 10  [[0, 0], [0, 5664], [3668, 5664], [3668, 0], [...
# 11  [[0, 0], [0, 5656], [3630, 5656], [3630, 0], [...
# 12  [[0, 0], [0, 5669], [3662, 5669], [3662, 0], [...
# 13  [[0, 0], [0, 5656], [3630, 5656], [3630, 0], [...
# 14  [[0, 0], [0, 5669], [3662, 5669], [3662, 0], [...
# 15  [[0, 0], [0, 5663], [3579, 5663], [3579, 0], [...
# 16  [[0, 0], [0, 5675], [3694, 5675], [3694, 0], [...
# 17  [[0, 0], [0, 5677], [3598, 5677], [3598, 0], [...
# 18  [[0, 0], [0, 5675], [3694, 5675], [3694, 0], [...
# 19  [[0, 0], [0, 5669], [3610, 5669], [3610, 0], [...
# 20  [[0, 0], [0, 5663], [3674, 5663], [3674, 0], [...
# 21  [[0, 0], [0, 5669], [3604, 5669], [3604, 0], [...
# 22  [[0, 0], [0, 5675], [3662, 5675], [3662, 0], [...
# 23  [[0, 0], [0, 5669], [3624, 5669], [3624, 0], [...
# 24  [[0, 0], [0, 5677], [3674, 5677], [3674, 0], [...
# 25  [[0, 0], [0, 5677], [3604, 5677], [3604, 0], [...
# 26  [[0, 0], [0, 5663], [3674, 5663], [3674, 0], [...
# 27  [[0, 0], [0, 5663], [3668, 5663], [3668, 0], [...
# 28  [[0, 0], [0, 5675], [3674, 5675], [3674, 0], [...
#
#                                 image_id  \
# 0   89c4f1f9-b119-4229-861c-fb64d953099d
# 1   44136ba4-ebf7-442a-b7ff-5d40c17ba080
# 2   70c70abd-a0e5-49e2-ac06-52642f37ce48
# 3   dfec8720-063c-4a93-83a1-fe1e7414ff61
# 4   03996fd6-ccfc-4b0e-bcf5-f643dc4f55a5
# 5   1a75a871-b8c9-4484-aea8-30d0c59def71
# 6   9cec091a-b9dd-4d9d-a8bf-3f44b9a4b356
# 7   0e94578d-4bf2-4c40-9c13-bb7bac9a0d8e
# 8   23411457-a033-427d-acd5-e299159734f7
# 9   afc98034-9e15-4f9e-8fe0-3cdb5121ec85
# 10  cd42fe28-d3ec-4081-9f7d-585051cb8fc8
# 11  262be557-5251-476d-b34f-24f27c60b23f
# 12  cec994a5-071c-485b-b03f-41e76d2cc84b
# 13  2cae29db-5f6c-46df-8ab4-6511be878f3f
# 14  e3e055d9-4caf-4edc-a6ae-c3541f4afc0c
# 15  d280e6ba-2edc-49cc-8d5a-bb8430835df8
# 16  f7587a31-c50b-4acc-9763-a6893acd4d8f
# 17  9c07893d-4c60-457c-94c6-27cf9947f14a
# 18  7ce3e441-8cef-4800-8765-15608360da7b
# 19  5e202378-a3a1-431a-9dc7-29c7930cf816
# 20  4eb68d7b-9b4b-4e6e-894c-0f17578f6884
# 21  67f88648-2f14-4be4-a85c-200119bd730f
# 22  2ce15569-5a9e-43d1-b716-47dec55ff103
# 23  32de5d28-72ee-4902-9575-17973813796d
# 24  40d0319a-52ef-4f58-a822-c2aaba94c7db
# 25  805065aa-c7f6-4026-aa7c-9cc5b7e2e547
# 26  acbd28b2-e4f0-42b0-afa4-000141e643f8
# 27  bf1d15f0-e85a-474b-a883-df4b432f8948
# 28  64e4d271-912b-4b55-a9df-04fcaeaa1bdd
#
#                                            image_name commune  \
# 0   CADASTRE%2FETATS_DE_SECTION%2FLHAY%2FFRAD094_3...    LHAY
# 1   CADASTRE%2FETATS_DE_SECTION%2FLHAY%2FFRAD094_3...    LHAY
# 2   CADASTRE%2FETATS_DE_SECTION%2FLHAY%2FFRAD094_3...    LHAY
# 3   CADASTRE%2FETATS_DE_SECTION%2FLHAY%2FFRAD094_3...    LHAY
# 4   CADASTRE%2FETATS_DE_SECTION%2FLHAY%2FFRAD094_3...    LHAY
# 5   CADASTRE%2FETATS_DE_SECTION%2FLHAY%2FFRAD094_3...    LHAY
# 6   CADASTRE%2FETATS_DE_SECTION%2FLHAY%2FFRAD094_3...    LHAY
# 7   CADASTRE%2FETATS_DE_SECTION%2FLHAY%2FFRAD094_3...    LHAY
# 8   CADASTRE%2FETATS_DE_SECTION%2FLHAY%2FFRAD094_3...    LHAY
# 9   CADASTRE%2FETATS_DE_SECTION%2FLHAY%2FFRAD094_3...    LHAY
# 10  CADASTRE%2FETATS_DE_SECTION%2FLHAY%2FFRAD094_3...    LHAY
# 11  CADASTRE%2FETATS_DE_SECTION%2FLHAY%2FFRAD094_3...    LHAY
# 12  CADASTRE%2FETATS_DE_SECTION%2FLHAY%2FFRAD094_3...    LHAY
# 13  CADASTRE%2FETATS_DE_SECTION%2FLHAY%2FFRAD094_3...    LHAY
# 14  CADASTRE%2FETATS_DE_SECTION%2FLHAY%2FFRAD094_3...    LHAY
# 15  CADASTRE%2FETATS_DE_SECTION%2FLHAY%2FFRAD094_3...    LHAY
# 16  CADASTRE%2FETATS_DE_SECTION%2FLHAY%2FFRAD094_3...    LHAY
# 17  CADASTRE%2FETATS_DE_SECTION%2FLHAY%2FFRAD094_3...    LHAY
# 18  CADASTRE%2FETATS_DE_SECTION%2FLHAY%2FFRAD094_3...    LHAY
# 19  CADASTRE%2FETATS_DE_SECTION%2FLHAY%2FFRAD094_3...    LHAY
# 20  CADASTRE%2FETATS_DE_SECTION%2FLHAY%2FFRAD094_3...    LHAY
# 21  CADASTRE%2FETATS_DE_SECTION%2FLHAY%2FFRAD094_3...    LHAY
# 22  CADASTRE%2FETATS_DE_SECTION%2FLHAY%2FFRAD094_3...    LHAY
# 23  CADASTRE%2FETATS_DE_SECTION%2FLHAY%2FFRAD094_3...    LHAY
# 24  CADASTRE%2FETATS_DE_SECTION%2FLHAY%2FFRAD094_3...    LHAY
# 25  CADASTRE%2FETATS_DE_SECTION%2FLHAY%2FFRAD094_3...    LHAY
# 26  CADASTRE%2FETATS_DE_SECTION%2FLHAY%2FFRAD094_3...    LHAY
# 27  CADASTRE%2FETATS_DE_SECTION%2FLHAY%2FFRAD094_3...    LHAY
# 28  CADASTRE%2FETATS_DE_SECTION%2FLHAY%2FFRAD094_3...    LHAY
#
#             dossier_cote                 image_cote image_index  \
# 0   FRAD094_3P_000275_01  FRAD094_3P_000275_01_0133         133
# 1   FRAD094_3P_000275_01  FRAD094_3P_000275_01_0134         134
# 2   FRAD094_3P_000275_01  FRAD094_3P_000275_01_0135         135
# 3   FRAD094_3P_000275_01  FRAD094_3P_000275_01_0136         136
# 4   FRAD094_3P_000275_01  FRAD094_3P_000275_01_0137         137
# 5   FRAD094_3P_000275_01  FRAD094_3P_000275_01_0138         138
# 6   FRAD094_3P_000275_01  FRAD094_3P_000275_01_0139         139
# 7   FRAD094_3P_000275_01  FRAD094_3P_000275_01_0140         140
# 8   FRAD094_3P_000275_01  FRAD094_3P_000275_01_0141         141
# 9   FRAD094_3P_000275_01  FRAD094_3P_000275_01_0142         142
# 10  FRAD094_3P_000275_01  FRAD094_3P_000275_01_0143         143
# 11  FRAD094_3P_000275_01  FRAD094_3P_000275_01_0144         144
# 12  FRAD094_3P_000275_01  FRAD094_3P_000275_01_0145         145
# 13  FRAD094_3P_000275_01  FRAD094_3P_000275_01_0146         146
# 14  FRAD094_3P_000275_01  FRAD094_3P_000275_01_0147         147
# 15  FRAD094_3P_000275_01  FRAD094_3P_000275_01_0148         148
# 16  FRAD094_3P_000275_01  FRAD094_3P_000275_01_0149         149
# 17  FRAD094_3P_000275_01  FRAD094_3P_000275_01_0150         150
# 18  FRAD094_3P_000275_01  FRAD094_3P_000275_01_0151         151
# 19  FRAD094_3P_000275_01  FRAD094_3P_000275_01_0152         152
# 20  FRAD094_3P_000275_01  FRAD094_3P_000275_01_0153         153
# 21  FRAD094_3P_000275_01  FRAD094_3P_000275_01_0154         154
# 22  FRAD094_3P_000275_01  FRAD094_3P_000275_01_0155         155
# 23  FRAD094_3P_000275_01  FRAD094_3P_000275_01_0156         156
# 24  FRAD094_3P_000275_01  FRAD094_3P_000275_01_0157         157
# 25  FRAD094_3P_000275_01  FRAD094_3P_000275_01_0158         158
# 26  FRAD094_3P_000275_01  FRAD094_3P_000275_01_0159         159
# 27  FRAD094_3P_000275_01  FRAD094_3P_000275_01_0160         160
# 28  FRAD094_3P_000275_01  FRAD094_3P_000275_01_0161         161
#
#                                             image_url  image_width  \
# 0   https://iiif.geohistoricaldata.org/iiif/2/CADA...         3565
# 1   https://iiif.geohistoricaldata.org/iiif/2/CADA...         3624
# 2   https://iiif.geohistoricaldata.org/iiif/2/CADA...         3668
# 3   https://iiif.geohistoricaldata.org/iiif/2/CADA...         3610
# 4   https://iiif.geohistoricaldata.org/iiif/2/CADA...         3668
# 5   https://iiif.geohistoricaldata.org/iiif/2/CADA...         3618
# 6   https://iiif.geohistoricaldata.org/iiif/2/CADA...         3668
# 7   https://iiif.geohistoricaldata.org/iiif/2/CADA...         3604
# 8   https://iiif.geohistoricaldata.org/iiif/2/CADA...         3674
# 9   https://iiif.geohistoricaldata.org/iiif/2/CADA...         3604
# 10  https://iiif.geohistoricaldata.org/iiif/2/CADA...         3668
# 11  https://iiif.geohistoricaldata.org/iiif/2/CADA...         3630
# 12  https://iiif.geohistoricaldata.org/iiif/2/CADA...         3662
# 13  https://iiif.geohistoricaldata.org/iiif/2/CADA...         3630
# 14  https://iiif.geohistoricaldata.org/iiif/2/CADA...         3662
# 15  https://iiif.geohistoricaldata.org/iiif/2/CADA...         3579
# 16  https://iiif.geohistoricaldata.org/iiif/2/CADA...         3694
# 17  https://iiif.geohistoricaldata.org/iiif/2/CADA...         3598
# 18  https://iiif.geohistoricaldata.org/iiif/2/CADA...         3694
# 19  https://iiif.geohistoricaldata.org/iiif/2/CADA...         3610
# 20  https://iiif.geohistoricaldata.org/iiif/2/CADA...         3674
# 21  https://iiif.geohistoricaldata.org/iiif/2/CADA...         3604
# 22  https://iiif.geohistoricaldata.org/iiif/2/CADA...         3662
# 23  https://iiif.geohistoricaldata.org/iiif/2/CADA...         3624
# 24  https://iiif.geohistoricaldata.org/iiif/2/CADA...         3674
# 25  https://iiif.geohistoricaldata.org/iiif/2/CADA...         3604
# 26  https://iiif.geohistoricaldata.org/iiif/2/CADA...         3674
# 27  https://iiif.geohistoricaldata.org/iiif/2/CADA...         3668
# 28  https://iiif.geohistoricaldata.org/iiif/2/CADA...         3674
#
#     image_height
# 0           5656
# 1           5664
# 2           5664
# 3           5663
# 4           5656
# 5           5663
# 6           5664
# 7           5656
# 8           5664
# 9           5656
# 10          5664
# 11          5656
# 12          5669
# 13          5656
# 14          5669
# 15          5663
# 16          5675
# 17          5677
# 18          5675
# 19          5669
# 20          5663
# 21          5669
# 22          5675
# 23          5669
# 24          5677
# 25          5677
# 26          5663
# 27          5663
# 28          5675

# %%
DOWNLOAD = False

if DOWNLOAD:
    downloader = ImageDownloader() # Create an instance of ImageDownloader
    
    # IIIF server 
    base_url = "https://iiif.geohistoricaldata.org/iiif/2/" #To adapt to you IIIF server
    
    urls, elements_uuid = [], []
    for _, row in df.iterrows():  
        # Assuming df is a DataFrame and "coords" and "image_name" are columns in it
        elements_uuid.append(row["id"])
        
        coords = row["coords"]
        image_name = row["image_name"]
        full_url = downloader.build_iiif_url(coords, base_url + image_name)
        urls.append(full_url)

    #download_images_from_list(SAVE_DIR, urls, elements_uuid)

# %% [markdown]
# ## 2. Inference
# This command should be run in the terminal, preferably in a persistent session (byobu).

# %% [raw]
# teklia-dan predict \
#     --image-dir /home/STual/DAN-cadastre/data/LHAY/ \
#     --model /home/STual/DAN-cadastre/outputs/training120325_config2025_prod_2000epochs/ \
#     --output /home/STual/DAN-cadastre/inference/LHAY/ \
#     --tokens /home/STual/DAN-cadastre/dataset2/tokens.yml \
#     --font /home/STual/DAN-cadastre/scripts/DAN/fonts/LinuxLibertine.ttf \
#     --dynamic-mode \
#     --confidence-score \
#     --attention-map \
#     --predict-objects

# %% [markdown]
# ## 3. Load results to Arkindex
# You can skip this part if you don't use Arkindex.

# %%
PATH_RES = ROOT + "/inference/LHAY"
CORPUS_UUID = '59285827-bba3-42d4-99c7-e2436fe19f94'
TAB_LINE_CLASS = "1cf133ba-7640-4ff5-b518-a150228460b4"

# %%
from elements_utils import sort_by_centroid_y
from string_utils import delete_characters, split_text_at_characters, create_split_dictionary
# Out:
# [nltk_data] Downloading package punkt to /home/STual/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/STual/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Retrieve the json files correspoding to pages automatic transcription by DAN.

# %%
RES_FILES = sorted(glob.glob(PATH_RES + '/*.json'))

# %%
PAGES = []
for R in RES_FILES:
    page_uuid = R.replace(PATH_RES,"")
    page_uuid = page_uuid.replace(".json","").replace('/','')
    PAGES.append([R,page_uuid])

# %%
len(PAGES)
# Out:
# 26

# %%
for p in PAGES[35:]:
    print(p[1])

# %% [markdown]
# ### 3.1 Load infered lines

# %%
# Open the file entities.json (link between the special tokens and Arkindex entities)
with open('entities.json', 'r') as file2:
    entities = json.load(file2)
chars_to_split = list(entities.keys())

# %%
IMPORT = False

if IMPORT:
    for json_path, page_uuid in PAGES:
        print(page_uuid)
        #Open the JSON containing DAN results
        with open(json_path, 'r') as file:
            data = json.load(file)
    
        #Retrieve image infos
        image = cli.request('RetrieveElement',id=page_uuid)
        width = image["zone"]["image"]["width"]
        height = image["zone"]["image"]["height"]
        print(width,height)
        #Update page classification
        parent_classification_request = cli.request('CreateClassification',body={"element":page_uuid,"ml_class":TAB_LINE_CLASS})
    
        counter = 0
        for e in data["objects"]:
            original_polygon = restore_polygon_to_original_size(e["polygon"], width, height, max_width=2000, max_height=3000)
            #Create Element
            elem = {"type": "tab_line_add",
            "name": str(counter),
            "corpus": CORPUS_UUID,
            "parent": page_uuid,
            "polygon": original_polygon,
            "confidence": e["confidence"]}
            elem_request = cli.request('CreateElement',body=elem)
            parent_classification_request = cli.request('CreateClassification',body={"element":elem_request["id"],"ml_class":"52aed5fb-791a-4c2a-93d8-f7050c5b5b46"}) #line_true by default
            
            #CreateTranscription
            text = e["text"].replace('ⒼⒼ','Ⓖ')
            t = delete_characters(text,chars_to_split)
            transcription_body={"text": t,"confidence": e["text_confidence"],"orientation": "horizontal-lr"}
            transcription_request = cli.request('CreateTranscription',
                    id=elem_request["id"],
                    body=transcription_body)
            
            entities_dict = create_split_dictionary(text, chars_to_split)
            for ent in entities_dict:
                entity_body = {
                "name": entities_dict[ent]["text"],
                "type_id": entities[ent]["uuid"],
                "corpus": CORPUS_UUID,
                }
                #CreateEntity
                entity_request = cli.request('CreateEntity',body=entity_body)
                transcriptionentity_body = {"entity":entity_request["id"],
                                            "type_id":entities[ent]["uuid"],
                                            "offset":entities_dict[ent]["offset"],
                                            "length":entities_dict[ent]["length"]
                                           }
                #CreateTranscriptionEntity
                transcriptionentity_request = cli.request('CreateTranscriptionEntity',
                    id=transcription_request["id"],
                    body=transcriptionentity_body)
            print(t,transcription_body)
            counter += 1
# Out:
# d7b0141b-7950-4d9b-a947-92728f613d8d
# 3668 5664
# La voie des→21 Barchoux denis 84 Terre 93 T {'text': 'La voie des→21 Barchoux denis 84 Terre 93 T', 'confidence': 0.95, 'orientation': 'horizontal-lr'}
# § 129 Godefroy denis V↑e↓ 85 T 94 T {'text': '§ 129 Godefroy denis V↑e↓ 85 T 94 T', 'confidence': 0.99, 'orientation': 'horizontal-lr'}
# § 212 Massuet germard 86 T 95 T {'text': '§ 212 Massuet germard 86 T 95 T', 'confidence': 0.99, 'orientation': 'horizontal-lr'}
# § 215 Mateu Jacques F↑ois↓ V↑e↓ 87 T 100 T {'text': '§ 215 Mateu Jacques F↑ois↓ V↑e↓ 87 T 100 T', 'confidence': 0.99, 'orientation': 'horizontal-lr'}
# § 147 hnard f↑ois↓ J↑n↓ 88 T 102→101 T {'text': '§ 147 hnard f↑ois↓ J↑n↓ 88 T 102→101 T', 'confidence': 0.99, 'orientation': 'horizontal-lr'}
# § 77 Chevreul michel 89 T 1026↑bis↓→102 T→T {'text': '§ 77 Chevreul michel 89 T 1026↑bis↓→102 T→T', 'confidence': 0.96, 'orientation': 'horizontal-lr'}
# § 77 idem 90 T.pl 1026↑bis↓ T {'text': '§ 77 idem 90 T.pl 1026↑bis↓ T', 'confidence': 0.97, 'orientation': 'horizontal-lr'}
# § 54 Bronzacpierre 91 Tprt 103p Ø {'text': '§ 54 Bronzacpierre 91 Tprt 103p Ø', 'confidence': 0.97, 'orientation': 'horizontal-lr'}
# § 233 Monsson J↑n↓ b↑te↓ 92 T 103p T {'text': '§ 233 Monsson J↑n↓ b↑te↓ 92 T 103p T', 'confidence': 0.97, 'orientation': 'horizontal-lr'}
# § 64 Chanevas louis 93 T. 103p T {'text': '§ 64 Chanevas louis 93 T. 103p T', 'confidence': 0.98, 'orientation': 'horizontal-lr'}
# § 26 Denoist Otanislas 94 T 1066↑bis↓ {'text': '§ 26 Denoist Otanislas 94 T 1066↑bis↓', 'confidence': 0.99, 'orientation': 'horizontal-lr'}
# T {'text': 'T', 'confidence': 0.97, 'orientation': 'horizontal-lr'}
# § 26 idem 95 T 1044→105 T {'text': '§ 26 idem 95 T 1044→105 T', 'confidence': 0.99, 'orientation': 'horizontal-lr'}
# § 26 idem 96 T 104p→105 p T {'text': '§ 26 idem 96 T 104p→105 p T', 'confidence': 0.96, 'orientation': 'horizontal-lr'}
# § 75 Chevalier houssaint 97 T. 106 T {'text': '§ 75 Chevalier houssaint 97 T. 106 T', 'confidence': 0.97, 'orientation': 'horizontal-lr'}
# d9678cb5-6ee1-4fda-9963-83108030d9b8
# 3674 5675
# Rue→ 338 Perin julien 707 cour et B↑t↓→n°24 404 cour et B↑te↓ {'text': 'Rue→ 338 Perin julien 707 cour et B↑t↓→n°24 404 cour et B↑te↓', 'confidence': 0.75, 'orientation': 'horizontal-lr'}
# § 7 id 63 maison pti 1041 j {'text': '§ 7 id 63 maison pti 1041 j', 'confidence': 0.74, 'orientation': 'horizontal-lr'}
# § § id 634 Maison pti 1332 j {'text': '§ § id 634 Maison pti 1332 j', 'confidence': 0.74, 'orientation': 'horizontal-lr'}
# § § id 653 maison cour→et B↑t↓ n°24 404 Ø {'text': '§ § id 653 maison cour→et B↑t↓ n°24 404 Ø', 'confidence': 0.81, 'orientation': 'horizontal-lr'}
# § Paris à Bour 156 T 253 T {'text': '§ Paris à Bour 156 T 253 T', 'confidence': 0.6, 'orientation': 'horizontal-lr'}
# § Parts Pierre 656 T p.213 T {'text': '§ Parts Pierre 656 T p.213 T', 'confidence': 0.67, 'orientation': 'horizontal-lr'}
# § Parlet B fontenay 1563 T P↑tie↓ 22003 T {'text': '§ Parlet B fontenay 1563 T P↑tie↓ 22003 T', 'confidence': 0.71, 'orientation': 'horizontal-lr'}
# § Basset Jean Baptiste 1563 T 2536 T {'text': '§ Basset Jean Baptiste 1563 T 2536 T', 'confidence': 0.71, 'orientation': 'horizontal-lr'}
# § Bassavet à françois 1565 T P↑tie↓ 2511 T {'text': '§ Bassavet à françois 1565 T P↑tie↓ 2511 T', 'confidence': 0.73, 'orientation': 'horizontal-lr'}
# § Bassau J↑n↓ B↑te↓ 1515 T P↑tie↓ 2201↑bis↓ T {'text': '§ Bassau J↑n↓ B↑te↓ 1515 T P↑tie↓ 2201↑bis↓ T', 'confidence': 0.79, 'orientation': 'horizontal-lr'}
# § Séricourd à Francois 1111 T P↑tie↓ 2201↑bis↓ T {'text': '§ Séricourd à Francois 1111 T P↑tie↓ 2201↑bis↓ T', 'confidence': 0.81, 'orientation': 'horizontal-lr'}
# § Sassin Pierre 1513 T P↑tie↓ 2201 T {'text': '§ Sassin Pierre 1513 T P↑tie↓ 2201 T', 'confidence': 0.77, 'orientation': 'horizontal-lr'}
# § Perier Pierre 1563 T P↑tie↓ 2201↑bis↓ T {'text': '§ Perier Pierre 1563 T P↑tie↓ 2201↑bis↓ T', 'confidence': 0.81, 'orientation': 'horizontal-lr'}
# § Sergist Paris 1111 T P↑tie↓ 2201 T {'text': '§ Sergist Paris 1111 T P↑tie↓ 2201 T', 'confidence': 0.75, 'orientation': 'horizontal-lr'}
# § Sassin Bimoist 151 T P↑tie↓ 2201 T {'text': '§ Sassin Bimoist 151 T P↑tie↓ 2201 T', 'confidence': 0.68, 'orientation': 'horizontal-lr'}
# § Saussaint françois 1541 T P↑tie↓ T {'text': '§ Saussaint françois 1541 T P↑tie↓ T', 'confidence': 0.78, 'orientation': 'horizontal-lr'}
# § Sarier Barie 1141 T P↑tie↓ T {'text': '§ Sarier Barie 1141 T P↑tie↓ T', 'confidence': 0.76, 'orientation': 'horizontal-lr'}
# § Surier Pierre 1413 T P↑tie↓ 2710↑bis↓ T {'text': '§ Surier Pierre 1413 T P↑tie↓ 2710↑bis↓ T', 'confidence': 0.76, 'orientation': 'horizontal-lr'}
# § Sèetier Joseph 1541 T P↑tie↓ T {'text': '§ Sèetier Joseph 1541 T P↑tie↓ T', 'confidence': 0.77, 'orientation': 'horizontal-lr'}
# eb4fc8e4-abb6-4b61-b3cc-3b244611e66f
# 3565 5656
# Voue des→Postes 300 Thibault Jean G↑re↓→claude 1 Terre 1→T {'text': 'Voue des→Postes 300 Thibault Jean G↑re↓→claude 1 Terre 1→T', 'confidence': 0.96, 'orientation': 'horizontal-lr'}
# § 282 Sérouge louisalexandre 2 Terre 3 T {'text': '§ 282 Sérouge louisalexandre 2 Terre 3 T', 'confidence': 0.99, 'orientation': 'horizontal-lr'}
# § 275 Robert J↑n↓ b↑te↓ 3 T 6 bie↓ T {'text': '§ 275 Robert J↑n↓ b↑te↓ 3 T 6 bie↓ T', 'confidence': 0.98, 'orientation': 'horizontal-lr'}
# § 160 Lamotte germain 4 T 7 T {'text': '§ 160 Lamotte germain 4 T 7 T', 'confidence': 0.99, 'orientation': 'horizontal-lr'}
# § 83 Cousté j↑h↓ 5 T 4 T {'text': '§ 83 Cousté j↑h↓ 5 T 4 T', 'confidence': 1.0, 'orientation': 'horizontal-lr'}
# § 216 Mayeux louis 6 T 5 T {'text': '§ 216 Mayeux louis 6 T 5 T', 'confidence': 1.0, 'orientation': 'horizontal-lr'}
# § 263 Reignautt fils 7 T 8 T {'text': '§ 263 Reignautt fils 7 T 8 T', 'confidence': 0.97, 'orientation': 'horizontal-lr'}
# § 263 idem 1 T 9.T {'text': '§ 263 idem 1 T 9.T', 'confidence': 0.96, 'orientation': 'horizontal-lr'}
# § 263 idem 9 T 10 T {'text': '§ 263 idem 9 T 10 T', 'confidence': 0.97, 'orientation': 'horizontal-lr'}
# § 196 Liou J↑n↓ michel 10 T 11 T {'text': '§ 196 Liou J↑n↓ michel 10 T 11 T', 'confidence': 0.97, 'orientation': 'horizontal-lr'}
# § 72 Cheva Pier louis Et↑e↓ 11 T 12 T {'text': '§ 72 Cheva Pier louis Et↑e↓ 11 T 12 T', 'confidence': 0.98, 'orientation': 'horizontal-lr'}
# § 200 Barrué J↑ques↓ victor 12 T 13→20 T {'text': '§ 200 Barrué J↑ques↓ victor 12 T 13→20 T', 'confidence': 0.98, 'orientation': 'horizontal-lr'}
# § 306 Trotier J↑h↓ 13 T 22 T {'text': '§ 306 Trotier J↑h↓ 13 T 22 T', 'confidence': 0.99, 'orientation': 'horizontal-lr'}
# eb6486bb-623d-4ddf-a704-7cebf29e730c
# 3674 5663
# Rue→ 73 Paris à Paris 1148 Terre 13 cour et Brte {'text': 'Rue→ 73 Paris à Paris 1148 Terre 13 cour et Brte', 'confidence': 0.69, 'orientation': 'horizontal-lr'}
# § 324 Paris 64 T 1541 T {'text': '§ 324 Paris 64 T 1541 T', 'confidence': 0.6, 'orientation': 'horizontal-lr'}
# § § id 64 T 1535 T {'text': '§ § id 64 T 1535 T', 'confidence': 0.78, 'orientation': 'horizontal-lr'}
# § § id 68 T 1535 T {'text': '§ § id 68 T 1535 T', 'confidence': 0.84, 'orientation': 'horizontal-lr'}
# § § id 66 T 1533 T {'text': '§ § id 66 T 1533 T', 'confidence': 0.8, 'orientation': 'horizontal-lr'}
# § id 66 T 1535 T {'text': '§ id 66 T 1535 T', 'confidence': 0.71, 'orientation': 'horizontal-lr'}
# § Larou Louis 65 T P.213 T {'text': '§ Larou Louis 65 T P.213 T', 'confidence': 0.69, 'orientation': 'horizontal-lr'}
# § Barsu 61 T 1541 T {'text': '§ Barsu 61 T 1541 T', 'confidence': 0.63, 'orientation': 'horizontal-lr'}
# § Bart Pharles 11 T P↑tie↓ 2011↑bis↓ T {'text': '§ Bart Pharles 11 T P↑tie↓ 2011↑bis↓ T', 'confidence': 0.76, 'orientation': 'horizontal-lr'}
# § Sassichy 61 T P↑tie↓ 2551 T {'text': '§ Sassichy 61 T P↑tie↓ 2551 T', 'confidence': 0.73, 'orientation': 'horizontal-lr'}
# § Bassier fils à Fontenay 15 T P↑tie↓ 2551↑bis↓ T {'text': '§ Bassier fils à Fontenay 15 T P↑tie↓ 2551↑bis↓ T', 'confidence': 0.81, 'orientation': 'horizontal-lr'}
# § Sassier fils 151 T P↑tie↓ 2551↑bis↓ T {'text': '§ Sassier fils 151 T P↑tie↓ 2551↑bis↓ T', 'confidence': 0.76, 'orientation': 'horizontal-lr'}
# § Saris arm 151 T P↑tie↓ 2201↑bis↓ T {'text': '§ Saris arm 151 T P↑tie↓ 2201↑bis↓ T', 'confidence': 0.76, 'orientation': 'horizontal-lr'}
# § Sassin 151 T P↑tie↓ 2211↑bis↓ T {'text': '§ Sassin 151 T P↑tie↓ 2211↑bis↓ T', 'confidence': 0.78, 'orientation': 'horizontal-lr'}
# § Sassin à Paris 151 T P↑tie↓ 2111↑bis↓ T {'text': '§ Sassin à Paris 151 T P↑tie↓ 2111↑bis↓ T', 'confidence': 0.79, 'orientation': 'horizontal-lr'}
# § Sardust Louis 151 T P↑tie↓ 2111↑bis↓ T {'text': '§ Sardust Louis 151 T P↑tie↓ 2111↑bis↓ T', 'confidence': 0.76, 'orientation': 'horizontal-lr'}
# § Sassier Antoine 151 T 15 T {'text': '§ Sassier Antoine 151 T 15 T', 'confidence': 0.73, 'orientation': 'horizontal-lr'}
# § Sassau françois 15 T P↑tie↓ 2551↑bis↓ T {'text': '§ Sassau françois 15 T P↑tie↓ 2551↑bis↓ T', 'confidence': 0.82, 'orientation': 'horizontal-lr'}
# § Sarille 151 T 1555 T {'text': '§ Sarille 151 T 1555 T', 'confidence': 0.67, 'orientation': 'horizontal-lr'}
# § Surier Br ouis 1513 T P↑tie↓ 2555↑bis↓ T {'text': '§ Surier Br ouis 1513 T P↑tie↓ 2555↑bis↓ T', 'confidence': 0.71, 'orientation': 'horizontal-lr'}
# f10c1378-c307-4b24-95f8-1c016610d4af
# 3662 5669
# La plaine 227 Moncouteau p↑re↓ toosar 196 Terre 162 T {'text': 'La plaine 227 Moncouteau p↑re↓ toosar 196 Terre 162 T', 'confidence': 0.96, 'orientation': 'horizontal-lr'}
# d 147 huard f↑ois↓ J↑h↓ 197 T 161 T {'text': 'd 147 huard f↑ois↓ J↑h↓ 197 T 161 T', 'confidence': 0.96, 'orientation': 'horizontal-lr'}
# § 267 Privière n↑as↓ michel 198 T 159 T {'text': '§ 267 Privière n↑as↓ michel 198 T 159 T', 'confidence': 1.0, 'orientation': 'horizontal-lr'}
# § 119 Plouguet J↑n↓ b↑te↓ 199 T 158 T {'text': '§ 119 Plouguet J↑n↓ b↑te↓ 199 T 158 T', 'confidence': 0.99, 'orientation': 'horizontal-lr'}
# § 35 Bleuze jacques 200 T 157→1586 T {'text': '§ 35 Bleuze jacques 200 T 157→1586 T', 'confidence': 0.99, 'orientation': 'horizontal-lr'}
# § 218 Mezy p↑re↓ Jean 201 T 156 T {'text': '§ 218 Mezy p↑re↓ Jean 201 T 156 T', 'confidence': 1.0, 'orientation': 'horizontal-lr'}
# § 35 Chevallier louis taytor 202 T 155 T {'text': '§ 35 Chevallier louis taytor 202 T 155 T', 'confidence': 0.94, 'orientation': 'horizontal-lr'}
# § 149 huard Joseph 203 T 152 T {'text': '§ 149 huard Joseph 203 T 152 T', 'confidence': 0.99, 'orientation': 'horizontal-lr'}
# § 66 Chapeltier J↑n↓ J↑n↓ 204 T 111→1117→1117↑bis↓ vig.→T {'text': '§ 66 Chapeltier J↑n↓ J↑n↓ 204 T 111→1117→1117↑bis↓ vig.→T', 'confidence': 0.95, 'orientation': 'horizontal-lr'}
# § 268 Diviere theodore 205 T 108→108 T→T {'text': '§ 268 Diviere theodore 205 T 108→108 T→T', 'confidence': 0.96, 'orientation': 'horizontal-lr'}
# § 263 Mannel ieu à loy 206 T 110 T {'text': '§ 263 Mannel ieu à loy 206 T 110 T', 'confidence': 0.89, 'orientation': 'horizontal-lr'}
# § 148 Pleuzy p↑re↓ Jeqne 207 T 113↑bis↓ T {'text': '§ 148 Pleuzy p↑re↓ Jeqne 207 T 113↑bis↓ T', 'confidence': 0.94, 'orientation': 'horizontal-lr'}
# § 32 Deurrier andré 208 T 113 T {'text': '§ 32 Deurrier andré 208 T 113 T', 'confidence': 0.99, 'orientation': 'horizontal-lr'}
# f937f814-1950-48e0-a095-bb61ee89b2f3
# 3668 5664
# La Voie 31 Beurrier pierre honoré 29 Terre 40→40→45→761 T→T→T {'text': 'La Voie 31 Beurrier pierre honoré 29 Terre 40→40→45→761 T→T→T', 'confidence': 0.97, 'orientation': 'horizontal-lr'}
# des postey 157 Joseph micolas V↑e↓ 30 T 41→42 T→T {'text': 'des postey 157 Joseph micolas V↑e↓ 30 T 41→42 T→T', 'confidence': 0.99, 'orientation': 'horizontal-lr'}
# § 306 Trotier joseph 31 T 42↑6↓ T {'text': '§ 306 Trotier joseph 31 T 42↑6↓ T', 'confidence': 0.97, 'orientation': 'horizontal-lr'}
# § 253 picard georges 32 T 146↑bis↓ T {'text': '§ 253 picard georges 32 T 146↑bis↓ T', 'confidence': 0.99, 'orientation': 'horizontal-lr'}
# § 20 Barriné J↑ques↓ victor 33 T 14 T {'text': '§ 20 Barriné J↑ques↓ victor 33 T 14 T', 'confidence': 0.98, 'orientation': 'horizontal-lr'}
# § 129 Godefroy denis ch↑es↓ 34 T 15 T {'text': '§ 129 Godefroy denis ch↑es↓ 34 T 15 T', 'confidence': 1.0, 'orientation': 'horizontal-lr'}
# § 106 Deu Jean V↑te↓ 35 T 16 T {'text': '§ 106 Deu Jean V↑te↓ 35 T 16 T', 'confidence': 0.96, 'orientation': 'horizontal-lr'}
# § 238 Micolas claude 36 T 166↑bis↓ T {'text': '§ 238 Micolas claude 36 T 166↑bis↓ T', 'confidence': 1.0, 'orientation': 'horizontal-lr'}
# § 201 Mainfray p↑re↓ ch↑es↓ 37 T 17p ☼ {'text': '§ 201 Mainfray p↑re↓ ch↑es↓ 37 T 17p ☼', 'confidence': 0.97, 'orientation': 'horizontal-lr'}
# § 106 Deu Jean b↑te↓ 38 T 17p T {'text': '§ 106 Deu Jean b↑te↓ 38 T 17p T', 'confidence': 0.99, 'orientation': 'horizontal-lr'}
# § 266 Pivière antoine 39 T 43→43→43 T→T {'text': '§ 266 Pivière antoine 39 T 43→43→43 T→T', 'confidence': 0.98, 'orientation': 'horizontal-lr'}
# § 201 Manfray ch↑es↓ pierre 40 T 18 T {'text': '§ 201 Manfray ch↑es↓ pierre 40 T 18 T', 'confidence': 1.0, 'orientation': 'horizontal-lr'}
# § 31 Beurrier pierre honoré 41 T 44 T {'text': '§ 31 Beurrier pierre honoré 41 T 44 T', 'confidence': 1.0, 'orientation': 'horizontal-lr'}
# § 150 huard paul f↑ois↓ 42 T 45 T {'text': '§ 150 huard paul f↑ois↓ 42 T 45 T', 'confidence': 0.99, 'orientation': 'horizontal-lr'}

# %%
UPDATE_INFERENCE_INFO = False

if UPDATE_INFERENCE_INFO:
    for json_path, page_uuid in PAGES[1:]:
        print(page_uuid)
        #Open the JSON containing DAN results
        with open(json_path, 'r') as file:
            data = json.load(file)

        elements = cli.request('ListElementChildren',
                   id=page_uuid,
                   type="tab_line_add",recursive=True,folder=False,page_size=500,page=1
                )

        #Update tab line add type
        for e in elements["results"]:
            update = cli.request('UpdateElement',id=e["id"],body={"type":"table_line_to_cor","name":e["name"]})
            
        update = cli.request('UpdateElement',id=page_uuid,body={"type":"page_add_to_cor","name":e["name"]})
# Out:
# 064cc4ee-9d5e-4922-a6dc-954aaf38fab2
# 0d2dbad9-68dd-4c66-a44d-87980720bc14
# 0dcdaeaf-a151-4496-9d68-9e30b63270f8
# 1f14549b-9b2e-4ee7-a3c4-c55b126db8af
# 26d52fc2-aafc-4e58-91f8-68bd6851ad37
# 2c59c9c6-5ed5-4fc1-85cd-4d162c324239
# 2e198618-c734-4d73-a67f-79fda49504f5
# 3435dedc-ddc0-4dfd-b834-d04148e44ddf
# 3ab13de2-f0b2-436f-9aa0-3b040e79975b
# 3e7683fb-6de4-4121-80b2-b1bae28bc950
# 484bd9b3-8084-4bd0-bec6-1bf0ab4907e5
# 5f985c84-34b8-4e56-b125-e2d454ade11f
# 683e7c3e-e537-44ba-8a02-3c4678d86b2f
# 6b08bf95-e3f5-423c-afa2-b088cc0ca11a
# 724852d2-464c-4364-a051-8a4505d6cbea
# 79ee0e05-59c0-4770-a20e-326574627577
# 7cc717f5-4612-45f0-8181-7e341e937880
# 8a6ef849-6266-415b-b9e7-b1604f3f41d4
# 8d60076b-985d-4374-acb8-c8f17db50d76
# 8de045eb-0069-4e8d-a519-df5f3c51e919
# 92fb30f9-6891-46e0-adb0-ad396a3ad2dc
# 9d6d69fc-cc55-4007-acbc-4ec375bec1b3
# 9e52f7f9-0e66-4753-bcf3-d3cb0916678c
# 9fde8f6c-f4bd-400c-9710-94f268917bf8
# a7067b75-0b1a-42ad-a01f-5bfe6ce8161e
# acb5c0fb-1901-405f-862e-f0726e867e7d
# ad913b91-539f-4645-bcde-69dee0c09bb3
# b38e1412-734c-423a-8abc-6758bff52e19
# b5e51a0b-23e8-4b63-a074-3ad00f40ecda
# b9996140-18ce-4374-8a66-01c4acdcbb2f
# ba86e3f2-7bb6-49a8-a2c2-0773e0a79626
# bd3d83f2-e9d7-4311-a9eb-c528f4501f27
# c8299489-3750-499c-a924-7f3365401c75
# d674fbbe-3b26-4e9d-8a6f-c8c8533d3123
# d7b0141b-7950-4d9b-a947-92728f613d8d
# d9678cb5-6ee1-4fda-9963-83108030d9b8
# eb4fc8e4-abb6-4b61-b3cc-3b244611e66f
# eb6486bb-623d-4ddf-a704-7cebf29e730c
# f10c1378-c307-4b24-95f8-1c016610d4af
# f937f814-1950-48e0-a095-bb61ee89b2f3
