# %% [markdown]
# # 10. Evaluation object type properties/property paths

# %%
import glob
import pandas as pd
import requests
from graphdbfunctions import *
from graph_evaluation import *
from great_tables import GT
import polars as pl

# %%
GRAPHDB_HOST = "http://localhost:7200"
GRAPHDB_REPO = 'lhay' # Your repository ID/Name
proxies = {
 "http": None,
 "https": None,
}

# %% [markdown]
# #### 0. All triples in triplestore (including blank nodes)

# %%
query_all_triples = prefixes + """
SELECT ?s ?p ?o
WHERE {GRAPH <GRAPH_URI> {
 # ?s ?p ?o .
}}
"""

# %%
gold_triples_all, pred_triples_all = get_triples(query_all_triples, "http://rdf.geohistoricaldata.org/gold", "http://rdf.geohistoricaldata.org/auto",GRAPHDB_HOST,GRAPHDB_REPO,proxies)

len(gold_triples_all), len(pred_triples_all)
# Out:
# (22521, 22202)

# %% [markdown]
# We can't use directly the triples for evaluation because of blank nodes in both grahs that might be the same but have differents URIs.
#
# So, the evaluation of relations (triples) is performed using property or property paths (*?s ?p ?o*) where *?s* and *?o* are not blank nodes.

# %% [markdown]
# ### 1. Retrieve relations

# %%
query = prefixes + """
SELECT ?s ?p ?o
WHERE {GRAPH <GRAPH_URI> {
 # ?s ?p ?o

 FILTER (!STRSTARTS(STR(?s), "_:"))  # Ensures the subject is not a blank node
 FILTER (!STRSTARTS(STR(?o), "_:"))  # Ensures the object is not a blank node
 FILTER (!isLiteral(?o))
 FILTER (!isLiteral(?s))
}}
"""

# %% [markdown]
# We first retrieve the simple triples (property path of length = 1) in both graphs (gold standard and automatically build).

# %%
gold_triples, pred_triples = get_triples(query, "http://rdf.geohistoricaldata.org/gold", "http://rdf.geohistoricaldata.org/auto",GRAPHDB_HOST,GRAPHDB_REPO,proxies)

# %%
print(f'Number of triples in gold : {len(gold_triples)}')
print(f'Number of triples in pred : {len(pred_triples)}')
# Out:
# Number of triples in gold : 10870
# Number of triples in pred : 10681

# %% [markdown]
# Then, we retrieve triples where ?p is a property path of length 2..n end ?s and ?o are not blank nodes. Property paths are listed bellow.

# %%
all__ = [
"cad:hasClasse/cad:hasClasseValue",
"addr:hasAttribute/rdf:type",
"addr:hasAttribute/addr:isAttributeType",
"addr:hasAttribute/addr:hasAttributeVersion/rdf:type",
"addr:hasAttribute/addr:hasAttributeVersion/cad:hasPlotAddress/addr:relatum",
"addr:hasAttribute/addr:hasAttributeVersion/cad:hasPlotAddress/addr:locatum",
"addr:hasAttribute/addr:hasAttributeVersion/cad:hasPlotNature",
"addr:hasAttribute/addr:hasAttributeVersion/cad:hasPlotTaxpayer",
"addr:hasTime/addr:timeCalendar",
"addr:hasTime/addr:timePrecision",
"addr:hasTime/addr:timeStamp",
"addr:hasTime/rdf:type",
"rico:hasCreationDate/rdf:type",
"rico:hasCreationDate/addr:timeStamp",
"rico:hasCreationDate/addr:timePrecision",
"rico:hasCreationDate/addr:timeStamp"
]

# %%
chained_properties = [
"cad:hasClasse/cad:hasClasseValue",
"addr:hasAttribute/rdf:type",
"addr:hasAttribute/addr:isAttributeType",
"addr:hasAttribute/addr:hasAttributeVersion/rdf:type",
"addr:hasAttribute/addr:hasAttributeVersion/cad:hasPlotAddress/addr:relatum",
"addr:hasAttribute/addr:hasAttributeVersion/cad:hasPlotAddress/addr:locatum",
"addr:hasAttribute/addr:hasAttributeVersion/cad:hasPlotNature",
"addr:hasAttribute/addr:hasAttributeVersion/cad:hasPlotTaxpayer",
"addr:hasTime/addr:timeCalendar",
"addr:hasTime/addr:timePrecision",
"addr:hasTime/rdf:type",
"rico:hasCreationDate/rdf:type",
"rico:hasCreationDate/addr:timePrecision",
"rico:hasCreationDate/addr:timeCalendar",
]

# %%
chained_query = prefixes + """
SELECT ?s ?p ?o
WHERE {
  GRAPH <GRAPH_URI> {
    # Retrieve all subjects that are of type Landmark
    # ?s PROP ?o.
    BIND("PROP" AS ?p )
    FILTER (!STRSTARTS(STR(?s), "_:"))  # Ensures the subject is not a blank node
    FILTER (!STRSTARTS(STR(?o), "_:"))  # Ensures the object is not a blank node
    FILTER (!isLiteral(?o))
    FILTER (!isLiteral(?s))
  }
}"""

# %%
ls_gold = []
ls_pred = []
for property_ in chained_properties:
  uquery = choose_property(property_, chained_query)
  df_gold, df_pred = get_triples(uquery, "http://rdf.geohistoricaldata.org/gold", "http://rdf.geohistoricaldata.org/auto",GRAPHDB_HOST,GRAPHDB_REPO,proxies)
  ls_gold.append(df_gold)
  ls_pred.append(df_pred)
  print(f"Number of triples in gold for {property_}: {len(df_gold)}")
  print(f"Number of triples in pred for {property_}: {len(df_pred)}")
# Out:
# Number of triples in gold for cad:hasClasse/cad:hasClasseValue: 30
# Number of triples in pred for cad:hasClasse/cad:hasClasseValue: 30
# Number of triples in gold for addr:hasAttribute/rdf:type: 1084
# Number of triples in pred for addr:hasAttribute/rdf:type: 1050
# Number of triples in gold for addr:hasAttribute/addr:isAttributeType: 1084
# Number of triples in pred for addr:hasAttribute/addr:isAttributeType: 1050
# Number of triples in gold for addr:hasAttribute/addr:hasAttributeVersion/rdf:type: 1084
# Number of triples in pred for addr:hasAttribute/addr:hasAttributeVersion/rdf:type: 1050
# Number of triples in gold for addr:hasAttribute/addr:hasAttributeVersion/cad:hasPlotAddress/addr:relatum: 362
# Number of triples in pred for addr:hasAttribute/addr:hasAttributeVersion/cad:hasPlotAddress/addr:relatum: 340
# Number of triples in gold for addr:hasAttribute/addr:hasAttributeVersion/cad:hasPlotAddress/addr:locatum: 362
# Number of triples in pred for addr:hasAttribute/addr:hasAttributeVersion/cad:hasPlotAddress/addr:locatum: 340
# Number of triples in gold for addr:hasAttribute/addr:hasAttributeVersion/cad:hasPlotNature: 360
# Number of triples in pred for addr:hasAttribute/addr:hasAttributeVersion/cad:hasPlotNature: 352
# Number of triples in gold for addr:hasAttribute/addr:hasAttributeVersion/cad:hasPlotTaxpayer: 362
# Number of triples in pred for addr:hasAttribute/addr:hasAttributeVersion/cad:hasPlotTaxpayer: 356
# Number of triples in gold for addr:hasTime/addr:timeCalendar: 2
# Number of triples in pred for addr:hasTime/addr:timeCalendar: 2
# Number of triples in gold for addr:hasTime/addr:timePrecision: 2
# Number of triples in pred for addr:hasTime/addr:timePrecision: 2
# Number of triples in gold for addr:hasTime/rdf:type: 2
# Number of triples in pred for addr:hasTime/rdf:type: 2
# Number of triples in gold for rico:hasCreationDate/rdf:type: 1
# Number of triples in pred for rico:hasCreationDate/rdf:type: 1
# Number of triples in gold for rico:hasCreationDate/addr:timePrecision: 1
# Number of triples in pred for rico:hasCreationDate/addr:timePrecision: 1
# Number of triples in gold for rico:hasCreationDate/addr:timeCalendar: 1
# Number of triples in pred for rico:hasCreationDate/addr:timeCalendar: 1

# %%
#concatenate all dataframes in the list into a single dataframe
gold_ppath_df = pd.concat(ls_gold, ignore_index=True)
pred_ppath_df = pd.concat(ls_pred, ignore_index=True)

# %%
gold = pd.concat([gold_triples, gold_ppath_df], ignore_index=True)
pred = pd.concat([pred_triples, pred_ppath_df], ignore_index=True)
len(gold), len(pred)
# Out:
# (15607, 15258)

# %%
from namespaces import prefixes_dict
#Using prefixes_dict, replace strings in the type column
for c in ["s","p","o"]:
    for prefix, uri in prefixes_dict.items():
        gold[c] = gold[c].str.replace(prefix, uri, regex=False)
        pred[c] = pred[c].str.replace(prefix, uri, regex=False)

# %%
SAVE_FILES = False

gold_in_pred, gold_not_in_pred, pred_in_gold, pred_not_in_gold = compare_dfs(gold, pred)

if SAVE_FILES:
    gold.to_csv("gold.csv", index=False)
    pred.to_csv("pred.csv", index=False)
    gold_in_pred.to_csv("non_identical_gold.csv", index=False)
    pred_in_gold.to_csv("non_identical_pred.csv", index=False)

# %% [markdown]
# ### 2. Metrics

# %% [markdown]
# The **agreement rate** for relation R is defined as the ratio between: the number of GOLD pairs that can be matched with a pair of PREDITED pairs, and the total number of GOLD pairs.
# Note:
# Matching a pair means that each of the two fields in the pair can be matched with its counterpart in an EJD pair.

# %% [markdown]
# The **deficit rate** is the ratio of the number of GOLD pairs that are not found in PREDICTED set to the total number of GOLD pairs.

# %% [markdown]
# The **surplus rate** is the ratio of the number of PREDICTED pairs that are not found in GOLD to the total number of PREDICTED pairs.

# %% [markdown]
# The **precision** is the ratio of correctly predicted positive observations to the total predicted positives. It indicates how many of the predicted triples are actually correct.

# %%
metrics_all = compute_metrics(gold,pred)
metrics_all
# Out:
# {'Agreement': 78.5, 'Deficit': 21.5, 'Surplus': 19.939999999999998}

# %%
gold
# Out:
#                                                        s  \
# 0      source:064cc4ee-9d5e-4922-a6dc-954aaf38fab2_FR...
# 1                  source:FRAD094_3P_000275_01_0151_page
# 2                            source:FRAD094_3P_000275_01
# 3      source:0d2dbad9-68dd-4c66-a44d-87980720bc14_FR...
# 4                  source:FRAD094_3P_000275_01_0160_page
# ...                                                  ...
# 15602             source:94_LHAY_RECTIFICATION_1835_1842
# 15603                           event:CADASTRE_LHAY_1842
# 15604             source:94_LHAY_RECTIFICATION_1835_1842
# 15605             source:94_LHAY_RECTIFICATION_1835_1842
# 15606             source:94_LHAY_RECTIFICATION_1835_1842
#
#                                              p                      o
# 0                                     rdf:type     rico:Instantiation
# 1                                     rdf:type            rico:Record
# 2                                     rdf:type     rico:Instantiation
# 3                                     rdf:type     rico:Instantiation
# 4                                     rdf:type            rico:Record
# ...                                        ...                    ...
# 15602                    addr:hasTime/rdf:type  addr:CrispTimeInstant
# 15603                    addr:hasTime/rdf:type  addr:CrispTimeInstant
# 15604            rico:hasCreationDate/rdf:type  addr:CrispTimeInstant
# 15605  rico:hasCreationDate/addr:timePrecision              time:Year
# 15606   rico:hasCreationDate/addr:timeCalendar         time:Gregorian
#
# [15607 rows x 3 columns]

# %% [markdown]
# ### 3. Evaluation for each property or property path

# %% [markdown]
# #### Count

# %%
# Get counts for gold and pred
gold_df = get_property_values_count_df(gold,'p')
pred_df = get_property_values_count_df(pred,'p')

# %%
# Merge the two DataFrames on the 'Property' column : Property Count_gold, Count_pred
df = pd.merge(gold_df, pred_df, on='p', how='outer')
df.fillna(0, inplace=True)
#Compmpute the difference (abs)
df['Difference'] = abs(df['Count_x'] - df['Count_y'])
#Sort by difference
df.sort_values(by='Difference', ascending=False, inplace=True)
display(df)
# Out:
#                                                     p  Count_x  Count_y  \
# 1                                      addr:dependsOn     1446     1407
# 13                                  addr:isChangeType     1446     1407
# 6   addr:hasAttribute/addr:hasAttributeVersion/rdf...     1084     1050
# 7              addr:hasAttribute/addr:isAttributeType     1084     1050
# 8                          addr:hasAttribute/rdf:type     1084     1050
# 21                                    cad:sourcedFrom     1086     1053
# 3   addr:hasAttribute/addr:hasAttributeVersion/cad...      362      340
# 2   addr:hasAttribute/addr:hasAttributeVersion/cad...      362      340
# 22                                           rdf:type     3121     3100
# 16                                       addr:locatum      728      712
# 17                                       addr:relatum      728      712
# 14                        addr:isLandmarkRelationType      728      712
# 4   addr:hasAttribute/addr:hasAttributeVersion/cad...      360      352
# 15                                addr:isLandmarkType      367      373
# 5   addr:hasAttribute/addr:hasAttributeVersion/cad...      362      356
# 0                                      addr:appliedTo      362      357
# 20                                   cad:isSourceType      397      392
# 27                              rico:isOrWasComponent      362      357
# 10                    addr:hasTime/addr:timePrecision        2        2
# 11                              addr:hasTime/rdf:type        2        2
# 12                                      addr:hasTrace        1        1
# 9                      addr:hasTime/addr:timeCalendar        2        2
# 19                                    cad:isEventType        1        1
# 23             rico:hasCreationDate/addr:timeCalendar        1        1
# 18                   cad:hasClasse/cad:hasClasseValue       30       30
# 24            rico:hasCreationDate/addr:timePrecision        1        1
# 25                      rico:hasCreationDate/rdf:type        1        1
# 26                  rico:hasOrHadDerivedInstantiation        1        1
# 28                            rico:isOrWasComponentOf       32       32
# 29                 rico:isOrWasDigitalInstantiationOf       31       31
# 30                             rico:isOrWasIncludedIn       31       31
# 31                          rico:isOrWasInstantiation        1        1
# 32                        rico:isOrWasInstantiationOf        1        1
#
#     Difference
# 1           39
# 13          39
# 6           34
# 7           34
# 8           34
# 21          33
# 3           22
# 2           22
# 22          21
# 16          16
# 17          16
# 14          16
# 4            8
# 15           6
# 5            6
# 0            5
# 20           5
# 27           5
# 10           0
# 11           0
# 12           0
# 9            0
# 19           0
# 23           0
# 18           0
# 24           0
# 25           0
# 26           0
# 28           0
# 29           0
# 30           0
# 31           0
# 32           0

# %%
properties = get_list_of_properties(df,'p')
properties
# Out:
# ['addr:dependsOn',
#  'addr:isChangeType',
#  'addr:hasAttribute/addr:hasAttributeVersion/rdf:type',
#  'addr:hasAttribute/addr:isAttributeType',
#  'addr:hasAttribute/rdf:type',
#  'cad:sourcedFrom',
#  'addr:hasAttribute/addr:hasAttributeVersion/cad:hasPlotAddress/addr:relatum',
#  'addr:hasAttribute/addr:hasAttributeVersion/cad:hasPlotAddress/addr:locatum',
#  'rdf:type',
#  'addr:locatum',
#  'addr:relatum',
#  'addr:isLandmarkRelationType',
#  'addr:hasAttribute/addr:hasAttributeVersion/cad:hasPlotNature',
#  'addr:isLandmarkType',
#  'addr:hasAttribute/addr:hasAttributeVersion/cad:hasPlotTaxpayer',
#  'addr:appliedTo',
#  'cad:isSourceType',
#  'rico:isOrWasComponent',
#  'addr:hasTime/addr:timePrecision',
#  'addr:hasTime/rdf:type',
#  'addr:hasTrace',
#  'addr:hasTime/addr:timeCalendar',
#  'cad:isEventType',
#  'rico:hasCreationDate/addr:timeCalendar',
#  'cad:hasClasse/cad:hasClasseValue',
#  'rico:hasCreationDate/addr:timePrecision',
#  'rico:hasCreationDate/rdf:type',
#  'rico:hasOrHadDerivedInstantiation',
#  'rico:isOrWasComponentOf',
#  'rico:isOrWasDigitalInstantiationOf',
#  'rico:isOrWasIncludedIn',
#  'rico:isOrWasInstantiation',
#  'rico:isOrWasInstantiationOf']

# %%
from great_tables import GT
import polars as pl

metrics_by_properties = []
for p in properties:
    # Get the instances of the property in gold and pred
    gold_instances = get_property_instances(gold, 'p', p)
    pred_instances = get_property_instances(pred, 'p', p)
    
    # Compute
    metrics = compute_metrics(gold_instances, pred_instances)
    metrics_by_properties.append({
        "Property": p,
        "Agreement": metrics["Agreement"],
        "Deficit": metrics["Deficit"],
        "Surplus": metrics["Surplus"],
    })
# Create a DataFrame from the metrics
metrics_df = pd.DataFrame(metrics_by_properties)

# %%
metrics_df
# Out:
#                                              Property  Agreement  Deficit  \
# 0                                      addr:dependsOn      93.91     6.09
# 1                                   addr:isChangeType      93.91     6.09
# 2   addr:hasAttribute/addr:hasAttributeVersion/rdf...      95.20     4.80
# 3              addr:hasAttribute/addr:isAttributeType      93.54     6.46
# 4                          addr:hasAttribute/rdf:type      95.20     4.80
# 5                                     cad:sourcedFrom      46.22    53.78
# 6   addr:hasAttribute/addr:hasAttributeVersion/cad...       0.00   100.00
# 7   addr:hasAttribute/addr:hasAttributeVersion/cad...      90.61     9.39
# 8                                            rdf:type      81.74    18.26
# 9                                        addr:locatum      47.39    52.61
# 10                                       addr:relatum      47.39    52.61
# 11                        addr:isLandmarkRelationType      47.39    52.61
# 12  addr:hasAttribute/addr:hasAttributeVersion/cad...      92.22     7.78
# 13                                addr:isLandmarkType      94.28     5.72
# 14  addr:hasAttribute/addr:hasAttributeVersion/cad...      43.65    56.35
# 15                                     addr:appliedTo      95.03     4.97
# 16                                   cad:isSourceType      95.47     4.53
# 17                              rico:isOrWasComponent      95.03     4.97
# 18                    addr:hasTime/addr:timePrecision     100.00     0.00
# 19                              addr:hasTime/rdf:type     100.00     0.00
# 20                                      addr:hasTrace     100.00     0.00
# 21                     addr:hasTime/addr:timeCalendar     100.00     0.00
# 22                                    cad:isEventType     100.00     0.00
# 23             rico:hasCreationDate/addr:timeCalendar     100.00     0.00
# 24                   cad:hasClasse/cad:hasClasseValue     100.00     0.00
# 25            rico:hasCreationDate/addr:timePrecision     100.00     0.00
# 26                      rico:hasCreationDate/rdf:type     100.00     0.00
# 27                  rico:hasOrHadDerivedInstantiation     100.00     0.00
# 28                            rico:isOrWasComponentOf     100.00     0.00
# 29                 rico:isOrWasDigitalInstantiationOf     100.00     0.00
# 30                             rico:isOrWasIncludedIn     100.00     0.00
# 31                          rico:isOrWasInstantiation     100.00     0.00
# 32                        rico:isOrWasInstantiationOf     100.00     0.00
#
#     Surplus
# 0      3.48
# 1      3.48
# 2      3.43
# 3      3.43
# 4      3.43
# 5     52.33
# 6    100.00
# 7      3.53
# 8     17.71
# 9     51.54
# 10    51.54
# 11    51.54
# 12     5.68
# 13     7.24
# 14    55.62
# 15     3.64
# 16     3.32
# 17     3.64
# 18     0.00
# 19     0.00
# 20     0.00
# 21     0.00
# 22     0.00
# 23     0.00
# 24     0.00
# 25     0.00
# 26     0.00
# 27     0.00
# 28     0.00
# 29     0.00
# 30     0.00
# 31     0.00
# 32     0.00

# %%
#Nice display
GT(metrics_df) \
    .data_color(columns=["Agreement"],#, "Precision", "Recall", "F1 score"
                palette=["red", "orange", "green"], domain=[0, 100]) \
    .data_color(columns=["Deficit", "Surplus"],
                palette=["green", "orange", "red"], domain=[0, 100])
# Out:
# GT(_tbl_data=                                             Property  Agreement  Deficit  \
# 0                                      addr:dependsOn      93.91     6.09
# 1                                   addr:isChangeType      93.91     6.09
# 2   addr:hasAttribute/addr:hasAttributeVersion/rdf...      95.20     4.80
# 3              addr:hasAttribute/addr:isAttributeType      93.54     6.46
# 4                          addr:hasAttribute/rdf:type      95.20     4.80
# 5                                     cad:sourcedFrom      46.22    53.78
# 6   addr:hasAttribute/addr:hasAttributeVersion/cad...       0.00   100.00
# 7   addr:hasAttribute/addr:hasAttributeVersion/cad...      90.61     9.39
# 8                                            rdf:type      81.74    18.26
# 9                                        addr:locatum      47.39    52.61
# 10                                       addr:relatum      47.39    52.61
# 11                        addr:isLandmarkRelationType      47.39    52.61
# 12  addr:hasAttribute/addr:hasAttributeVersion/cad...      92.22     7.78
# 13                                addr:isLandmarkType      94.28     5.72
# 14  addr:hasAttribute/addr:hasAttributeVersion/cad...      43.65    56.35
# 15                                     addr:appliedTo      95.03     4.97
# 16                                   cad:isSourceType      95.47     4.53
# 17                              rico:isOrWasComponent      95.03     4.97
# 18                    addr:hasTime/addr:timePrecision     100.00     0.00
# 19                              addr:hasTime/rdf:type     100.00     0.00
# 20                                      addr:hasTrace     100.00     0.00
# 21                     addr:hasTime/addr:timeCalendar     100.00     0.00
# 22                                    cad:isEventType     100.00     0.00
# 23             rico:hasCreationDate/addr:timeCalendar     100.00     0.00
# 24                   cad:hasClasse/cad:hasClasseValue     100.00     0.00
# 25            rico:hasCreationDate/addr:timePrecision     100.00     0.00
# 26                      rico:hasCreationDate/rdf:type     100.00     0.00
# 27                  rico:hasOrHadDerivedInstantiation     100.00     0.00
# 28                            rico:isOrWasComponentOf     100.00     0.00
# 29                 rico:isOrWasDigitalInstantiationOf     100.00     0.00
# 30                             rico:isOrWasIncludedIn     100.00     0.00
# 31                          rico:isOrWasInstantiation     100.00     0.00
# 32                        rico:isOrWasInstantiationOf     100.00     0.00
#
#     Surplus
# 0      3.48
# 1      3.48
# 2      3.43
# 3      3.43
# 4      3.43
# 5     52.33
# 6    100.00
# 7      3.53
# 8     17.71
# 9     51.54
# 10    51.54
# 11    51.54
# 12     5.68
# 13     7.24
# 14    55.62
# 15     3.64
# 16     3.32
# 17     3.64
# 18     0.00
# 19     0.00
# 20     0.00
# 21     0.00
# 22     0.00
# 23     0.00
# 24     0.00
# 25     0.00
# 26     0.00
# 27     0.00
# 28     0.00
# 29     0.00
# 30     0.00
# 31     0.00
# 32     0.00  , _body=<great_tables._gt_data.Body object at 0x0000015C4749C2B0>, _boxhead=Boxhead([ColInfo(var='Property', type=<ColInfoTypeEnum.default: 1>, column_label='Property', column_align='left', column_width=None), ColInfo(var='Agreement', type=<ColInfoTypeEnum.default: 1>, column_label='Agreement', column_align='right', column_width=None), ColInfo(var='Deficit', type=<ColInfoTypeEnum.default: 1>, column_label='Deficit', column_align='right', column_width=None), ColInfo(var='Surplus', type=<ColInfoTypeEnum.default: 1>, column_label='Surplus', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000015C4749CA90>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname=LocBody(columns='Agreement', rows=[0], mask=None), grpname=None, colname='Agreement', rownum=0, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#1f8500')]), StyleInfo(locname=LocBody(columns='Agreement', rows=[1], mask=None), grpname=None, colname='Agreement', rownum=1, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#1f8500')]), StyleInfo(locname=LocBody(columns='Agreement', rows=[2], mask=None), grpname=None, colname='Agreement', rownum=2, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#188400')]), StyleInfo(locname=LocBody(columns='Agreement', rows=[3], mask=None), grpname=None, colname='Agreement', rownum=3, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#218500')]), StyleInfo(locname=LocBody(columns='Agreement', rows=[4], mask=None), grpname=None, colname='Agreement', rownum=4, colnum=None, styles=[CellStyleText(color='#FFFFFF', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#188400')]), StyleInfo(locname=LocBody(columns='Agreement', rows=[5], mask=None), grpname=None, colname='Agreement', rownum=5, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#ff9900')]), StyleInfo(locname=LocBody(columns='Agreement', rows=[6], mask=None), grpname=None, colname='Agreement', rownum=6, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#ff0000')]), StyleInfo(locname=LocBody(columns='Agreement', rows=[7], mask=None), grpname=None, colname='Agreement', rownum=7, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#308700')]), StyleInfo(locname=LocBody(columns='Agreement', rows=[8], mask=None), grpname=None, colname='Agreement', rownum=8, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#5d8e00')]), StyleInfo(locname=LocBody(columns='Agreement', rows=[9], mask=None), grpname=None, colname='Agreement', rownum=9, colnum=None, styles=[CellStyleText(color='#000000', f ...

# %%
df_to_latex(metrics_df)
# Out:
# \begin{tabular}{lrrr}
# \toprule
# Property & Agreement & Deficit & Surplus \\
# \midrule
# rico:hasCreationDate/addr:timePrecision & 100.000000 & 0.000000 & 0.000000 \\
# addr:hasTime/addr:timeCalendar & 100.000000 & 0.000000 & 0.000000 \\
# rico:isOrWasInstantiationOf & 100.000000 & 0.000000 & 0.000000 \\
# rico:isOrWasIncludedIn & 100.000000 & 0.000000 & 0.000000 \\
# rico:isOrWasInstantiation & 100.000000 & 0.000000 & 0.000000 \\
# rico:isOrWasComponentOf & 100.000000 & 0.000000 & 0.000000 \\
# rico:hasOrHadDerivedInstantiation & 100.000000 & 0.000000 & 0.000000 \\
# rico:hasCreationDate/rdf:type & 100.000000 & 0.000000 & 0.000000 \\
# rico:isOrWasDigitalInstantiationOf & 100.000000 & 0.000000 & 0.000000 \\
# addr:hasTime/rdf:type & 100.000000 & 0.000000 & 0.000000 \\
# cad:hasClasse/cad:hasClasseValue & 100.000000 & 0.000000 & 0.000000 \\
# cad:isEventType & 100.000000 & 0.000000 & 0.000000 \\
# rico:hasCreationDate/addr:timeCalendar & 100.000000 & 0.000000 & 0.000000 \\
# addr:hasTime/addr:timePrecision & 100.000000 & 0.000000 & 0.000000 \\
# addr:hasTrace & 100.000000 & 0.000000 & 0.000000 \\
# cad:isSourceType & 95.470000 & 4.530000 & 3.320000 \\
# addr:hasAttribute/addr:hasAttributeVersion/rdf:type & 95.200000 & 4.800000 & 3.430000 \\
# addr:hasAttribute/rdf:type & 95.200000 & 4.800000 & 3.430000 \\
# addr:appliedTo & 95.030000 & 4.970000 & 3.640000 \\
# rico:isOrWasComponent & 95.030000 & 4.970000 & 3.640000 \\
# addr:isLandmarkType & 94.280000 & 5.720000 & 7.240000 \\
# addr:dependsOn & 93.910000 & 6.090000 & 3.480000 \\
# addr:isChangeType & 93.910000 & 6.090000 & 3.480000 \\
# addr:hasAttribute/addr:isAttributeType & 93.540000 & 6.460000 & 3.430000 \\
# addr:hasAttribute/addr:hasAttributeVersion/cad:hasPlotNature & 92.220000 & 7.780000 & 5.680000 \\
# addr:hasAttribute/addr:hasAttributeVersion/cad:hasPlotAddress/addr:locatum & 90.610000 & 9.390000 & 3.530000 \\
# rdf:type & 81.740000 & 18.260000 & 17.710000 \\
# addr:relatum & 47.390000 & 52.610000 & 51.540000 \\
# addr:isLandmarkRelationType & 47.390000 & 52.610000 & 51.540000 \\
# addr:locatum & 47.390000 & 52.610000 & 51.540000 \\
# cad:sourcedFrom & 46.220000 & 53.780000 & 52.330000 \\
# addr:hasAttribute/addr:hasAttributeVersion/cad:hasPlotTaxpayer & 43.650000 & 56.350000 & 55.620000 \\
# addr:hasAttribute/addr:hasAttributeVersion/cad:hasPlotAddress/addr:relatum & 0.000000 & 100.000000 & 100.000000 \\
# \bottomrule
# \end{tabular}
# '\\begin{tabular}{lrrr}\n\\toprule\nProperty & Agreement & Deficit & Surplus \\\\\n\\midrule\nrico:hasCreationDate/addr:timePrecision & 100.000000 & 0.000000 & 0.000000 \\\\\naddr:hasTime/addr:timeCalendar & 100.000000 & 0.000000 & 0.000000 \\\\\nrico:isOrWasInstantiationOf & 100.000000 & 0.000000 & 0.000000 \\\\\nrico:isOrWasIncludedIn & 100.000000 & 0.000000 & 0.000000 \\\\\nrico:isOrWasInstantiation & 100.000000 & 0.000000 & 0.000000 \\\\\nrico:isOrWasComponentOf & 100.000000 & 0.000000 & 0.000000 \\\\\nrico:hasOrHadDerivedInstantiation & 100.000000 & 0.000000 & 0.000000 \\\\\nrico:hasCreationDate/rdf:type & 100.000000 & 0.000000 & 0.000000 \\\\\nrico:isOrWasDigitalInstantiationOf & 100.000000 & 0.000000 & 0.000000 \\\\\naddr:hasTime/rdf:type & 100.000000 & 0.000000 & 0.000000 \\\\\ncad:hasClasse/cad:hasClasseValue & 100.000000 & 0.000000 & 0.000000 \\\\\ncad:isEventType & 100.000000 & 0.000000 & 0.000000 \\\\\nrico:hasCreationDate/addr:timeCalendar & 100.000000 & 0.000000 & 0.000000 \\\\\naddr:hasTime/addr:timePrecision & 100.000000 & 0.000000 & 0.000000 \\\\\naddr:hasTrace & 100.000000 & 0.000000 & 0.000000 \\\\\ncad:isSourceType & 95.470000 & 4.530000 & 3.320000 \\\\\naddr:hasAttribute/addr:hasAttributeVersion/rdf:type & 95.200000 & 4.800000 & 3.430000 \\\\\naddr:hasAttribute/rdf:type & 95.200000 & 4.800000 & 3.430000 \\\\\naddr:appliedTo & 95.030000 & 4.970000 & 3.640000 \\\\\nrico:isOrWasComponent & 95.030000 & 4.970000 & 3.640000 \\\\\naddr:isLandmarkType & 94.280000 & 5.720000 & 7.240000 \\\\\naddr:dependsOn & 93.910000 & 6.090000 & 3.480000 \\\\\naddr:isChangeType & 93.910000 & 6.090000 & 3.480000 \\\\\naddr:hasAttribute/addr:isAttributeType & 93.540000 & 6.460000 & 3.430000 \\\\\naddr:hasAttribute/addr:hasAttributeVersion/cad:hasPlotNature & 92.220000 & 7.780000 & 5.680000 \\\\\naddr:hasAttribute/addr:hasAttributeVersion/cad:hasPlotAddress/addr:locatum & 90.610000 & 9.390000 & 3.530000 \\\\\nrdf:type & 81.740000 & 18.260000 & 17.710000 \\\\\naddr:relatum & 47.390000 & 52.610000 & 51.540000 \\\\\naddr:isLandmarkRelationType & 47.390000 & 52.610000 & 51.540000 \\\\\naddr:locatum & 47.390000 & 52.610000 & 51.540000 \\\\\ncad:sourcedFrom & 46.220000 & 53.780000 & 52.330000 \\\\\naddr:hasAttribute/addr:hasAttributeVersion/cad:hasPlotTaxpayer & 43.650000 & 56.350000 & 55.620000 \\\\\naddr:hasAttribute/addr:hasAttributeVersion/cad:hasPlotAddress/addr:relatum & 0.000000 & 100.000000 & 100.000000 \\\\\n\\bottomrule\n\\end{tabular}\n'
