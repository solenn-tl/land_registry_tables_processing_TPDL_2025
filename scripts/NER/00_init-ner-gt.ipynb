# %% [markdown]
# # 00 - Initialize NER/Span segmentation ground-truth using a LLM
#
# The aim of this notebook is to quickly initialise a ground-truth to further train a NER model without annotating the data by hand from scratch. The initial annotationis performed with a LLM (using Ollama). After a manual post-correction step, the annotations can be used to create a dataset to fine-tune Camembert-NER model (stored in Hugging-Face).
#
# **You can skip this notebook. Download the NER data applied to taxpayers on [Zenodo](https://zenodo.org/10.5281/zenodo.15423885)**

# %% [markdown]
# Some informations about the named entities :
# * Name (person name or company)
# * Firstnames
# * Address
# * Activity
# * Title
# * Family status

# %%
import pandas as pd
from ollama import chat
from pydantic import BaseModel
import time
import json
import regex

# %%
from formats import Taxpayer, TaxpayersList

# %%
ROOT = "/home/STual/DAN-cadastre"

# %% [markdown]
# ## 1. Load the data

# %%
#Import entities
ENTITIES_CSV = ROOT + "/data/NER/entities.csv" #Available on Zenodo
df = pd.read_csv(ENTITIES_CSV)
display(df)
# Out:
#                               element_uuid             address plot_number  \
# 0     33278fbe-9845-49a9-9fc0-00faf13c0484    Port à l'anglais          95
# 1     58dfd0f9-62e9-4f95-b17d-922f3ce150d2                   §           §
# 2     c648b66a-1cd1-4a66-9b48-10429ea2f08d                   §           §
# 3     93b4fad5-d5dd-4763-a56d-a35fc089c11d                   §           §
# 4     b3ad0224-1d5a-42b1-a41d-13531c23907b                   §           §
# ...                                    ...                 ...         ...
# 3221  97b9d7aa-e38b-4032-b263-2ac2433bb850                   §         307
# 3222  0829167d-6ff5-4ecd-bfd5-a30b7c40b2aa                   §         308
# 3223  5698c83e-8192-48f4-8542-7613edd5d528       le petit parc     16↑bis↓
# 3224  4b02c685-a8a2-4547-8002-09a8c6ac4fd4  le bois des champs          17
# 3225  8f78e779-92e1-4d19-893e-eaf5f81402fe                  id          18
#
#                                     taxpayer taxpayer_number  \
# 0                             Charte Etienne             NaN
# 1                    Crispin désiré augustin             NaN
# 2                 chichérit françois auguste             NaN
# 3                    C↑ie↓ parisienne du gaz             NaN
# 4     Coquette léon et Coquette Louis→alfred             NaN
# ...                                      ...             ...
# 3221                                    idem             167
# 3222                                    idem             107
# 3223                Pierlot banquier à Paris             NaN
# 3224             Delamare Mathurin Bourgeois             NaN
# 3225          Delauge Bourgeois à Petit-Brie             NaN
#
#                    nature former_plot_number former_nature
# 0                   terre                NaN           NaN
# 1                       §                NaN           NaN
# 2                       §                NaN           NaN
# 3                       §                NaN           NaN
# 4                       §                NaN           NaN
# ...                   ...                ...           ...
# 3221  maison b↑t↓→et cour               220p             Ø
# 3222               maison               220p             Ø
# 3223          Gazon d'agt                NaN           NaN
# 3224                 Bois                NaN           NaN
# 3225                 Bois                NaN           NaN
#
# [3226 rows x 8 columns]

# %% [markdown]
# ### 1.1 Filter the Taxpayer column

# %%
# Remove the value which don't describe a taxpayer
taxpayers_df = df[df['taxpayer'] != '§']
taxpayers_df = taxpayers_df[taxpayers_df['taxpayer'] != 'id']
taxpayers_df = taxpayers_df[taxpayers_df['taxpayer'] != 'idem']

## The following values have been treated by hand :( (should be uncomment in case of a new run)
#taxpayers_df = taxpayers_df[taxpayers_df['taxpayer'] != 'Id']
#taxpayers_df = taxpayers_df[taxpayers_df['taxpayer'] != 'Idem']
#taxpayers_df = taxpayers_df[taxpayers_df['taxpayer'] != 'Le même']
#taxpayers_df = taxpayers_df[taxpayers_df['taxpayer'] != 'Les mêmes']
#taxpayers_df = taxpayers_df[taxpayers_df['taxpayer'] != '\']

# %%
len(taxpayers_df)
# Out:
# 2843

# %% [markdown]
# ### 1.2 Set LLM parameters and prompt

# %%
# Roles
USER = 'user' #you
ASSISTANT = 'assistant' #the LLM
MODEL = "llama3.1"

# %%
EXAMPLES_LIST = [["Prudhomme",Taxpayer(name="Prudhomme")],
                ["Société anonyme du Comptoir Central de l'Est",Taxpayer(name="Société anonyme du Comptoir Central de l'Est")],
                ["Germay à Paris",Taxpayer(name="Germay", address=["Paris"])],
                ["Barbaroux quincailler à Paris",Taxpayer(name="Barbaroux",activity=["quincailler"],address=["Paris"])],
                ["Costy, Jn Bte Tailleur de Pierre à Villeneuve Leroy",Taxpayer(name="Costy", firstnames="Jn Bte",activity=["Tailleur de Pierre"],address=["Villeneuve Leroy"])],
                ["Besnet Joseph, Henri - 6/8 Rue Camille Desmoulins 19 Rue Guichard", Taxpayer(name="Besnet", firstnames="Joseph, Henri", address=["6/8 Rue Camille Desmoulins", "19 Rue Guichard"])],
                ["Tellier Catherine fille majeure à Ablon", Taxpayer(name="Tellier", firstnames="Catherine", familystatus=["fille majeure"], address=["Ablon"])],
                ["Pravel Louis Ve né Gerbuisson",Taxpayer(name="Pravel",firstnames="Louis",familystatus=["Ve"],birthname="Gerbuisson")],
                ["Commune d'Ablon",Taxpayer(name="Commune d'Ablon")]
]

# %%
PROMPT_CONTEXT = """You are a senior researcher specialized in digital humanities and linguistic. 
Your goal is to structure short texts describing taxpayers extracted from 19th century registers. More precisly, you have to create spans of these texts which are categorized as named entities described bellow.

### Entities

- **name**: The last name of a person or the name of a company.
- **firstnames**: One or more first names of the individual.
- **address**: An address or any other spatial entity associated with the individual.
- **activity"**: The profession, occupation, or work associated with the individual.
- **title**: Title of the individual such as 'M', 'Mme', 'Mademoiselle', 'Monseigneur', 'General', or 'Prince'.
- **familystatus**: Mentions of family or marital status of the individual such as 'Père', 'Veuve', 'Fille', 'Fils', or 'Héritier'.
- **birthname** : Name of an individual (in most of this case a woman) before its wedding

## Task description (hard constraints)
1. You can have one (more rarely 2 or 3) taxpayers described in a text.
2. You have to preserve original text strings and case.
3. The outputs have to be structure has the json described in the examples. 
4. If an entity type is not present in the input, it should be represented with an empty string (`''`) for singular entities or an empty list (`[]`) for plural entities.

### Examples:
Here are examples of inputs and outputs:
"""

# %%
PROMPT_EXAMPLES = ""
for elem in EXAMPLES_LIST:
    PROMPT_EXAMPLES += "\n**Input:** " + elem[0] + ""
    PROMPT_EXAMPLES += "\n**Output:** " + str(elem[1].model_dump())+"\n"

FULL_PROMPT = PROMPT_CONTEXT + PROMPT_EXAMPLES + "Please provide the response in the form of a list of JSON structured as in the example. It should begin with [ and end with ]."
print(FULL_PROMPT)
# Out:
# You are a senior researcher specialized in digital humanities and linguistic.
# Your goal is to structure short texts describing taxpayers extracted from 19th century registers. More precisly, you have to create spans of these texts which are categorized as named entities described bellow.
#
# ### Entities
#
# - **name**: The last name of a person or the name of a company.
# - **firstnames**: One or more first names of the individual.
# - **address**: An address or any other spatial entity associated with the individual.
# - **activity"**: The profession, occupation, or work associated with the individual.
# - **title**: Title of the individual such as 'M', 'Mme', 'Mademoiselle', 'Monseigneur', 'General', or 'Prince'.
# - **familystatus**: Mentions of family or marital status of the individual such as 'Père', 'Veuve', 'Fille', 'Fils', or 'Héritier'.
# - **birthname** : Name of an individual (in most of this case a woman) before its wedding
#
# ## Task description (hard constraints)
# 1. You can have one (more rarely 2 or 3) taxpayers described in a text.
# 2. You have to preserve original text strings and case.
# 3. The outputs have to be structure has the json described in the examples.
# 4. If an entity type is not present in the input, it should be represented with an empty string (`''`) for singular entities or an empty list (`[]`) for plural entities.
#
# ### Examples:
# Here are examples of inputs and outputs:
#
# **Input:** Prudhomme
# **Output:** {'name': 'Prudhomme', 'firstnames': '', 'activity': [], 'address': [], 'title': [], 'familystatus': [], 'birthname': ''}
#
# **Input:** Société anonyme du Comptoir Central de l'Est
# **Output:** {'name': "Société anonyme du Comptoir Central de l'Est", 'firstnames': '', 'activity': [], 'address': [], 'title': [], 'familystatus': [], 'birthname': ''}
#
# **Input:** Germay à Paris
# **Output:** {'name': 'Germay', 'firstnames': '', 'activity': [], 'address': ['Paris'], 'title': [], 'familystatus': [], 'birthname': ''}
#
# **Input:** Barbaroux quincailler à Paris
# **Output:** {'name': 'Barbaroux', 'firstnames': '', 'activity': ['quincailler'], 'address': ['Paris'], 'title': [], 'familystatus': [], 'birthname': ''}
#
# **Input:** Costy, Jn Bte Tailleur de Pierre à Villeneuve Leroy
# **Output:** {'name': 'Costy', 'firstnames': 'Jn Bte', 'activity': ['Tailleur de Pierre'], 'address': ['Villeneuve Leroy'], 'title': [], 'familystatus': [], 'birthname': ''}
#
# **Input:** Besnet Joseph, Henri - 6/8 Rue Camille Desmoulins 19 Rue Guichard
# **Output:** {'name': 'Besnet', 'firstnames': 'Joseph, Henri', 'activity': [], 'address': ['6/8 Rue Camille Desmoulins', '19 Rue Guichard'], 'title': [], 'familystatus': [], 'birthname': ''}
#
# **Input:** Tellier Catherine fille majeure à Ablon
# **Output:** {'name': 'Tellier', 'firstnames': 'Catherine', 'activity': [], 'address': ['Ablon'], 'title': [], 'familystatus': ['fille majeure'], 'birthname': ''}
#
# **Input:** Pravel Louis Ve né Gerbuisson
# **Output:** {'name': 'Pravel', 'firstnames': 'Louis', 'activity': [], 'address': [], 'title': [], 'familystatus': ['Ve'], 'birthname': 'Gerbuisson'}
#
# **Input:** Commune d'Ablon
# **Output:** {'name': "Commune d'Ablon", 'firstnames': '', 'activity': [], 'address': [], 'title': [], 'familystatus': [], 'birthname': ''}
# Please provide the response in the form of a list of JSON structured as in the example. It should begin with [ and end with ].

# %%
FULL_PROMPT = PROMPT_CONTEXT + PROMPT_EXAMPLES
print(FULL_PROMPT)
# Out:
# You are a senior researcher specialized in digital humanities and linguistic.
# Your goal is to structure short texts describing taxpayers extracted from 19th century registers. More precisly, you have to create spans of these texts which are categorized as named entities described bellow.
#
# ### Entities
#
# - **name**: The last name of a person or the name of a company.
# - **firstnames**: One or more first names of the individual.
# - **address**: An address or any other spatial entity associated with the individual.
# - **activity"**: The profession, occupation, or work associated with the individual.
# - **title**: Title of the individual such as 'M', 'Mme', 'Mademoiselle', 'Monseigneur', 'General', or 'Prince'.
# - **familystatus**: Mentions of family or marital status of the individual such as 'Père', 'Veuve', 'Fille', 'Fils', or 'Héritier'.
# - **birthname** : Name of an individual (in most of this case a woman) before its wedding
#
# ## Task description (hard constraints)
# 1. You can have one (more rarely 2 or 3) taxpayers described in a text.
# 2. You have to preserve original text strings and case.
# 3. The outputs have to be structure has the json described in the examples.
# 4. If an entity type is not present in the input, it should be represented with an empty string (`''`) for singular entities or an empty list (`[]`) for plural entities.
#
# ### Examples:
# Here are examples of inputs and outputs:
#
# **Input:** Prudhomme
# **Output:** {'name': 'Prudhomme', 'firstnames': '', 'activity': [], 'address': [], 'title': [], 'familystatus': [], 'birthname': ''}
#
# **Input:** Société anonyme du Comptoir Central de l'Est
# **Output:** {'name': "Société anonyme du Comptoir Central de l'Est", 'firstnames': '', 'activity': [], 'address': [], 'title': [], 'familystatus': [], 'birthname': ''}
#
# **Input:** Germay à Paris
# **Output:** {'name': 'Germay', 'firstnames': '', 'activity': [], 'address': ['Paris'], 'title': [], 'familystatus': [], 'birthname': ''}
#
# **Input:** Barbaroux quincailler à Paris
# **Output:** {'name': 'Barbaroux', 'firstnames': '', 'activity': ['quincailler'], 'address': ['Paris'], 'title': [], 'familystatus': [], 'birthname': ''}
#
# **Input:** Costy, Jn Bte Tailleur de Pierre à Villeneuve Leroy
# **Output:** {'name': 'Costy', 'firstnames': 'Jn Bte', 'activity': ['Tailleur de Pierre'], 'address': ['Villeneuve Leroy'], 'title': [], 'familystatus': [], 'birthname': ''}
#
# **Input:** Besnet Joseph, Henri - 6/8 Rue Camille Desmoulins 19 Rue Guichard
# **Output:** {'name': 'Besnet', 'firstnames': 'Joseph, Henri', 'activity': [], 'address': ['6/8 Rue Camille Desmoulins', '19 Rue Guichard'], 'title': [], 'familystatus': [], 'birthname': ''}
#
# **Input:** Tellier Catherine fille majeure à Ablon
# **Output:** {'name': 'Tellier', 'firstnames': 'Catherine', 'activity': [], 'address': ['Ablon'], 'title': [], 'familystatus': ['fille majeure'], 'birthname': ''}
#
# **Input:** Pravel Louis Ve né Gerbuisson
# **Output:** {'name': 'Pravel', 'firstnames': 'Louis', 'activity': [], 'address': [], 'title': [], 'familystatus': ['Ve'], 'birthname': 'Gerbuisson'}
#
# **Input:** Commune d'Ablon
# **Output:** {'name': "Commune d'Ablon", 'firstnames': '', 'activity': [], 'address': [], 'title': [], 'familystatus': [], 'birthname': ''}

# %%
def named_entities(role, prompt, model):
    # Call the `chat` function with the specified model, format, and parameters.
    response = chat(
        model=model,
        format=TaxpayersList.model_json_schema(),
        messages=[
            {
                'role': role,
                'content': prompt
            },
        ]
    )
    # Validate and parse the response JSON into an AnimalList object.
    taxpayers_data = TaxpayersList.model_validate_json(response.message.content)
    return response

# %% [markdown]
# ### 1.3 Execute the LLM

# %%
# Main block to execute the script.
results = []
if __name__ == "__main__":
    for i in range(600,700):
        # Path to the image to be analyzed.
        uuid = taxpayers_df.iloc[i]["element_uuid"]
        taxpayer_str = taxpayers_df.iloc[i]["taxpayer"]

        try:
            print("###########################################################")
            # Print an initial message before starting the analysis.
            print(f"\nAnalyzing a taxpayer : {taxpayer_str}")
        
            # Call the function to analyze the image and get the results.
            result = named_entities(ASSISTANT, FULL_PROMPT + "**Input:**" + taxpayer_str + " **Output:**" , MODEL)
    
            print(result.message.content)
            results.append({"element_uuid":uuid,"transcription":taxpayer_str,"entities_json":json.loads(result.message.content)})
            time.sleep(0.1)
        except:
            print("ERROR")
            print(uuid)
# Out:
# ###########################################################
#
# Analyzing a taxpayer : Desgranges p↑re↓→maire d'Ormesson
# { "taxpayers": [{ "name": "Desgranges", "firstnames": "", "activity": ["maire"], "address": ["d'Ormesson"], "title": [], "familystatus": ["p\u2192maire"], "birthname": "" }] }
# ###########################################################
#
# Analyzing a taxpayer : Belleman Jean Marie→maçon à Berauié
# { "taxpayers": [ { "name": "Belleman", "firstnames": "Jean Marie", "activity": ["maçon"], "address": ["Berauié"], "title": [], "familystatus": [], "birthname": "" } ] }
# ###########################################################
#
# Analyzing a taxpayer : Le Prince de Neuchâtel→×Vauguyon→Bourgeois, maire±
# {"taxpayers":[{"name": "Le Prince de Neuch\u00e2tel", "firstnames": "", "activity": [], "address": [], "title": ["Prince"], "familystatus": [], "birthname": ""}, {"name": "\u00c0 Vauguyon", "firstnames": "", "activity": [], "address": [], "title": [], "familystatus": [], "birthname": ""}, {"name": "Bourgeois, maire", "firstnames": "", "activity": ["maire"], "address": [], "title": ["Bourgeois"], "familystatus": [], "birthname": ""}]}
# ###########################################################
#
# Analyzing a taxpayer : Vigoureux Gabriel→fab↑t↓ de bas à id
# {"taxpayers": [
#   {"name": "Vigoureux", "firstnames": "Gabriel", "activity": ["fabricant"], "address": [], "title": [], "familystatus": [], "birthname": ""}
# ]}
#
# ###########################################################
#
# Analyzing a taxpayer : Guérin Joseph fils→vig↑on↓ à id
# { "taxpayers" : [{"name": "Guérin", "firstnames": "Joseph", "activity": ["fils"], "address": ["id"], "title": [], "familystatus": [], "birthname": ""}, {"name": "vig↑on↓", "firstnames": "", "activity": [], "address": [], "title": [], "familystatus": [], "birthname": ""}] }
# ###########################################################
#
# Analyzing a taxpayer : Coudrai aug↑te↓ andré→vig↑on↓ à id
# { "taxpayers": [{"name": "", "firstnames": "", "activity": ["id"], "address": ["Ablon"], "title": [], "familystatus": ["vig\u00E9on", "aug\u00E0te"], "birthname": ""}]}
# ###########################################################
#
# Analyzing a taxpayer : Guerin Joseph, jean→Vig↑on↓ à id
# {"taxpayers":[{"name":"Guerin","firstnames":"Joseph, Jean","activity":[],"address":["id"], "title": [], "familystatus": [], "birthname": ""}]}
#
# ###########################################################
#
# Analyzing a taxpayer : Idem
# {"taxpayers":[{"name":"Prudhomme","firstnames":"","activity":[],"address":[],"title":[],"familystatus":[],"birthname":""},{"name":"Germay","firstnames":"","activity":[],"address":["Paris"],"title":[],"familystatus":[],"birthname":""},{"name":"Costy","firstnames":"Jn Bte","activity":["Tailleur de Pierre"],"address":["Villeneuve Leroy"],"title":[],"familystatus":[],"birthname":""}]}
# ###########################################################
#
# Analyzing a taxpayer : Lamblet, Pierre→vig↑on↓ à id
# { "taxpayers": [{"name": "Lamblet", "firstnames": "Pierre", "activity": ["vig\u00b0on"], "address": ["id"], "title": [], "familystatus": [], "birthname": ""}] }
# ###########################################################
#
# Analyzing a taxpayer : Bouton, Charles Louis→fab, m↑d↓ à Paris
# {"taxpayers": [{"name":"Bouton","firstnames":"","activity":["fab"],"address":["Paris"],"title":[],"familystatus":[],"birthname":""}, {"name":"Charles Louis","firstnames":"","activity":[],"address":[],"title":[],"familystatus":["m"], "birthname":""} ]}
# ###########################################################
#
# Analyzing a taxpayer : Moreau françois→Terrassier à marolles
# { "taxpayers" : [{"title": ["françois"], "familystatus": [], "birthname": ""}] }
# ###########################################################
#
# Analyzing a taxpayer : Guérin Jacq henry→maçon à id
# { "taxpayers": [ {"name":"Guerin","firstnames":"Jacq Hen," ,"activity":["maçon"],"address":["id"],"title":[],"familystatus":[],"birthname":""} ]}
# ###########################################################
#
# Analyzing a taxpayer : Idem
# {"taxpayers": [{"title": [], "familystatus": ["veuve"], "birthname": "Derville née Dupont"}, {"title": [], "familystatus": [], "birthname": ""}] }
# ###########################################################
#
# Analyzing a taxpayer : Dubief, Louis→Charetier à id
# {"taxpayers": [{"name":"Dubief","firstnames":"Louis", "activity": ["Charetier"], "address": [], "title": [], "familystatus" :[], "birthname": ""}]}
# ###########################################################
#
# Analyzing a taxpayer : Le Prince de Neufchâtel→×Vauguyon, maire→de marolles±
# {"taxpayers": [{"name": "Le Prince de NeufchÃ¢tel", "firstnames": "", "activity": [], "address": [], "title": ["Prince"], "familystatus": [], "birthname": ""}, {"name": "Vauguyon", "firstnames": "", "activity": [], "address": [], "title": ["maire" ,"marolles ±"], "familystatus": [], "birthname": ""}] }
#
# ###########################################################
#
# Analyzing a taxpayer : Le Prince de Neuchâtel→×Vauguyon, maire→de marolles±
# {"taxpayers":[{"name": "Le", "firstnames": "Prince de Neuch\u00e2tal", "activity": [], "address": ["Vauguyon"], "title": ["Prince"], "familystatus": [], "birthname": ""}, {"name": "Vauguyon", "firstnames": "", "activity": [], "address": [], "title": [], "familystatus": [], "birthname": ""}, {"name": "maire", "firstnames": "", "activity": [], "address": ["de marolles"], "title": [], "familystatus": [], "birthname": ""}]}
# ###########################################################
#
# Analyzing a taxpayer : Vigoureux→Gabriel f↑b↓ de bas
# {"taxpayers":[{"title": ["f"], "familystatus": ["b", "de bas"], "birthname": "Vigoureux, Gabriel"}]}
#
# ###########################################################
#
# Analyzing a taxpayer : Vigoureux J↑n↓ ant↑e↓→militaire
# { "taxpayers": [{"name":"Vigoureux","firstnames":"","activity":["ant\u00E9 militaire"],"address":[],"title":[],"familystatus":[],"birthname":""}] }
# ###########################################################
#
# Analyzing a taxpayer : Guérin Joseph, fils→vig↑on↓ à idem
# { "taxpayers": [ { "name": "Guerin", "firstnames": "Joseph, fils\n", "activity": ["vig\u009d\u00adon"], "address": ["idem"], "title": [], "familystatus": ["fils"], "birthname": "" } ] }
# ###########################################################
#
# Analyzing a taxpayer : Vigoureux françois→vig↑on↓ à id
# { "taxpayers": [{ "name":"Vigoureux", "firstnames": "", "activity":[], "address":["id"], "title":[], "familystatus":[], "birthname":"" }] }
# ###########################################################
#
# Analyzing a taxpayer : Vigoureux, J↑n↓ ant↑e↓→militaire
# { "taxpayers": [ { "name": "Vigoureux", "firstnames": "J↑n↓", "activity": ["ant↑e↓→militaire"], "address": [], "title": [], "familystatus": [], "birthname": "" } ] }
#
# ###########################################################
#
# Analyzing a taxpayer : Vigoureux françois→vig↑on↓ à id
# {"taxpayers": [{"title": ["françois"], "familystatus": [], "birthname": "Vigoureux"}, {"activity": ["id"], "address": ["à"]}]}
#
# ###########################################################
#
# Analyzing a taxpayer : Cretté J↑n↓ Cadet Prompt
# { "taxpayers": [ { "title": ["M"], "familystatus": [], "birthname": "Gallienourt" } ] }
# ###########################################################
#
# Analyzing a taxpayer : Bouquet Cousin
# {"taxpayers": [{"name": "Bouquet", "firstnames": "", "activity": [], "address": [], "title": [], "familystatus": [], "birthname": ""}, {"name": "Cousin", "firstnames": "", "activity": [], "address": [], "title": [], "familystatus": [], "birthname": ""}]}
#
# ###########################################################
#
# Analyzing a taxpayer : Perous
# { "taxpayers": [ {"name": "", "firstnames": "P", "activity": [""], "address": [], "title": [], "familystatus": [], "birthname": ""} ] }
# ###########################################################
#
# Analyzing a taxpayer : Legrand fils
# { "taxpayers": [{"name":"Legrand", "firstnames":"","activity":[],"address":[],"title":["fils"],"familystatus":[],"birthname":""}]}
# ###########################################################
#
# Analyzing a taxpayer : Chaillou 16↑ar↓
# { "taxpayers": [{ "name": "Chaillou", "firstnames": "", "activity": [], "address": ["16ar"], "title": [], "familystatus": [], "birthname": "" }]}
# ###########################################################
#
# Analyzing a taxpayer : Defresnes P↑re↓ J↑n↓
# { "taxpayers": [{ "name": "", "firstnames": "P\\u00b0re", "activity": [], "address": [], "title": ["M"], "familystatus": ["P\\u00bere"], "birthname": "" }] }
# ###########################################################
#
# Analyzing a taxpayer : Villerou
# {"taxpayers": [{"name": "Villerou", "firstnames": "", "activity": [], "address": [], "title": [], "familystatus": [], "birthname": ""}, {"name": "Poulain", "firstnames": "Jeanne Marie", "activity": ["Femme de Chambre"], "address": ["Paris"], "title": [], "familystatus": [], "birthname": ""}]}
#
# ###########################################################
#
# Analyzing a taxpayer : Drouhot J L
# {"taxpayers": [{"name": "Drouhot", "firstnames": "JL", "address": ["Paris"], "title": [], "familystatus": [], "birthname": ""}]}
# ###########################################################
#
# Analyzing a taxpayer : Jacquet
# { "taxpayers": [{"name": "Jacquet", "firstnames": "", "activity": [], "address": [], "title": [], "familystatus": [], "birthname": ""}] }
# ###########################################################
#
# Analyzing a taxpayer : Barre J↑n↓ L Maurice
# {"taxpayers": [{"name": "J", "firstnames": "L Maurice","familystatus": ["ve"], "birthname": ""}] }
# ###########################################################
#
# Analyzing a taxpayer : Defresnes Jacq L.
# {"taxpayers":[{"name":"Defresnes","firstnames":"","activity":[],"address":[],"title":[],"familystatus":[],"birthname":""}]}
#
# ###########################################################
#
# Analyzing a taxpayer : Adam J↑n↓ Sulpice
# {"taxpayers": [{"name": "Adam", "firstnames": "J\u00d1 n\u009D", "activity": [], "address": [], "title": [], "familystatus": [], "birthname": ""}]}
# ###########################################################
#
# Analyzing a taxpayer : Ø
# { "taxpayers": [ ] }
#
# ###########################################################
#
# Analyzing a taxpayer : Boumelet p↑re↓
# { "taxpayers": [ { "name": "", "firstnames": "", "activity": [], "address": [""], "title": [], "familystatus": ["p↑re↓"], "birthname": "" } ] }
# ###########################################################
#
# Analyzing a taxpayer : Duclos J B↑te↓ L.
# { "taxpayers": [{"name": "Duclos", "firstnames": "J B", "activity": [], "address": [], "title": ["L"], "familystatus": [], "birthname": ""}] }
# ###########################################################
#
# Analyzing a taxpayer : Vaudoyer régis père
# { "taxpayers": [ { "name": "", "firstnames": "Rgis", "activity": [], "address": [], "title": ["Pgre"], "familystatus": ["Pgr"], "birthname": "" } ] }
#
# ###########################################################
#
# Analyzing a taxpayer : Deschamp J Gabriel
# {"taxpayers":[{"name":"Deschamp","firstnames":"J Gabriel","activity":[],"address":[],"title":[],"familystatus":[],"birthname":""}]}
#
# ###########################################################
#
# Analyzing a taxpayer : Caron Mathias
# { "taxpayers": [{"name": "Caron", "firstnames": "Mathias", "activity": [], "address": [], "title": [], "familystatus": [], "birthname": ""}] }
# ###########################################################
#
# Analyzing a taxpayer : Vaudoyer regis père
# { "taxpayers" : [{"name": "", "firstnames": "Vaudoyer", "activity": [], "address": [], "title": ["père"], "familystatus": ["regis"], "birthname": ""}] }
# ###########################################################
#
# Analyzing a taxpayer : houdé Joseph
# {"taxpayers":[{"name":"houd\u00e9","firstnames":"","activity":[],"address":[],"title":[],"familystatus":[],"birthname":""}]}
# ###########################################################
#
# Analyzing a taxpayer : Craux J↑n↓
# {"taxpayers":[{"name":"Craux","firstnames":"","activity":[],"address":[],"title":[],"familystatus":[],"birthname":""}]}
#
# ###########################################################
#
# Analyzing a taxpayer : Fontaine V↑ve↓
# { "taxpayers": [{"name": "Fontaine", "firstnames": "", "activity": [], "address": [], "title": ["V"], "familystatus": ["Ve"], "birthname": ""}] }
# ###########################################################
#
# Analyzing a taxpayer : Gervatiers
# {"taxpayers":[{"name":"Gervatiers","firstnames":"","activity":[],"address":[],"title":[],"familystatus":[],"birthname":""}]}
# ###########################################################
#
# Analyzing a taxpayer : Defresnes Jacq L
# {"taxpayers": [
#   {"name":"Defresnes", "firstnames": "Jacq L","activity":[],"address":["Châteaudun"],"title":[],"familystatus":[],"birthname":""}
# ]}
# ###########################################################
#
# Analyzing a taxpayer : Delanoue V↑e↓
# {"taxpayers": [{"name": "Delanoue", "firstnames": "", "activity": [], "address": [], "title": ["Ve"], "familystatus": ["V\ufb01ve"], "birthname": ""}]}
# ###########################################################
#
# Analyzing a taxpayer : D↑elle↓ Marehane
# { "taxpayers": [{"name": "", "firstnames": "Marehane", "activity": [], "address": [], "title": ["Madame"], "familystatus": [], "birthname": ""}, {"name": "", "firstnames": "", "activity": ["Delle"], "address": [], "title": [], "familystatus": [], "birthname": ""}]}
# ###########################################################
#
# Analyzing a taxpayer : Fontaine V↑e↓
# { "taxpayers": [{ "name": "Fontaine", "firstnames": "", "activity": [], "address": [], "title": ["Ve"], "familystatus": [], "birthname": "" }] }
# ###########################################################
#
# Analyzing a taxpayer : Blost
# { "taxpayers": [{"name":"Blost", "firstnames":"","activity":[],"address":[],"title":[],"familystatus":[],"birthname":""}]}
# ###########################################################
#
# Analyzing a taxpayer : Delanoue V↑e↓
# {"taxpayers": [{"name": "Delanoue", "firstnames": "", "activity": [], "address": ["V↑e↓"], "title": [], "familystatus": [], "birthname": ""}]}
#
# ###########################################################
#
# Analyzing a taxpayer : Berthier→×Vauguyon±
# { "taxpayers": [{"name": "", "firstnames": "", "activity": [""], "address": ["Paris"], "title": [], "familystatus": [], "birthname": ""}] }
# ###########################################################
#
# Analyzing a taxpayer : Berthier
# {"taxpayers": [{"name": "Berthier", "firstnames": "", "activity": [], "address": [], "title": [], "familystatus": [], "birthname": ""}]}
# ###########################################################
#
# Analyzing a taxpayer : idem→×Vauguyon±
# { "taxpayers": [{ "name": "", "firstnames": "idem", "activity": [], "address": ["d'Ablon"], "title": [], "familystatus": ["→×", "Vauguyon", "+", ""], "birthname": "" }, { "name": "Pierre", "firstnames": "Jeanne", "activity": [], "address": ["Paris"], "title": [], "familystatus": [], "birthname": "" }]}
# ###########################################################
#
# Analyzing a taxpayer : Duclos maitre→de poste
# { "taxpayers": [{"name":"Duclos","firstnames":"","activity":["maitre de poste"],"address":[],"title":["maitre"], "familystatus":[],"birthname":""}]}
# ###########################################################
#
# Analyzing a taxpayer : Guérin J↑es↓ henry→maçon
# { "taxpayers": [{"name": "", "firstnames": "J\u2191es\u2193henry", "activity": ["\u2197ma\u2190on"], "address": [], "title": [], "familystatus": [], "birthname": ""}]}
# ###########################################################
#
# Analyzing a taxpayer : Lefevre Jacques
# {"taxpayers":[{"name":"Lefevre","firstnames":"","activity":[],"address":[],"title":[],"familystatus":[],"birthname":""}]}
# ###########################################################
#
# Analyzing a taxpayer : Galland Louis→nicolas
# { "taxpayers": [{"name": "Galland", "firstnames": "", "activity": [], "address": [], "title": [], "familystatus": ["Louis"], "birthname": ""}] }
# ###########################################################
#
# Analyzing a taxpayer : Galland antoine→romain V↑on↓
# { "taxpayers": [ {}] }
# ###########################################################
#
# Analyzing a taxpayer : Berthier prince→de neufchâtel
# {"taxpayers":[{"name":"Berthier","firstnames":"","activity":[],"address":[],"title":["prince"],"familystatus":["de neufchâtel"], "birthname": ""}]}
# ###########################################################
#
# Analyzing a taxpayer : Barrey pierre
# { "taxpayers": [{"name": "Barrey", "firstnames": "", "activity": [], "address": [], "title": [], "familystatus": [], "birthname": ""}] }
# ###########################################################
#
# Analyzing a taxpayer : Le Prince de Neufchâtel→×Vauguyon±
# {"taxpayers": [{"name": "Prince de Neufch\ud835\udc0dal", "firstnames": "", "activity": [], "address": [], "title": ["PrincE"], "familystatus": [], "birthname": ""}]}
# ###########################################################
#
# Analyzing a taxpayer : Berthier
# {"taxpayers": [{"name":"Berthier","firstnames":"","activity":[],"address":[],"title":[],"familystatus":[],"birthname":""}] }
# ###########################################################
#
# Analyzing a taxpayer : idem→×Vauguyon±
# {"taxpayers": [{"name":"idem","firstnames":"","activity":[],"address":[],"title":[],"familystatus":[],"birthname":""},{"name":"\u00b7 Vauguyon","firstnames":"","activity":[],"address":[],"title":[],"familystatus":[],"birthname":""}]}
# ###########################################################
#
# Analyzing a taxpayer : Berthier
# { "taxpayers": [
#     { "address": ["Paris"], "title": [], "familystatus": [], "birthname": "" },
#     { "address": [], "title": [], "familystatus": [], "birthname": "" }
# ]}
#
# ###########################################################
#
# Analyzing a taxpayer : idem→×Vauguyon±
# {"taxpayers": [{"name": "idem", "firstnames": "", "activity": [], "address": ["Vauguyon"], "title": [], "familystatus": [], "birthname": ""}]}
#
# ###########################################################
#
# Analyzing a taxpayer : Duclos
# {"taxpayers":[{"title": [],"birthname": ""}]}
# ###########################################################
#
# Analyzing a taxpayer : Ally Joseph Marie
# { "taxpayers": [{"name": "Ally", "firstnames": "Joseph Marie","activity":[],"address":["Paris"],"title":[],"familystatus":[],"birthname":""}] }
# ###########################################################
#
# Analyzing a taxpayer : Héricourt Pierre Saturnin
# { "taxpayers" : [{"title": ["Pierre"], "familystatus": [], "birthname": ""}, {"firstnames": "Saturnin", "activity": [], "address": [], "title": [], "familystatus": [], "birthname": ""}]}
# ###########################################################
#
# Analyzing a taxpayer : Héricourt Louis Victor
# { "taxpayers": [
#   { "name": "H\u00e9ricourt", "firstnames": "Louis Victor", "activity": [], "address": [], "title": [], "familystatus": [], "birthname": "" } ] }
#
# ###########################################################
#
# Analyzing a taxpayer : Rameau Pierre Côme
# {"taxpayers": [{"name": "Rameau", "firstnames": "", "activity": [], "address": [], "title": [], "familystatus": [], "birthname": ""}]}
# ###########################################################
#
# Analyzing a taxpayer : Mérillon Jean Denis, V↑ve↓
# { "taxpayers": [ { "name": "Mérillon", "firstnames": "Jean Denis, V", "activity": [], "address": [], "title": ["V"], "familystatus": ["V"], "birthname": "" } ] }
# ###########################################################
#
# Analyzing a taxpayer : Berger Ambroise magloire
# { "taxpayers": [{"title": [], "birthname": ""}]}
#
# ###########################################################
#
# Analyzing a taxpayer : Verneau Jean, dit le→Dogue
# { "taxpayers": [{"name": "Verneau", "firstnames": "Jean, dit le Douge", "activity": [], "address": [], "title": [], "familystatus": [], "birthname": ""}] }
#
# ###########################################################
#
# Analyzing a taxpayer : Berger Baptiste
# { "taxpayers": [{"name": "Berger", "firstnames": "", "activity": [], "address": [], "title": [], "familystatus": [], "birthname": ""}] }
# ###########################################################
#
# Analyzing a taxpayer : Mouscadet Pierre Grégoire→à Fontenay
# {"taxpayers": [{"name": "Mouscadet", "firstnames": "Pierre Gr\u00e9goire", "activity": [], "address": ["Fontenay"], "title": [], "familystatus": [], "birthname": ""}]}
# ###########################################################
#
# Analyzing a taxpayer : Beuzeville charles, dit→Michon
# { "taxpayers": [{"name": "Beuzeville", "firstnames": "charles", "activity": ["dit"], "address": [], "title": [], "familystatus": [], "birthname": "Michon"}]}
# ###########################################################
#
# Analyzing a taxpayer : Héricourd Louis Gabriel
# { "taxpayers": [
#     { "name": "Héricourd", "firstnames": "Louis Gabriel", "activity": [], "address": [], "title": [], "familystatus": [], "birthname": "" },
#    { "name": "Héricourd", "firstnames": "", "activity": [], "address": [], "title": ["M"], "familystatus": [], "birthname": ""}
#   ]
# }
#
# ###########################################################
#
# Analyzing a taxpayer : Ancelot Pierre Saturnin, dit Carabin
# { "taxpayers": [{ "name": "Ancelot", "firstnames": "Pierre Saturnin dit Carabin", "activity": [], "address": [], "title": [], "familystatus": [], "birthname": "" }]}
# ###########################################################
#
# Analyzing a taxpayer : Ancelot Nicolas Joseph
# {"taxpayers":[{"name":"Ancelot","firstnames":"","activity":[],"address":[],"title":[],"familystatus":[],"birthname":""}]}
# ###########################################################
#
# Analyzing a taxpayer : Ancelot nicolas, dit ancelon→Veuve
# {"taxpayers": [{"name": "Ancelot", "firstnames": "nicolas dit ancelon", "activity": [], "address": [], "title": [], "familystatus": ["veuve"], "birthname": ""}]}
# ###########################################################
#
# Analyzing a taxpayer : Delage Bourgeois
# { "taxpayers": [{"name": "Delage", "firstnames": "", "activity": [], "address": [], "title": [], "familystatus": [], "birthname": ""}, {"name": "Bourgeois", "firstnames": "", "activity": [], "address": [], "title": [], "familystatus": [], "birthname": ""}] }
# ###########################################################
#
# Analyzing a taxpayer : De la Marre Mathurin à→Paris
# { "taxpayers": [{"name":"De la Marre", "firstnames": "", "activity": [],"address":["Paris"], "title": ["Mathurin"], "familystatus": [], "birthname": ""}] }
# ###########################################################
#
# Analyzing a taxpayer : Pierlot banquier à Paris
# { "taxpayers": [{ "name": "Pierlot", "firstnames": "", "activity": ["banquier"], "address": ["Paris"], "title": [], "familystatus": [], "birthname": "" }]}
# ###########################################################
#
# Analyzing a taxpayer : "
# { "taxpayers": [
#     {
#         "name": "",
#         "firstnames": "Pierre et Hippolyte",
#         "activity": ["Tailleur de pierre"],
#         "address": ["Paris"],
#         "title": [],
#         "familystatus": [],
#         "birthname": ""
#     },
#     {
#         "name": "Gambart",
#         "firstnames": "",
#         "activity": [],
#         "address": ["14, rue Saint-Fiacre"],
#         "title": [],
#         "familystatus": [],
#         "birthname": ""
#     }
# ] }
# ###########################################################
#
# Analyzing a taxpayer : "
# { "taxpayers": [
# { "name": "" , "title": [] , "familystatus": [""] ,"birthname": "" },{"title":[""],"familystatus":[],"birthname":""}]
#  }
# ###########################################################
#
# Analyzing a taxpayer : "
# { "taxpayers": [{"name":"Prudhomme","firstnames":"","activity":[],"address":[],"title":[],"familystatus":[],"birthname":""},{"name": "","firstnames":"","activity":[],"address":[],"title":[],"familystatus":[],"birthname":""}] }
# ###########################################################
#
# Analyzing a taxpayer : "
# { "taxpayers": [
# { "name": "", "firstnames": "", "activity": [], "address": [], "title": [], "familystatus": [], "birthname": "" }, { "name": "", "firstnames": "Jn", "activity": ["Tailleur de Pierre"], "address": [], "title": [], "familystatus": [], "birthname": "" }]}
# ###########################################################
#
# Analyzing a taxpayer : "
# { "taxpayers": [{"name": "Prudhomme", "firstnames": "", "activity": [], "address": [], "title": [], "familystatus": [], "birthname": ""}, {"name": "Société anonyme du Comptoir Central de l'Est", "firstnames": "", "activity": [], "address": [], "title": [], "familystatus": [], "birthname": ""}] }
# ###########################################################
#
# Analyzing a taxpayer : Cochet mineurs
# {"taxpayers": [{"name": "Cochet", "firstnames": "", "activity": ["mineurs"], "address": [], "title": [], "familystatus": [], "birthname": ""}]}
#
# ###########################################################
#
# Analyzing a taxpayer : Leroy Clément
# {"taxpayers": [{"name":"Leroy","firstnames":"","activity":[],"address":[],"title":[],"familystatus":[],"birthname":""}]}
#
# ###########################################################
#
# Analyzing a taxpayer : Cochet mineurs
# { "taxpayers": [{"name": "Cochet", "firstnames": "", "activity": ["mineurs"], "address": [], "title": [], "familystatus": [], "birthname": ""}]}
# ###########################################################
#
# Analyzing a taxpayer : Leroy J↑n↓
# { "taxpayers":[{"name":"Leroy","firstnames":"J\n\u2191d","activity":[],"address":[],"title":[],"familystatus":[],"birthname":""}] }
# ###########################################################
#
# Analyzing a taxpayer : Cochet Georges
# {"taxpayers" : [{"name": "Cochet", "firstnames": "", "activity": [], "address": [], "title": [], "familystatus": [], "birthname":""}, {"name":"Société anonyme du Comptoir Central de l'Est", "firstnames": "", "activity": [], "address": [], "title": [], "familystatus": [], "birthname": ""}]}
# ###########################################################
#
# Analyzing a taxpayer : Bourdillat
# { "taxpayers": [{"name": "Bourdillat", "firstnames": "", "activity": [], "address": [], "title": [], "familystatus": [], "birthname": ""}, {"name": "Bourdillat", "firstnames": "", "activity": [], "address": [], "title": [], "familystatus": [], "birthname": ""}] }
# ###########################################################
#
# Analyzing a taxpayer : Cochet Gabriel
# {"taxpayers":[{"name": "Cochet","firstnames":"","activity":[],"address":[],"title":[],"familystatus":[],"birthname":""}] }
#
# ###########################################################
#
# Analyzing a taxpayer : V↑ve↓ Collet
# {"taxpayers":[{"name":"Collet","firstnames":"","activity":[],"address":[],"title":[],"familystatus":["Ve"],"birthname":""}]}
# ###########################################################
#
# Analyzing a taxpayer : Creté hector
# { "taxpayers": [{"name": "", "firstnames": "", "activity": ["ferrailleur"], "address": ["Paris"], "title": [], "familystatus": [], "birthname": ""}]}
# ###########################################################
#
# Analyzing a taxpayer : Noblet
# {"taxpayers":[{"firstnames":"","activity":[],"address":[],"title":[],"familystatus":[],"birthname":"Noblet"}]}
# ###########################################################
#
# Analyzing a taxpayer : Mayeux
# {"taxpayers": [{"activity": [], "address": [], "familystatus": [], "birthname": "\n    \n        Mayeux\n    \n    \n    \n        \n            Mme\n        \n    \n    \n    \n    \n    \n    \n    "}] }

# %%
with open('taxpayers_all.json', 'w',encoding='utf-8') as f:
    json.dump(results, f, ensure_ascii=False, indent=4)

# %% [markdown]
# **A post-correction-by-hand step of taxpayers.json is required here !!!**

# %% [markdown]
# ### 1.4 Convert JSON to Brat format

# %%
import json
with open('taxpayers_all.json', 'r',encoding='utf-8') as file:
    results_f = json.load(file)

# %%
from formats import create_brat_entity_T

RES_PATH = ROOT + "/data/NER/NER_dataset"

for r in results_f:
    element_uuid = r['element_uuid']
    transcription = r['transcription']
    
    #Create files to store the results
    txt = open(RES_PATH + "/" + element_uuid + ".txt","w")
    txt.write(transcription)
    ann = open(RES_PATH + "/" + element_uuid + ".ann","w")
    
    #Create a counter for entities
    counter = 0
    for e in r['entities_json']['taxpayers']:
        keys = e.keys()
        for k in keys:
            entity_value = e[k]
            try:
                if isinstance(entity_value,str) and len(entity_value) != 0:
                    if transcription == entity_value:
                        brat = create_brat_entity_T(counter,k,0,len(transcription),transcription)
                        ann.write(brat)
                        counter +=1
                    else:
                        if '(' in entity_value and ')' in entity_value:
                            entity_value_r = entity_value.replace('(','\(').replace(')','\)')
                            reg = regex.search(entity_value_r,transcription)
                        elif '(' in entity_value:
                            entity_value_r = entity_value.replace('(','\(')
                            reg = regex.search(entity_value_r,transcription)
                        elif ')' in entity_value:
                            entity_value_r = entity_value.replace(')','\)')
                            reg = regex.search(entity_value_r,transcription)
                        else:
                            reg = regex.search(entity_value,transcription)
                        span = reg.span(0)
                        if span[1] - span[0] != 0:
                            brat = create_brat_entity_T(counter,k,span[0],span[1],reg.group(0))
                            ann.write(brat)
                            counter +=1
                elif isinstance(entity_value,list) and len(entity_value) != 0:
                    for part in entity_value:
                        reg = regex.search(part,transcription)
                        span = reg.span(0)
                        if span[1] - span[0] != 0:
                            brat = create_brat_entity_T(counter,k,span[0],span[1],reg.group(0))
                            ann.write(brat)
                            counter +=1
            except:
                print(element_uuid)
                print(transcription)
# Out:
# T0	name 0 6	Rameau
#
# T1	firstnames 7 17	J↑n↓ louis
#
# T2	familystatus 18 22	fils
#
# T3	name 0 6	Rameau
#
# T4	firstnames 7 17	J↑n↓ louis
#
# T5	familystatus 23 28	veuve
#
# T0	name 0 9	Vigoureux
#
# T1	firstnames 10 16	f↑ois↓
#
# T0	name 0 5	Royer
#
# T1	firstnames 6 21	Jean louis marc
#
# T0	name 0 6	Véron,
#
# T1	firstnames 7 18	J↑n↓ J↑ques
#
# T2	activity 20 28	Vig↑ron↓
#
# T3	address 31 41	chenevière
#
# T0	name 0 6	Gachet
#
# T1	firstnames 7 28	p↑re↓ (dit le→dragon)
#
# T2	activity 29 36	Vig↑on↓
#
# T3	address 39 43	Sucy
#
# T0	name 0 10	Bourdillat
#
# T1	firstnames 11 15	J↑n↓
#
# T0	name 0 5	Leroy
#
# T1	firstnames 6 12	Gilles
#
# T0	name 0 6	Rémoud
#
# T1	firstnames 7 14	Charles
#
# T0	name 0 6	Cochet
#
# T1	firstnames 7 11	J↑n↓
#
# T0	name 0 7	Pigeron
#
# T0	name 0 5	Leroy
#
# T1	firstnames 6 10	J↑n↓
#
# T0	name 0 6	Collet
#
# T1	firstnames 7 12	marie
#
# T0	name 0 5	Baron
#
# T1	firstnames 6 11	N↑as↓
#
# T0	name 0 6	Pillet
#
# T0	name 0 8	Mignière
#
# T1	firstnames 9 15	Claude
#
# T0	name 0 7	Pigeron
#
# T0	name 5 11	Corday
#
# T1	name 13 21	hospices
#
# T0	name 0 5	Leroy
#
# T1	firstnames 6 12	F↑ois↓
#
# T0	name 0 10	Bourdillat
#
# T0	name 5 12	Moutard
#
# T1	familystatus 0 4	V↑e↓
#
# T0	name 0 7	Renoult
#
# T1	firstnames 8 18	J↑n↓ B↑te↓
#
# T0	name 0 7	Chompré
#
# T1	firstnames 8 15	maurice
#
# T0	name 0 23	Le Prince de→Neufchâtel
#
# T0	name 0 4	idem
#
# T1	name 6 14	Vauguyon
#
# T2	activity 16 21	maire
#
# T0	name 0 23	Le Prince de→neufchâtel
#
# T0	name 0 4	idem
#
# T1	name 6 14	Vauguyon
#
# T2	activity 16 34	maire→de marolles±
#
# T0	name 0 23	Le Prince de→neufchâtel
#
# T0	name 0 6	Dubief
#
# T1	firstnames 7 12	Louis
#
# T2	activity 13 22	Charetier
#
# T3	address 25 33	marolles
#
# T0	name 0 23	Le Prince de→Neufchâtel
#
# T0	name 0 8	Berthier
#
# T1	firstnames 9 18	alexandre
#
# T0	name 0 6	Gachet
#
# T1	address 9 14	Paris
#
# T0	name 0 7	Javelot
#
# T1	firstnames 8 14	michel
#
# T0	name 0 6	Gachet
#
# T1	firstnames 7 19	J↑n↓ Ch↑les↓
#
# T2	familystatus 20 35	Gendre le maire
#
# T0	name 0 8	hideline
#
# T1	firstnames 9 14	Louis
#
# T0	name 0 7	Laurent
#
# T1	familystatus 8 13	Veuve
#
# T0	name 0 7	Meunier
#
# T1	familystatus 8 13	Cadet
#
# T0	name 0 9	Le Grain
#
# T1	firstnames 9 25	↑Joseph↓ leonard
#
# T0	name 0 7	Perrier
#
# T1	firstnames 8 14	Pierre
#
# T0	name 0 6	Martin
#
# T1	firstnames 7 15	Maréchal
#
# T0	name 0 11	Arpentinier
#
# T1	firstnames 12 18	f↑ois↓
#
# T0	name 0 5	fouré
#
# T1	firstnames 6 12	f↑ois↓
#
# T0	name 0 5	David
#
# T1	firstnames 6 12	Pierre
#
# T0	name 0 6	aubert
#
# T1	firstnames 7 14	Jacques
#
# T0	name 7 14	Gervaix
#
# T1	name 0 5	Camot
#
# T2	firstnames 16 22	Pierre
#
# T0	name 0 6	aubert
#
# T1	firstnames 7 14	Jacques
#
# T0	name 1 7	Savart
#
# T1	firstnames 8 24	françois nicolas
#
# T0	name 0 6	Préaus
#
# T1	firstnames 7 20	denis vincent
#
# T0	name 0 7	Milcens
#
# T1	firstnames 8 28	geneviève guillaumed
#
# T0	name 0 7	Laizier
#
# T1	firstnames 8 15	Jacques
#
# T0	name 0 8	Lemaître
#
# T1	firstnames 9 19	Jean spire
#
# T0	name 0 7	Thioust
#
# T1	firstnames 8 19	marie henry
#
# T0	name 0 6	Savart
#
# T1	firstnames 7 23	françois nicolas
#
# T0	name 0 7	Milcent
#
# T1	firstnames 8 19	Jean pierre
#
# T0	name 0 8	Bataille
#
# T1	firstnames 9 21	pierre louis
#
# T0	name 0 7	Milcent
#
# T1	firstnames 8 21	louis gervais
#
# T0	name 0 6	Vienoz
#
# T1	firstnames 7 28	pierre Philippe Spire
#
# T0	name 0 7	Milcent
#
# T1	firstnames 8 19	Jean Pierre
#
# T0	name 0 8	Bataille
#
# T1	firstnames 9 24	claude françois
#
# T0	name 2 22	Hospice de charenton
#
# T0	name 0 6	Girard
#
# T1	firstnames 7 22	pierre françois
#
# T0	name 0 7	Vienot,
#
# T1	firstnames 8 20	pierre louis
#
# T2	familystatus 21 26	jeune
#
# T0	name 0 6	Delor,
#
# T1	firstnames 12 18	claude
#
# T2	familystatus 7 11	V↑e↓
#
# T0	name 0 7	Berault
#
# T1	firstnames 8 20	pieric n↑as↓
#
# T0	name 0 5	hétru
#
# T1	firstnames 6 16	Jean louis
#
# T0	name 0 8	Chevreau
#
# T1	familystatus 10 32	h↑ers↓ françois aug↑n↓
#
# T0	name 0 6	Savart
#
# T1	firstnames 7 21	f↑ois↓ nicolas
#
# T0	name 0 6	Moulin
#
# T1	firstnames 7 14	nicolas
#
# T0	name 0 8	henault,
#
# T1	firstnames 9 25	Jean louis marie
#
# T0	name 0 9	Gouillard
#
# T1	firstnames 16 30	louis philippe
#
# T2	familystatus 11 15	V↑e↓
#
# T0	name 0 7	Ancelle
#
# T1	address 10 16	Evreux
#
# T2	name 17 23	Bennet
#
# T3	familystatus 24 28	V↑e↓
#
# T0	name 0 7	Pvotait
#
# T1	firstnames 14 20	Claude
#
# T2	familystatus 8 13	V.↑e↓
#
# T0	name 0 6	Monroy
#
# T0	name 0 6	Ragues
#
# T0	name 0 5	hutin
#
# T0	name 0 5	Veron
#
# T1	familystatus 6 10	V↑e↓
#
# T0	name 0 6	Dutray
#
# T0	name 0 5	Jolly
#
# T1	firstnames 6 15	hippolite
#
# T0	name 0 7	Bracony
#
# T1	firstnames 13 19	Pierre
#
# T2	familystatus 8 12	V↑e↓
#
# T0	name 0 6	Dutray
#
# T0	name 0 5	Cotty
#
# T0	name 0 6	Grangé
#
# T0	name 0 8	Vignet❌❌
#
# T1	address 11 17	choisy
#
# T2	address 31 38	Corbeil
#
# T3	name 19 27	Deforges
#
# T0	name 8 16	Delanoue
#
# T1	firstnames 0 7	antoine
#
# T2	name 8 16	Delanoue
#
# T3	firstnames 17 23	×J↑n↓±
#
# T0	name 0 6	Saugin
#
# T1	firstnames 7 13	F↑ois↓
#
# T0	name 0 8	Delanoue
#
# T1	firstnames 9 18	toussaint
#
# T2	activity 19 28	Jardinier
#
# T3	address 31 35	Brie
#
# T0	name 0 8	Delanoue
#
# T1	firstnames 9 18	J↑n↓ bapt
#
# T2	address 21 27	Grinon
#
# T0	name 1 6	huten
#
# T0	name 0 5	Piors
#
# T1	firstnames 6 14	augustin
#
# T2	title 14 20	, V↑e↓
#
# T0	name 0 12	Dubois Petié
#
# T1	firstnames 13 32	Louis Charles André
#
# T2	address 34 39	Paris
#
# T0	name 0 14	Migon de Berty
#
# T1	firstnames 15 36	ange maximilien simon
#
# T2	address 38 43	Paris
#
# T0	name 0 8	Defresne
#
# T1	firstnames 9 34	honoré frédéric dit Bizet
#
# T2	address 36 41	Vitry
#
# T0	name 0 8	Duchange
#
# T1	firstnames 9 20	Jean Pierre
#
# T2	address 22 27	Vitry
#
# T0	name 0 8	Leprince
#
# T1	firstnames 9 25	andré marguerite
#
# T0	name 0 5	Maton
#
# T1	firstnames 6 24	Pierre Jean Basile
#
# T2	address 26 31	Vitry
#
# T0	name 0 7	Grognet
#
# T1	firstnames 8 23	Philippe Julien
#
# T2	address 25 30	Vitry
#
# T0	name 0 8	Thévenoi
#
# T1	firstnames 9 19	jean louis
#
# T2	address 39 44	vitry
#
# T3	familystatus 20 24	père
#
# T4	familystatus 25 37	g↑dre↓ bizon
#
# T0	name 0 4	Lamy
#
# T1	firstnames 5 27	Jean Louis denis Félix
#
# T0	name 0 6	Fleury
#
# T1	firstnames 7 14	J B↑te↓
#
# T2	activity 15 30	m↑d↓ de moutons
#
# T3	address 33 41	marolles
#
# T0	name 0 6	huguet
#
# T1	firstnames 7 12	Louis
#
# T2	activity 13 20	vig↑on↓
#
# T3	address 23 25	id
#
# T0	name 0 6	Guérin
#
# T1	firstnames 7 20	Jaq↑es↓ henry
#
# T2	activity 21 26	maçon
#
# T3	address 29 31	id
#
# T0	name 0 7	Gaillon
#
# T1	firstnames 8 14	Pierre
#
# T2	activity 15 26	Cultivat↑r↓
#
# T3	address 29 31	id
#
# T0	name 0 23	Le Prince de Neufchâtel
#
# T1	name 25 33	Vauguyon
#
# T2	activity 35 52	maire→de marolles
#
# T0	name 0 22	La Commune→de marolles
#
# T0	name 0 8	Berthier
#
# T1	firstnames 9 18	alex↑dre↓
#
# T2	title 19 39	Prince de neufchâtel
#
# T0	name 0 22	La Commune→de marolles
#
# T0	name 0 23	Le Prince de→neufchâtel
#
# T0	name 0 4	idem
#
# T1	name 6 14	Vauguyon
#
# T2	activity 15 32	maire de marolles
#
# T0	name 0 22	La Commune→de marolles
#
# T0	name 0 23	Le Prince de→neufchâtel
#
# T0	name 0 6	Barrey
#
# T1	firstnames 7 13	Pierre
#
# T2	activity 14 29	garde champêtre
#
# T0	name 0 7	Galland
#
# T1	firstnames 8 19	Louis N↑as↓
#
# T2	activity 20 27	vig↑on↓
#
# T3	address 30 38	marolles
#
# T0	name 0 23	Le Prince de neufchâtel
#
# T1	name 25 33	Vauguyon
#
# T2	activity 34 39	maire
#
# T0	name 0 8	Piedquin
#
# T1	firstnames 9 28	f↑ois↓ marie→charon
#
# T2	address 31 48	Brie→comte Robert
#
# T0	name 0 23	Le Prince de Neufchâtel
#
# T1	name 25 33	Vauguyon
#
# T0	name 0 8	Berthier
#
# T1	firstnames 9 18	alexandre
#
# T0	name 0 2	id
#
# T1	name 4 12	Vauguyon
#
# T0	name 0 7	Gallais
#
# T1	firstnames 8 14	Julien
#
# T0	name 0 7	Galland
#
# T1	firstnames 8 19	Louis N↑as↓
#
# T0	name 0 7	Lefevre
#
# T1	firstnames 8 15	Jacques
#
# T0	name 0 8	Berthier
#
# T1	firstnames 9 18	alexandre
#
# T0	name 0 6	Bedeau
#
# T1	firstnames 7 13	pierre
#
# T2	address 16 27	Villecresne
#
# T0	name 0 5	Corse
#
# T1	activity 6 15	bourgeois
#
# T2	address 18 23	paris
#
# T0	name 0 23	Le Prince de Neufchâtel
#
# T1	name 25 33	Vauguyon
#
# T0	name 0 7	Motheau
#
# T1	familystatus 9 23	h↑ers↓→Germain
#
# T0	name 0 23	Le Prince de Neufchâtel
#
# T1	name 25 33	Vauguyon
#
# T0	name 0 8	Berthier
#
# T1	firstnames 9 18	alexandre
#
# T0	name 0 4	idem
#
# T1	name 6 14	Vauguyon
#
# T0	name 0 8	Mazareau
#
# T1	firstnames 9 15	pierre
#
# T2	familystatus 17 22	veuve
#
# T3	familystatus 24 29	Veuve
#
# T0	name 0 9	Jacquemin
#
# T1	firstnames 10 14	Jean
#
# T2	activity 15 20	V↑on↓
#
# T3	address 23 30	Santeny
#
# T0	name 0 6	Guérin
#
# T1	firstnames 7 30	J↑n↓ B↑te↓→dit le Sourd
#
# T2	address 33 35	id
#
# T0	name 0 8	Mazareau
#
# T1	activity 14 20	pierre
#
# T2	address 23 31	marolles
#
# T3	familystatus 9 13	V↑e↓
#
# T0	name 0 6	Lamcau
#
# T1	firstnames 7 24	Pierre Jh achille
#
# T0	name 0 9	Pascallet
#
# T1	firstnames 10 25	Jean Bte Claude
#
# T0	name 0 7	Gervais
#
# T1	firstnames 8 15	adolphe
#
# T0	name 0 8	Coiffier
#
# T1	firstnames 9 25	Désiré sébastien
#
# T0	name 0 9	Héricourt
#
# T1	firstnames 10 26	françois maurice
#
# T0	name 0 8	Soudieux
#
# T1	firstnames 9 23	louis alphonse
#
# T0	name 0 13	voie publique
#
# T0	name 0 6	Rameau
#
# T1	firstnames 7 19	Paul Clément
#
# T0	name 0 6	Hudrir
#
# T1	firstnames 7 22	Charles Clément
#
# T0	name 0 8	Coiffier
#
# T1	firstnames 9 25	Sébastien Joseph
#
# T0	name 0 8	Soudieux
#
# T1	firstnames 9 21	Louis Joseph
#
# T0	name 0 13	voie publique
#
# T0	name 0 15	de Beaufranchet
#
# T1	familystatus 16 22	frères
#
# T0	name 0 6	Rameau
#
# T1	firstnames 7 25	helvébais françois
#
# T0	name 0 8	Coiffier
#
# T1	firstnames 9 25	désiré sébastien
#
# T0	name 0 9	Mouscadet
#
# T1	firstnames 10 22	pierre louis
#
# T0	name 0 7	Ancelet
#
# T1	firstnames 8 20	nicolas J↑h↓
#
# T0	name 0 8	Misgault
#
# T1	firstnames 9 19	J↑n↓ B↑te↓
#
# T2	name 0 8	Misgault
#
# T3	firstnames 25 30	louis
#
# T4	familystatus 20 24	fils
#
# T0	name 0 8	Fountain
#
# T1	firstnames 9 23	thomas taylord
#
# T0	name 0 8	Misgault
#
# T1	firstnames 9 19	J↑n↓ B↑te↓
#
# T2	name 0 8	Misgault
#
# T3	firstnames 25 30	louis
#
# T4	familystatus 20 24	fils
#
# T0	name 0 8	Fountain
#
# T1	firstnames 9 23	thomas taylord
#
# T0	name 0 7	Gallais
#
# T1	firstnames 8 14	Joseph
#
# T0	name 0 8	Beurrier
#
# T1	firstnames 9 22	pierre honoré
#
# T0	name 0 5	Brice
#
# T1	firstnames 6 16	j↑h↓ marie
#
# T0	name 0 7	Nicolas
#
# T1	firstnames 8 21	j↑n↓ philippe
#
# T0	name 0 6	Picard
#
# T1	firstnames 7 14	georges
#
# T0	name 0 8	Beurrier
#
# T1	firstnames 9 21	p↑re↓ honoré
#
# T0	name 0 3	Deu
#
# T1	firstnames 4 14	j↑n↓ B↑te↓
#
# T2	familystatus 15 29	gendre mauciut
#
# T0	name 0 6	Guenot
#
# T1	firstnames 7 14	jacques
#
# T0	name 0 8	Chenevas
#
# T1	firstnames 9 24	Louis Fructidor
#
# T0	name 0 11	Chanterelle
#
# T1	firstnames 12 19	Nicolas
#
# T0	name 0 5	huart
#
# T1	firstnames 6 12	joseph
#
# T0	name 0 6	Mozeau
#
# T1	firstnames 7 20	ant↑ne↓ Louis
#
# T0	name 0 10	Betancourt
#
# T1	firstnames 11 18	antoine
#
# T0	name 0 8	Chanevas
#
# T1	firstnames 9 22	victor ch↑es↓
#
# T0	name 0 5	Vitry
#
# T1	firstnames 6 14	françois
#
# T2	name 15 26	et consorts
#
# T0	name 0 8	Laligéry
#
# T1	firstnames 9 24	Emmanuel désiré
#
# T0	name 0 7	Ancelet
#
# T1	firstnames 8 21	louis auguste
#
# T2	name 25 32	Rethers
#
# T3	firstnames 33 38	henri
#
# T0	name 0 10	Reuzeville
#
# T1	firstnames 11 25	charles alexis
#
# T0	name 0 7	Ancelet
#
# T1	firstnames 8 25	charles dominique
#
# T0	name 0 7	Laizier
#
# T1	firstnames 8 21	louis adolphe
#
# T0	name 0 8	Lalegéry
#
# T1	firstnames 9 21	denis joseph
#
# T0	name 0 6	Tardif
#
# T1	firstnames 7 14	Delorme
#
# T0	name 0 10	Beuzeville
#
# T1	firstnames 11 20	thimothée
#
# T2	familystatus 21 25	fils
#
# T0	name 0 5	Dumez
#
# T1	firstnames 6 15	théophile
#
# T0	name 0 7	Mackels
#
# T1	firstnames 8 13	henri
#
# T0	name 0 5	Ruvée
#
# T1	firstnames 6 14	Constant
#
# T0	name 0 8	Barberet
#
# T1	firstnames 9 23	pierre germain
#
# T0	name 0 7	Cochois
#
# T1	firstnames 8 14	alfred
#
# T0	name 0 6	Cuchet
#
# T1	firstnames 7 21	auguste Marius
#
# T0	name 0 7	Delorme
#
# T1	firstnames 8 15	édouard
#
# T0	name 0 3	Hue
#
# T1	firstnames 4 13	alexandre
#
# T0	name 0 7	Jeannin
#
# T1	firstnames 8 16	alphonse
#
# T0	name 0 5	Jarry
#
# T1	firstnames 6 13	onésime
#
# T0	name 0 9	Rousselle
#
# T1	firstnames 10 24	charles ernest
#
# T0	name 0 6	Michin
#
# T1	firstnames 7 14	auguste
#
# T0	name 0 6	Leroux
#
# T1	firstnames 7 20	auguste marie
#
# T0	name 0 7	Chamiot
#
# T1	firstnames 8 15	propser
#
# T0	name 0 9	Anastasie
#
# T0	name 0 8	Langlois
#
# T1	firstnames 9 16	Mathieu
#
# T2	familystatus 17 22	veuve
#
# T0	name 0 6	Gobert
#
# T1	firstnames 7 18	Marc Désiré
#
# T0	name 0 7	Delorme
#
# T1	firstnames 8 14	Benoît
#
# T0	name 0 7	Chenard
#
# T1	firstnames 8 16	Flotrien
#
# T0	name 0 7	Jacquin
#
# T1	firstnames 8 20	Claude Denis
#
# T0	name 0 6	Foulon
#
# T1	familystatus 7 12	Veuve
#
# T0	name 0 7	Pessoux
#
# T1	familystatus 8 12	Pere
#
# T0	name 0 4	Giot
#
# T1	familystatus 5 10	Veuve
#
# T0	name 0 7	Pessoux
#
# T1	familystatus 8 12	Pere
#
# T0	name 0 18	Commune de Santeny
#
# T0	name 0 7	Roussel
#
# T0	name 0 6	Laclos
#
# T1	familystatus 7 12	Veuve
#
# T0	name 0 4	Jary
#
# T1	firstnames 5 10	Louis
#
# T2	address 13 18	Paris
#
# T0	name 0 7	Therese
#
# T1	firstnames 8 13	Louis
#
# T0	name 0 4	Giot
#
# T1	familystatus 5 10	Veuve
#
# T0	name 0 7	Debesse
#
# T0	name 12 35	Le Prince→de Neufchâtel
#
# T1	title 0 5	S.A.S
#
# T2	title 6 11	M↑gr↓
#
# T0	name 0 9	Bainville
#
# T1	firstnames 10 22	p↑re↓ victor
#
# T0	name 0 7	Jacolet
#
# T1	firstnames 8 14	ursane
#
# T0	name 0 7	Chauvai
#
# T1	firstnames 8 14	pierre
#
# T0	name 0 7	Pommier
#
# T1	firstnames 8 15	gabriel
#
# T0	name 0 9	Marcellis
#
# T1	firstnames 10 22	pierre→ursin
#
# T0	name 1 7	L'Etat
#
# T1	name 9 31	Joinville (Commune de)
#
# T0	name 0 9	Bainville
#
# T1	firstnames 10 16	victor
#
# T0	name 0 7	Pigalet
#
# T1	familystatus 8 12	père
#
# T0	name 0 6	Cheret
#
# T1	firstnames 7 15	alphonse
#
# T0	name 0 7	Pigalet
#
# T1	familystatus 8 12	père
#
# T0	name 0 6	Cheret
#
# T1	firstnames 7 15	alphonse
#
# T0	name 0 8	Moignard
#
# T1	firstnames 9 21	J↑ques↓ P↑e↓
#
# T0	name 0 9	Bainville
#
# T1	firstnames 10 16	victor
#
# T0	name 0 8	Moignard
#
# T1	firstnames 9 21	J↑ques↓ P↑e↓
#
# T0	name 0 7	Mazarot
#
# T1	firstnames 8 14	Pierre
#
# T2	activity 15 37	M↑d↓ de Vin ou de lait
#
# T3	address 40 48	marolles
#
# T0	name 0 6	Guerin
#
# T1	firstnames 7 18	Jacq. henry
#
# T2	activity 19 24	maçon
#
# T3	address 27 29	id
#
# T0	name 0 7	Guillot
#
# T1	firstnames 8 14	Pierre
#
# T2	activity 15 21	Cultiv
#
# T3	address 24 26	id
#
# T0	name 0 7	Coudrai
#
# T1	firstnames 8 21	aug↑te↓ andré
#
# T2	activity 22 29	vig↑on↓
#
# T3	address 32 40	marolles
#
# T0	name 0 7	Galland
#
# T1	firstnames 8 18	↑françois↓
#
# T2	activity 29 36	vig↑on↓
#
# T3	address 39 41	id
#
# T4	name 0 7	Galland
#
# T5	firstnames 20 27	auguste
#
# T0	name 0 7	Galland
#
# T1	firstnames 30 35	Louis
#
# T2	activity 37 44	vig↑on↓
#
# T3	address 47 49	id
#
# T4	name 0 7	Galland
#
# T5	firstnames 18 26	françois
#
# T6	name 0 7	Galland
#
# T7	firstnames 9 16	auguste
#
# T0	name 0 7	Galland
#
# T1	firstnames 8 14	Pierre
#
# T2	activity 15 28	aux barrières
#
# T3	address 31 36	Paris
#
# T0	name 0 7	Galland
#
# T1	firstnames 8 19	Louis n↑as↓
#
# T2	activity 20 27	vig↑on↓
#
# T3	address 30 32	id
#
# T0	name 0 6	Guérin
#
# T1	firstnames 7 17	Jacq henry
#
# T2	activity 18 23	maçon
#
# T3	address 26 28	id
#
# T0	name 0 23	Le Prince de Neufchâtel
#
# T1	name 25 33	Vauguyon
#
# T2	activity 35 52	maire→de marolles
#
# T0	name 0 23	Le Prince de→neufchâtel
#
# T0	name 1 9	Vauguyon
#
# T1	activity 10 15	maire
#
# T0	name 0 8	Tourneur
#
# T1	firstnames 9 19	Barthel→my
#
# T2	activity 20 27	vig↑on↓
#
# T3	address 30 32	id
#
# T0	name 0 6	Guerin
#
# T1	firstnames 7 13	Joseph
#
# T2	activity 19 26	vig↑on↓
#
# T3	address 29 31	id
#
# T4	familystatus 14 18	père
#
# T0	name 1 9	Vauguyon
#
# T1	activity 11 16	maire
#
# T2	name 18 41	Le Prince de Neufchâtel
#
# T0	name 0 7	Massuet
#
# T1	firstnames 8 20	louis michel
#
# T0	name 0 5	Leduc
#
# T1	firstnames 6 18	pierre denis
#
# T0	name 0 8	Gabillot
#
# T1	firstnames 9 22	louis lambert
#
# T0	name 0 6	Mayeux
#
# T1	firstnames 7 22	pierre françois
#
# T0	name 0 8	Chatenay
#
# T1	firstnames 9 24	Jean Marie→abel
#
# T0	name 0 6	Fleury
#
# T1	firstnames 7 23	gabriel françois
#
# T0	name 0 10	Guillemain
#
# T1	firstnames 11 19	frédéric
#
# T2	address 22 27	Vitry
#
# T0	name 0 7	Massuet
#
# T1	firstnames 8 19	Jean Pierre
#
# T0	name 0 10	Moncouteau
#
# T1	firstnames 11 25	Claude lambert
#
# T0	name 0 7	Massuet
#
# T1	firstnames 8 27	↑cyr↓ J↑n↓ baptiste
#
# T0	name 0 6	Mayeux
#
# T1	firstnames 7 21	pierre f↑çois↓
#
# T0	name 0 8	Thévenot
#
# T1	firstnames 9 19	Jean louis
#
# T0	name 0 5	Pepin
#
# T1	firstnames 6 16	edme louis
#
# T0	name 0 17	Serre de St Roman
#
# T0	name 0 8	Delanoue
#
# T1	address 25 35	Versailles
#
# T2	familystatus 9 22	les→heritiers
#
# T0	name 0 10	St Arnoulx
#
# T0	name 0 10	St Arnoulx
#
# T1	address 30 40	Villepinte
#
# T2	name 12 17	Forge
#
# T3	activity 18 27	Bourgeois
#
# T0	name 0 10	St Arnoulx
#
# T0	name 1 6	Forgé
#
# T1	name 8 18	St Arnoulx
#
# T0	name 0 6	Grangé
#
# T0	name 0 10	St Arnoulx
#
# T0	name 0 6	Costly
#
# T1	firstnames 7 19	Jean Bap↑te↓
#
# T2	activity 20 39	tailleur→de pierres
#
# T3	address 42 55	Vil↑v↓ le Roy
#
# T0	name 0 8	françois
#
# T0	name 1 7	Grangé
#
# T1	name 9 16	Perault
#
# T2	activity 17 24	Maurice
#
# T0	name 0 7	Tellier
#
# T1	firstnames 8 21	pierre Cul↑t↓
#
# T2	address 24 29	ablon
#
# T0	name 0 10	St arnoulx
#
# T1	name 11 27	Guillaume→hector
#
# T2	activity 28 37	Bourgeois
#
# T3	address 40 45	ablon
#
# T0	name 0 5	Costy
#
# T1	firstnames 6 15	Jean Marc
#
# T2	activity 16 34	Tailleur→de pierre
#
# T3	address 37 42	ablon
#
# T0	name 0 5	Costy
#
# T1	firstnames 6 18	Jean Bap↑te↓
#
# T2	activity 19 37	tailleur de pierre
#
# T3	address 40 52	Vil↑v↓le Roy
#
# T0	name 0 5	Costy
#
# T1	firstnames 6 15	Jean Bapt
#
# T2	activity 16 34	tailleur→de pierre
#
# T3	address 37 54	Villeneuve le Roy
#
# T0	name 0 6	Grangé
#
# T1	firstnames 7 14	antoine
#
# T2	activity 15 25	aubergiste
#
# T3	address 28 33	ablon
#
# T0	name 1 11	St Arnoulx
#
# T1	name 13 18	Ayhan
#
# T2	firstnames 19 24	henry
#
# T3	activity 25 40	garde→champêtre
#
# T4	address 43 47	Orly
#
# T0	name 0 10	Braconnier
#
# T1	firstnames 11 17	pierre
#
# T2	activity 27 33	Cul↑v↓
#
# T3	address 36 53	Villeneuve le Roy
#
# T4	familystatus 18 26	la veuve
#
# T0	name 0 5	Costy
#
# T1	firstnames 6 18	Jean Bap↑te↓
#
# T2	activity 19 33	tail→de pierre
#
# T3	address 36 53	Villeneuve le Roy
#
# T0	name 0 7	Bracony
#
# T1	firstnames 8 15	antoine
#
# T2	activity 16 21	maçon
#
# T3	address 24 41	Villeneuve le Roy
#
# T0	name 0 19	François aubergiste
#
# T1	address 22 26	Orly
#
# T0	name 0 7	Barreau
#
# T1	firstnames 8 17	Guillaume
#
# T0	name 5 13	Courtois
#
# T1	familystatus 0 4	V↑e↓
#
# T0	name 0 6	Monier
#
# T1	activity 7 14	peintre
#
# T0	name 5 13	Lecolant
#
# T1	firstnames 14 24	al↑ cl↑de↓
#
# T2	familystatus 0 4	V↑e↓
#
# T0	name 1 5	fain
#
# T1	name 7 14	Pontois
#
# T2	firstnames 15 27	Jean paschal
#
# T0	name 6 13	Linotte
#
# T1	familystatus 1 5	V↑e↓
#
# T2	name 6 13	Linotte
#
# T3	familystatus 15 19	fils
#
# T0	name 5 9	Blin
#
# T1	familystatus 0 4	V↑e↓
#
# T0	name 0 17	hospices de Paris
#
# T0	name 0 8	malbezin
#
# T1	firstnames 9 17	alcistre
#
# T2	name 19 26	Menager
#
# T3	firstnames 27 36	laiturine
#
# T0	name 0 17	hospices de Paris
#
# T0	name 0 17	Fleury (ptassier)
#
# T1	firstnames 18 31	germain felix
#
# T0	name 0 8	Dufresne
#
# T1	firstnames 9 24	abel jean henry
#
# T0	name 0 7	Massuet
#
# T1	firstnames 8 21	louis gaspard
#
# T0	name 0 6	Cocher
#
# T1	firstnames 7 14	nicolas
#
# T0	name 0 4	J↑n↓
#
# T1	firstnames 5 18	J↑ques↓ denis
#
# T2	name 19 27	Godefroy
#
# T3	firstnames 28 45	denis Ch↑re↓ J↑n↓
#
# T0	name 0 8	Dufresne
#
# T1	firstnames 9 21	jean germain
#
# T0	name 1 7	Corday
#
# T1	address 10 15	Vitry
#
# T2	name 17 23	mayeux
#
# T3	address 26 35	Villejuif
#
# T0	name 0 5	Leroy
#
# T1	firstnames 6 19	louis georges
#
# T0	name 0 10	Lebourlier
#
# T1	firstnames 11 23	n↑as↓ hector
#
# T0	name 0 5	Leroy
#
# T1	firstnames 6 17	jean gilles
#
# T0	name 0 4	J↑n↓
#
# T1	firstnames 5 18	J↑ques↓ denis
#
# T2	name 19 27	Godefroy
#
# T3	firstnames 29 37	Denis ch
#
# T0	name 0 7	Boujard
#
# T1	address 10 15	Paris
#
# T0	name 0 7	Boujard
#
# T1	address 10 15	Paris
#
# T0	name 0 6	Prieur
#
# T1	firstnames 7 22	aimé J↑n↓ b↑te↓
#
# T0	name 0 7	Olivier
#
# T0	name 0 5	Lecoq
#
# T1	familystatus 6 11	maçon
#
# T0	name 0 7	Motheau
#
# T1	familystatus 8 22	h↑ers↓ Germain
#
# T2	name 23 33	et Consors
#
# T3	address 36 44	marolles
#
# T0	name 0 9	Vigoureux
#
# T1	firstnames 10 18	françois
#
# T2	activity 19 26	vig↑on↓
#
# T3	address 29 33	idem
#
# T0	name 0 6	Guérin
#
# T1	firstnames 7 13	Joseph
#
# T2	activity 19 26	vig↑on↓
#
# T3	address 29 31	id
#
# T4	familystatus 14 18	fils
#
# T0	name 0 9	Vigoureux
#
# T1	firstnames 10 21	J↑n↓ ant↑e↓
#
# T2	activity 22 31	militaire
#
# T0	name 0 6	Guérin
#
# T1	firstnames 12 19	Laurent
#
# T2	activity 20 27	vig↑on↓
#
# T3	address 30 32	id
#
# T4	familystatus 7 11	V↑e↓
#
# T0	name 0 9	Vigoureux
#
# T1	firstnames 10 17	Gabriel
#
# T2	activity 18 31	fab↑t↓ de bas
#
# T0	name 0 6	Bouton
#
# T1	firstnames 7 20	Charles→Louis
#
# T2	activity 21 30	fab, m↑d↓
#
# T3	address 33 38	Paris
#
# T0	name 0 6	Bouton
#
# T1	name 8 15	Le même
#
# T2	name 17 27	et consors
#
# T0	name 0 6	Guérin
#
# T1	firstnames 12 19	Laurent
#
# T2	activity 20 28	vig↑ons↓
#
# T3	address 31 39	marolles
#
# T4	familystatus 7 11	V↑e↓
#
# T0	name 0 6	Bouton
#
# T1	firstnames 7 20	charles louis
#
# T2	activity 21 30	fab, m↑d↓
#
# T3	address 33 38	Paris
#
# T0	name 0 6	Guérin
#
# T1	firstnames 7 19	ant↑e↓ Louis
#
# T0	name 0 6	Guérin
#
# T1	firstnames 7 19	Louis ant↑e↓
#
# T0	name 0 9	Vigoureux
#
# T1	firstnames 10 17	Gabriel
#
# T0	name 0 9	Vigoureux
#
# T1	firstnames 10 17	Gabriel
#
# T2	activity 18 31	fab↑t↓ de bas
#
# T3	address 34 42	marolles
#
# T0	name 0 8	Galland,
#
# T1	firstnames 9 16	auguste
#
# T2	activity 17 24	vig↑on↓
#
# T3	address 27 29	id
#
# T0	name 0 8	Galland,
#
# T1	firstnames 9 16	auguste
#
# T2	activity 17 24	vig↑on↓
#
# T3	address 27 29	id
#
# T0	name 0 7	Galland
#
# T1	firstnames 8 19	Louis n↑as↓
#
# T2	activity 20 26	vig↑on
#
# T3	address 29 31	id
#
# T0	name 1 9	Vauguyon
#
# T1	activity 36 53	maire de marolles
#
# T2	name 11 34	Le Prince de neufchâtel
#
# T0	name 0 5	Leroy
#
# T1	familystatus 7 22	fils de Clement
#
# T0	name 0 12	Haingnerelle
#
# T0	name 0 10	Montebelle
#
# T1	familystatus 11 22	la Duchesse
#
# T0	name 0 5	Leroy
#
# T1	firstnames 6 11	Louis
#
# T0	name 0 7	Noblet,
#
# T1	firstnames 8 13	N↑as↓
#
# T2	familystatus 14 19	Veuve
#
# T0	name 0 10	Montebello
#
# T1	familystatus 11 22	la Duchesse
#
# T0	name 0 5	Leroy
#
# T1	firstnames 6 19	Germain Louis
#
# T0	name 0 11	Bourdillat,
#
# T1	firstnames 12 23	J↑n↓ F↑ois↓
#
# T0	name 0 8	Perdrier
#
# T1	firstnames 10 24	vincent Pascal
#
# T0	name 0 7	Perrin,
#
# T1	firstnames 8 16	Constant
#
# T0	name 0 5	Jolly
#
# T1	firstnames 7 17	Jean Marie
#
# T0	name 0 6	Gallet
#
# T1	firstnames 8 19	Jean F↑ois↓
#
# T0	name 0 5	Faure
#
# T1	familystatus 7 15	le Comte
#
# T0	name 0 5	Jolly
#
# T1	firstnames 7 17	Jean Marie
#
# T0	name 6 15	Lhuillier
#
# T1	firstnames 17 24	nicolas
#
# T2	activity 26 33	vig↑on↓
#
# T3	address 37 45	marolles
#
# T4	address 49 53	brie
#
# T5	familystatus 0 5	veuve
#
# T0	name 0 7	Lemenil
#
# T1	firstnames 8 17	Euphrasie
#
# T2	address 26 28	id
#
# T3	familystatus 18 23	fille
#
# T0	name 0 9	Vigoureux
#
# T1	firstnames 10 17	Gabriel
#
# T2	activity 18 31	fab↑t↓ de bar
#
# T0	name 0 6	Guérin
#
# T1	firstnames 7 19	Louis ant↑e↓
#
# T2	activity 20 27	Vig↑on↓
#
# T3	address 30 32	id
#
# T0	name 0 11	Charpentier
#
# T1	firstnames 12 17	Louis
#
# T2	activity 18 23	maçon
#
# T3	address 26 28	id
#
# T0	name 0 6	Guérin
#
# T1	firstnames 7 19	Louis ant↑e↓
#
# T2	activity 20 28	vigneron
#
# T3	address 31 33	id
#
# T0	name 0 6	Guérin
#
# T1	firstnames 7 12	Louis
#
# T2	activity 13 22	voiturier
#
# T3	address 25 27	id
#
# T0	name 0 7	Soutier
#
# T1	activity 13 21	vigneron
#
# T2	address 24 32	marolles
#
# T3	familystatus 8 12	V↑e↓
#
# T0	name 0 6	Guérin
#
# T1	firstnames 12 19	Laurent
#
# T2	activity 20 27	vig↑on↓
#
# T3	address 30 32	id
#
# T4	familystatus 7 11	V↑e↓
#
# T0	name 0 19	Commune de→marolles
#
# T0	name 1 7	boulay
#
# T1	name 9 16	Thibout
#
# T2	firstnames 17 23	Joseph
#
# T0	name 1 7	Boulay
#
# T1	familystatus 30 37	Meurthe
#
# T2	name 15 21	Tibout
#
# T3	firstnames 22 28	Joseph
#
# T0	name 0 23	Le Prince de neufchâtel
#
# T1	name 25 33	Vauguyon
#
# T2	activity 35 53	maire→de marolles±
#
# T0	name 1 7	Boulay
#
# T1	address 24 31	Meurthe
#
# T2	name 15 22	Thibout
#
# T3	firstnames 33 39	Joseph
#
# T0	name 0 8	Berthier
#
# T1	firstnames 9 18	alex↑dre↓
#
# T2	title 19 39	Prince de neufchâtel
#
# T0	name 0 7	Thibout
#
# T1	firstnames 8 14	Joseph
#
# T2	name 16 22	Boulay
#
# T3	address 29 36	Meurthe
#
# T0	name 0 8	Berthier
#
# T1	firstnames 9 18	alex↑dre↓
#
# T2	title 19 39	Prince de neufchâtel
#
# T0	name 0 8	Courière
#
# T1	firstnames 9 18	françoise
#
# T0	name 0 8	Mérillon
#
# T0	name 0 7	Ancelet
#
# T1	firstnames 8 13	André
#
# T0	name 0 6	Subtil
#
# T1	firstnames 7 19	Denis Pierre
#
# T0	name 0 8	Mérillon
#
# T1	firstnames 9 14	félix
#
# T0	name 0 7	Ancelet
#
# T1	firstnames 8 28	nicolas, dit Ancelon
#
# T2	familystatus 29 34	Veuve
#
# T0	name 0 6	Lameau
#
# T1	firstnames 7 21	Marie Saturnin
#
# T2	activity 23 28	f↑dre
#
# T3	address 30 35	Vitry
#
# T0	name 0 9	Mouscadet
#
# T1	firstnames 10 25	Pierre Grégoire
#
# T2	address 28 36	fontenay
#
# T0	name 0 6	Berger
#
# T1	firstnames 7 15	Baptiste
#
# T0	name 0 6	Bosset
#
# T1	firstnames 7 12	félix
#
# T2	address 16 21	Paris
#
# T0	name 0 8	Saussary
#
# T1	familystatus 9 13	fils
#
# T0	name 0 5	Robin
#
# T1	firstnames 6 15	Toussaint
#
# T2	address 19 27	fontenay
#
# T0	name 0 6	Berger
#
# T1	firstnames 7 18	Louis Simon
#
# T0	name 0 7	Surault
#
# T1	firstnames 8 12	Jean
#
# T2	address 16 24	fontenay
#
# T0	name 0 5	Leduc
#
# T1	firstnames 6 17	Jean Pierre
#
# T0	name 0 6	Berger
#
# T1	firstnames 7 18	Jean pierre
#
# T0	name 0 5	André
#
# T1	firstnames 6 23	alexandre Edouard
#
# T0	name 0 8	Barillet
#
# T1	firstnames 9 20	paul désiré
#
# T0	name 0 7	Ancelot
#
# T1	firstnames 8 20	Nicolas J↑h↓
#
# T0	name 0 6	Lameau
#
# T1	firstnames 7 20	Jean Saturnin
#
# T0	name 0 8	Soudieux
#
# T1	firstnames 9 21	louis joseph
#
# T0	name 0 6	Lameau
#
# T1	firstnames 7 18	Louis Jules
#
# T0	name 0 8	Barillet
#
# T1	firstnames 9 20	louis jules
#
# T0	name 0 6	Hériot
#
# T1	firstnames 7 13	justin
#
# T0	name 0 8	Barillet
#
# T1	firstnames 9 22	alphonse léon
#
# T0	name 0 5	Vitry
#
# T1	firstnames 6 21	Joseph Emmanuel
#
# T2	familystatus 22 26	V↑e↓
#
# T0	name 0 6	Rameau
#
# T1	firstnames 7 19	Louis honoré
#
# T0	name 0 8	Fontaine
#
# T0	name 0 5	Padet
#
# T1	firstnames 6 12	alfred
#
# T0	name 0 13	Baton mercier
#
# T0	name 0 7	Laurent
#
# T1	firstnames 8 14	eugène
#
# T0	name 0 8	Soudieux
#
# T1	firstnames 9 24	adolphe laurent
#
# T0	name 0 9	Bidermann
#
# T1	firstnames 10 14	Jean
#
# T0	name 0 6	Picard
#
# T1	firstnames 7 13	Ernest
#
# T0	name 0 7	Laurent
#
# T1	firstnames 8 14	eugène
#
# T0	name 0 8	Barillet
#
# T1	firstnames 9 23	eugène auguste
#
# T0	name 0 5	Morin
#
# T1	firstnames 6 19	louis auguste
#
# T0	name 0 8	Mérillon
#
# T1	firstnames 9 17	saturnin
#
# T2	title 18 23	veuve
#
# T0	name 0 6	Gasser
#
# T1	firstnames 7 21	auguste victor
#
# T0	name 0 13	Voie publique
#
# T1	address 15 33	chemin de S↑t↓ Mau
#
# T0	name 0 6	Michel
#
# T1	firstnames 7 12	Louis
#
# T0	name 0 8	Cheminat
#
# T1	firstnames 26 29	Ida
#
# T2	familystatus 9 14	Veuve
#
# T3	birthname 19 25	Sperts
#
# T0	name 0 8	Valignon
#
# T1	firstnames 9 17	Philippe
#
# T0	name 0 5	Poles
#
# T1	firstnames 6 19	Léon augustin
#
# T0	name 0 8	Fourtier
#
# T1	firstnames 9 16	onésime
#
# T0	name 0 6	Polack
#
# T1	firstnames 7 13	Joseph
#
# T0	name 0 6	Pitoux
#
# T1	firstnames 7 27	flavien oscar alexis
#
# T0	name 0 6	Grisot
#
# T1	firstnames 7 15	françois
#
# T0	name 0 7	Regnier
#
# T1	firstnames 8 21	Eugène Benoit
#
# T0	name 0 6	Lequis
#
# T1	firstnames 7 26	Jean Jacques Xavier
#
# T0	name 0 9	Grandjean
#
# T1	familystatus 10 14	fils
#
# T0	name 0 9	Dominique
#
# T1	firstnames 10 16	Michel
#
# T0	name 0 8	Michalet
#
# T1	firstnames 9 21	Marc antoine
#
# T0	name 0 8	Pourreau
#
# T1	firstnames 9 16	auguste
#
# T2	name 19 26	Etienne
#
# T3	firstnames 27 35	Théodore
#
# T0	name 0 5	Morin
#
# T1	firstnames 6 20	Isidore amédée
#
# T0	name 0 6	allary
#
# T1	firstnames 7 21	auguste armand
#
# T0	name 0 8	Chotteau
#
# T1	firstnames 9 27	henri charles J↑h↓
#
# T0	name 0 6	Poirez
#
# T1	firstnames 7 13	xavier
#
# T0	name 0 6	Billot
#
# T1	firstnames 7 13	Michel
#
# T0	name 0 8	Persicot
#
# T1	firstnames 9 15	adrien
#
# T0	name 0 2	id
#
# T1	firstnames 3 13	(Fourtier)
#
# T0	name 0 15	Pain - et - Vin
#
# T0	name 0 5	Robin
#
# T1	firstnames 6 12	pierre
#
# T0	name 0 9	Couvertet
#
# T1	firstnames 10 16	martin
#
# T2	activity 17 24	Vig↑on↓
#
# T3	address 27 37	chenevière
#
# T0	name 0 6	Gachet
#
# T1	firstnames 7 13	pierre
#
# T0	name 0 7	Brumeau
#
# T1	firstnames 8 15	Etienne
#
# T0	name 0 5	Robin
#
# T1	firstnames 6 12	pierre
#
# T0	name 0 6	Gasset
#
# T1	firstnames 7 13	martin
#
# T2	activity 14 21	Vig↑on↓
#
# T3	address 24 35	chenevières
#
# T0	name 0 5	Nasse
#
# T1	firstnames 6 16	J↑n↓ B↑te↓
#
# T0	name 0 7	Germoud
#
# T1	firstnames 8 25	l↑ele↓ félix J↑e↓
#
# T0	name 0 7	Guiniot
#
# T1	firstnames 8 17	J↑n↓ B↑t↓
#
# T2	activity 18 31	m↑d↓→Merecier
#
# T3	address 34 44	chenevière
#
# T0	name 0 9	Desgrange
#
# T0	name 0 5	Veron
#
# T1	firstnames 6 18	J↑n↓ J↑ques↓
#
# T0	name 0 9	Giraudeau
#
# T1	firstnames 10 15	louis
#
# T0	name 0 13	voie publique
#
# T0	name 0 5	Biard
#
# T1	firstnames 6 20	raphaël julien
#
# T0	name 0 13	voie publique
#
# T0	name 0 8	Fontaine
#
# T1	firstnames 9 22	françois J↑h↓
#
# T0	name 0 5	Biard
#
# T1	firstnames 6 20	raphaël julien
#
# T0	name 0 13	voie publique
#
# T0	name 0 6	Victor
#
# T1	firstnames 7 13	Désiré
#
# T0	name 0 7	Ancelot
#
# T1	firstnames 8 25	charles dominique
#
# T0	name 0 9	Giraudeau
#
# T1	firstnames 10 15	louis
#
# T0	name 0 5	Vitry
#
# T1	firstnames 6 26	Jean B↑te↓ alexandre
#
# T0	name 0 8	Barillet
#
# T1	firstnames 9 20	paul désiré
#
# T0	name 0 9	Héricourt
#
# T1	firstnames 10 17	gabriel
#
# T0	name 0 8	Barillet
#
# T1	firstnames 9 20	louis jules
#
# T0	name 0 9	Bachereau
#
# T1	firstnames 10 24	léopold arsène
#
# T0	name 0 8	Misgault
#
# T1	firstnames 9 20	Léon michel
#
# T0	name 0 7	Ancelet
#
# T1	firstnames 8 24	françois antoine
#
# T0	name 0 13	voie publique
#
# T0	name 0 7	Prinbel
#
# T0	name 0 9	Bachereau
#
# T1	firstnames 10 24	Léopold arsène
#
# T0	name 0 13	voie publique
#
# T0	name 0 8	Coiffier
#
# T1	firstnames 9 22	pierre honoré
#
# T0	name 0 6	Rameau
#
# T1	firstnames 7 20	Jean françois
#
# T0	name 0 7	Ancelet
#
# T1	firstnames 8 25	charles dominique
#
# T0	name 0 7	Laizier
#
# T1	firstnames 8 21	louis adolphe
#
# T0	name 0 8	Chaillou
#
# T1	firstnames 9 22	pierre julien
#
# T0	name 0 8	Chaillou
#
# T1	firstnames 9 23	Louis frédéric
#
# T0	name 0 6	Landry
#
# T0	name 0 9	Outrequin
#
# T0	name 0 6	Maufra
#
# T1	address 9 14	Paris
#
# T0	name 0 5	Mozet
#
# T1	firstnames 6 15	patissier
#
# T0	name 0 17	Gouvernement (le)
#
# T0	name 0 5	Petit
#
# T1	firstnames 6 19	pierre F↑ois↓
#
# T0	name 0 8	Chaillou
#
# T1	firstnames 9 22	pierre julien
#
# T0	name 0 8	Chaillou
#
# T1	firstnames 9 27	J↑ques↓ J↑n↓ marie
#
# T0	name 0 8	Chaillou
#
# T1	firstnames 9 22	pierre Julien
#
# T0	name 0 7	Bauchet
#
# T1	firstnames 8 18	jean louis
#
# T0	name 0 8	Boulogne
#
# T1	firstnames 9 23	philippe henry
#
# T0	name 0 7	Menager
#
# T1	firstnames 8 24	Jean Denis Josée
#
# T0	name 0 10	Coulombier
#
# T1	firstnames 11 18	J↑ques↓
#
# T2	familystatus 19 25	H↑ers↓
#
# T0	name 0 6	Aubauf
#
# T1	familystatus 7 11	V↑e↓
#
# T0	name 0 8	Bonnelet
#
# T1	firstnames 9 14	p↑re↓
#
# T0	name 0 7	Grognet
#
# T1	firstnames 8 18	J↑n↓ Denis
#
# T0	name 0 8	Thevenot
#
# T1	firstnames 9 18	J↑n↓ L↑s↓
#
# T0	name 0 7	Grognet
#
# T1	firstnames 8 10	L.
#
# T0	name 0 6	Moreau
#
# T1	firstnames 7 14	J↑ques↓
#
# T0	name 0 8	Thevenot
#
# T1	firstnames 9 15	P↑r↓ L
#
# T0	name 0 6	Cretté
#
# T1	firstnames 7 20	J↑n↓ Touss↑t↓
#
# T0	name 0 4	Sian
#
# T0	name 0 6	Goyard
#
# T1	firstnames 7 25	Gervais det Brunot
#
# T0	name 0 6	Mayeux
#
# T1	firstnames 7 12	P↑re↓
#
# T2	familystatus 13 18	Cadet
#
# T0	name 0 6	Cretté
#
# T1	firstnames 7 11	J↑n↓
#
# T0	name 0 8	Chatenay
#
# T1	firstnames 9 16	Germain
#
# T0	name 0 7	Chabots
#
# T0	name 0 8	Delanoue
#
# T1	familystatus 9 13	V↑e↓
#
# T0	name 0 8	Bonnelet
#
# T1	firstnames 9 14	P↑re↓
#
# T0	name 0 7	Caillet
#
# T1	firstnames 8 19	J↑n↓ Joseph
#
# T0	name 0 7	Michaud
#
# T1	firstnames 8 15	Germain
#
# T0	name 0 6	Cretté
#
# T1	firstnames 7 20	J↑n↓ Valentin
#
# T0	name 0 4	Lamy
#
# T1	firstnames 5 12	J↑ques↓
#
# T0	name 0 7	Jouette
#
# T1	firstnames 8 18	J↑n↓ Marie
#
# T0	name 0 5	Duval
#
# T1	firstnames 6 13	Gervais
#
# T0	name 0 9	Boulanger
#
# T1	firstnames 10 17	J P↑re↓
#
# T0	name 9 15	Dubois
#
# T1	title 0 8	Le Comte
#
# T0	name 0 8	Duchange
#
# T1	firstnames 9 16	Charles
#
# T0	name 0 9	Lachausse
#
# T1	firstnames 10 17	Laurent
#
# T0	name 0 5	Huard
#
# T1	firstnames 6 10	J↑n↓
#
# T0	name 0 8	Vaudayer
#
# T1	firstnames 9 16	Gervais
#
# T0	name 0 5	Amiot
#
# T1	firstnames 6 15	L. F↑ois↓
#
# T2	familystatus 16 21	Veuve
#
# T0	name 0 9	Letellier
#
# T1	firstnames 10 17	Germain
#
# T2	familystatus 18 24	h↑ers↓
#
# T0	name 0 5	Talon
#
# T1	firstnames 6 14	gendarme
#
# T0	name 0 6	Viénos
#
# T1	firstnames 7 18	J↑n↓ f↑ois↓
#
# T0	name 0 6	Guérin
#
# T1	firstnames 7 21	L↑n↓ ferm↑ier↓
#
# T0	name 0 8	François
#
# T1	firstnames 9 13	J↑n↓
#
# T2	familystatus 14 27	fils de→p↑re↓
#
# T3	familystatus 28 42	gendre videard
#
# T0	name 0 8	Esterbes
#
# T1	firstnames 9 19	G↑n↓ f↑on↓
#
# T2	address 20 28	fontenay
#
# T0	name 0 8	François
#
# T1	firstnames 9 19	p↑re↓ p↑i↓
#
# T2	familystatus 20 33	fils→de p↑re↓
#
# T3	familystatus 34 48	g↑dre↓ vidiard
#
# T0	name 0 8	Beriault
#
# T1	firstnames 9 19	J↑n↓ L↑is↓
#
# T0	name 0 7	Bérault
#
# T1	firstnames 8 14	michel
#
# T0	name 0 7	Bérault
#
# T1	firstnames 8 18	J↑n↓ L↑is↓
#
# T0	name 0 8	Blondeau
#
# T1	firstnames 9 19	J↑n↓ L↑is↓
#
# T0	name 0 7	hédelin
#
# T1	firstnames 8 21	J↑n↓ corentin
#
# T0	name 0 6	Ledoux
#
# T1	firstnames 7 22	nicolas vincent
#
# T0	name 0 6	Ledoux
#
# T1	firstnames 7 22	nicolas vincent
#
# T0	name 0 10	Piton hort
#
# T1	firstnames 10 20	ense marie
#
# T2	address 31 39	fontenay
#
# T3	familystatus 21 28	mineure
#
# T0	name 0 18	Cassen de Ciablice
#
# T1	firstnames 19 41	augustin marie sylvain
#
# T2	address 42 47	Paris
#
# T0	name 0 8	Delanoue
#
# T1	firstnames 9 24	marie geneviève
#
# T2	address 35 40	Paris
#
# T3	title 26 33	d↑elle↓
#
# T0	name 0 6	Boutté
#
# T1	firstnames 7 27	Charles Joseph denis
#
# T2	address 29 34	Paris
#
# T3	familystatus 36 41	Veuve
#
# T0	name 0 5	Leleu
#
# T1	firstnames 6 17	hubert Noël
#
# T2	address 19 24	Paris
#
# T0	name 0 5	Piors
#
# T1	firstnames 6 14	augustin
#
# T2	title 16 20	V↑e↓
#
# T0	name 0 5	Leleu
#
# T1	firstnames 6 17	hubert Noël
#
# T2	address 19 24	Paris
#
# T0	name 0 6	Durand
#
# T1	firstnames 7 19	Jean Etienne
#
# T2	address 35 42	bicètre
#
# T3	familystatus 21 31	les h↑ers↓
#
# T0	name 0 8	Delanoue
#
# T1	firstnames 9 18	Toussaint
#
# T2	address 20 24	Orly
#
# T0	name 0 7	Pigeron
#
# T1	address 9 14	Paris
#
# T0	name 0 5	Couté
#
# T1	firstnames 6 18	Jean Jacques
#
# T0	name 0 6	hébert
#
# T1	firstnames 7 12	Louis
#
# T2	address 19 23	Orly
#
# T3	familystatus 13 17	V↑e↓
#
# T0	name 6 13	Lérault
#
# T1	address 31 36	Paris
#
# T2	title 0 5	Mm↑e↓
#
# T3	familystatus 14 17	V↑e
#
# T4	birthname 24 29	Véron
#
# T0	name 0 24	Leroy de la Brière Furcy
#
# T1	firstnames 25 38	marie nicolas
#
# T2	address 40 44	Orly
#
# T0	name 0 6	Basset
#
# T1	firstnames 7 15	Philippe
#
# T2	address 23 28	yères
#
# T3	familystatus 17 21	V↑e↓
#
# T0	name 0 7	Bordier
#
# T1	firstnames 8 14	Pierre
#
# T2	activity 15 22	vig↑on↓
#
# T3	address 25 33	marolles
#
# T0	name 0 9	Piedquin
#
# T1	firstnames 9 21	f↑ois↓ marie
#
# T2	activity 22 28	Charon
#
# T3	address 31 48	brie-comte robert
#
# T0	name 0 10	La Commune
#
# T0	name 0 8	Tourneur
#
# T1	firstnames 9 19	Barthelemy
#
# T2	activity 20 27	vig↑on↓
#
# T0	name 0 7	Lefevre
#
# T1	firstnames 8 15	Jacques
#
# T2	name 17 25	Piedquin
#
# T3	firstnames 27 39	f↑ois↓ marie
#
# T4	activity 40 46	Charon
#
# T5	address 49 66	Brie comte→Robert
#
# T0	name 0 8	Lefevre,
#
# T1	firstnames 9 16	Jacques
#
# T2	activity 17 24	adjoint
#
# T0	name 0 9	Piedquin,
#
# T1	firstnames 10 22	f↑ois↓ marie
#
# T2	activity 23 29	Charon
#
# T3	address 32 36	Brie
#
# T0	name 0 7	Lefevre
#
# T1	firstnames 8 15	Jacques
#
# T2	activity 16 35	adjoint de marolles
#
# T0	name 0 9	Berthier
#
# T1	firstnames 9 18	alex↑dre↓
#
# T2	title 19 24	M↑gr↓
#
# T3	title 25 45	Prince de neufchâtel
#
# T0	name 0 4	idem
#
# T1	name 6 14	Vauguyon
#
# T2	activity 15 32	maire de marolles
#
# T0	name 0 7	Bronzac
#
# T1	firstnames 8 14	pierre
#
# T0	name 0 7	Detinte
#
# T1	firstnames 8 14	JUlien
#
# T2	familystatus 15 19	v↑e↓
#
# T3	name 20 26	Cousin
#
# T0	name 0 5	Angot
#
# T1	firstnames 6 16	J↑n↓ B↑te↓
#
# T2	familystatus 17 21	père
#
# T0	name 0 10	Pierreloth
#
# T0	name 0 19	Commune→de marolles
#
# T0	name 0 23	Le Prince de Neufchâtel
#
# T1	name 25 33	Vauguyon
#
# T2	activity 34 51	maire de marolles
#
# T0	name 0 19	Commune de→Marolles
#
# T0	name 0 23	Le Prince de Neufchâtel
#
# T1	name 25 33	Vauguyon
#
# T2	activity 34 51	maire→de marolles
#
# T0	name 0 6	Guérin
#
# T1	firstnames 7 12	Louis
#
# T2	activity 13 22	voiturier
#
# T3	address 25 33	marolles
#
# T0	name 0 7	Soulier
#
# T1	firstnames 13 20	Georges
#
# T2	address 23 31	marolles
#
# T3	familystatus 8 12	V↑e↓
#
# T0	name 0 6	Moreau
#
# T1	firstnames 7 14	Germain
#
# T2	activity 15 23	Bucheron
#
# T3	address 26 34	Marolles
#
# T0	name 0 6	Gugnot
#
# T1	firstnames 7 18	J↑n↓ Claude
#
# T0	name 0 8	Enjalvan
#
# T0	name 0 9	Mentienne
#
# T1	firstnames 10 19	alex↑dre↓
#
# T0	name 0 7	Benoist
#
# T1	firstnames 8 17	J↑h↓ J↑n↓
#
# T0	name 0 9	Mentienne
#
# T1	firstnames 10 20	J↑n↓ Louis
#
# T0	name 0 8	Jourdain
#
# T1	firstnames 9 19	J↑n↓ Louis
#
# T2	familystatus 20 25	Veuve
#
# T0	name 0 9	Perrigaut
#
# T1	firstnames 10 21	andré F↑is↓
#
# T0	name 0 7	Sellier
#
# T1	firstnames 8 23	J↑ques↓ Georges
#
# T0	name 0 5	Quevu
#
# T1	firstnames 6 18	F↑ois↓ N↑as↓
#
# T0	name 0 6	Basire
#
# T1	firstnames 7 15	guill↑e↓
#
# T2	familystatus 16 21	Veuve
#
# T0	name 0 5	Queru
#
# T1	firstnames 6 17	P↑re↓ marie
#
# T0	name 0 6	Benoit
#
# T1	firstnames 7 16	alex↑dre↓
#
# T0	name 0 8	Metivier
#
# T1	firstnames 9 20	Louis F↑re↓
#
# T0	name 0 7	Garreau
#
# T1	firstnames 8 21	Louise michel
#
# T0	name 0 9	Mentienne
#
# T1	firstnames 10 23	Louis gervais
#
# T0	name 0 7	Sellier
#
# T1	firstnames 8 18	F↑s↓ marie
#
# T0	name 0 7	Desnyau
#
# T1	firstnames 8 22	J↑n↓ Alex↑dre↓
#
# T0	name 0 6	Marbot
#
# T1	familystatus 8 16	le Baron
#
# T0	name 0 9	Delaville
#
# T1	firstnames 10 16	Leroux
#
# T0	name 0 10	Desgrouets
#
# T1	firstnames 11 17	B.↑te↓
#
# T0	name 0 8	ferriere
#
# T1	firstnames 9 15	pierre
#
# T2	name 17 25	Courtois
#
# T3	firstnames 32 37	Louis
#
# T4	familystatus 26 31	Veuve
#
# T0	name 0 7	Pilleux
#
# T1	firstnames 19 27	Julienne
#
# T2	familystatus 28 33	fille
#
# T3	name 9 17	Courtois
#
# T0	name 0 7	Jarrier
#
# T1	firstnames 8 15	Joseph
#
# T2	activity 23 30	fermier
#
# T3	activity 16 21	V↑on↓
#
# T4	address 34 40	Oravel
#
# T0	name 0 7	Barreau
#
# T1	firstnames 8 12	G↑me
#
# T2	activity 14 19	maçon
#
# T3	address 22 30	Valenton
#
# T0	name 0 8	Chalopin
#
# T1	activity 9 17	batelier
#
# T0	name 0 4	Mayé
#
# T1	familystatus 5 10	Veuve
#
# T0	name 0 7	Barreau
#
# T1	firstnames 8 12	G↑me
#
# T2	activity 14 19	maçon
#
# T0	name 0 7	Jarrier
#
# T1	firstnames 8 14	Joseph
#
# T0	name 0 5	Belin
#
# T1	familystatus 6 11	Veuve
#
# T0	name 0 8	Gauthier
#
# T1	firstnames 9 14	Louis
#
# T2	address 17 25	Valenton
#
# T0	name 0 5	Seble
#
# T1	firstnames 6 13	Nicolas
#
# T0	name 0 7	Barreau
#
# T1	firstnames 8 13	G↑me↓
#
# T2	address 16 24	Valenton
#
# T0	name 0 10	Bouttenois
#
# T1	name 12 21	Thuillier
#
# T2	firstnames 22 27	Louis
#
# T0	name 0 7	Mitauls
#
# T1	firstnames 8 12	Jean
#
# T2	address 14 32	route de Charenton
#
# T0	name 0 7	Mitauls
#
# T1	firstnames 8 12	Jean
#
# T2	address 13 15	id
#
# T0	name 0 7	Mitauls
#
# T1	firstnames 8 12	Jean
#
# T2	address 13 15	id
#
# T0	name 0 7	Mitauls
#
# T1	firstnames 8 12	Jean
#
# T2	activity 13 15	id
#
# T0	name 0 7	Mitauls
#
# T1	firstnames 8 12	Jean
#
# T2	address 13 15	id
#
# T0	name 0 7	Mitauls
#
# T1	firstnames 8 12	Jean
#
# T2	address 13 15	id
#
# T0	name 0 7	Mitauls
#
# T1	firstnames 8 12	Jean
#
# T2	address 13 15	id
#
# T0	name 0 7	Mitauls
#
# T1	firstnames 8 12	Jean
#
# T2	address 13 15	id
#
# T0	name 0 7	Mitauls
#
# T1	firstnames 8 12	Jean
#
# T2	address 13 15	id
#
# T0	name 0 7	Mitauls
#
# T1	firstnames 8 12	Jean
#
# T2	address 13 15	id
#
# T0	name 0 7	Mitauls
#
# T1	firstnames 8 12	Jean
#
# T2	address 13 15	id
#
# T0	name 0 7	Mitauls
#
# T1	firstnames 8 12	Jean
#
# T2	address 13 15	id
#
# T0	name 0 7	Mitauls
#
# T1	firstnames 8 12	Jean
#
# T2	address 13 15	id
#
# T0	name 0 7	Mitauls
#
# T1	firstnames 8 12	Jean
#
# T2	address 13 15	id
#
# T0	name 0 7	Mitauls
#
# T1	firstnames 8 12	Jean
#
# T2	address 13 15	id
#
# T0	name 0 7	Mitauls
#
# T1	firstnames 8 12	Jean
#
# T2	address 13 15	id
#
# T0	name 0 7	Mitauls
#
# T1	firstnames 8 12	Jean
#
# T2	address 13 15	id
#
# T0	name 0 7	Mitauls
#
# T1	firstnames 8 12	Jean
#
# T2	address 13 15	id
#
# T0	name 0 7	Mitauls
#
# T1	firstnames 8 12	Jean
#
# T2	address 13 15	id
#
# T0	name 0 7	Mitauls
#
# T1	firstnames 8 12	Jean
#
# T2	address 13 15	id
#
# T0	name 0 7	Mitauls
#
# T1	firstnames 8 12	Jean
#
# T2	address 13 15	id
#
# T0	name 0 7	Mitauls
#
# T1	firstnames 8 12	Jean
#
# T2	address 13 15	id
#
# T0	name 0 7	Mitauls
#
# T1	firstnames 8 12	Jean
#
# T2	address 13 15	id
#
# T0	name 0 7	Mitauls
#
# T1	firstnames 8 12	Jean
#
# T2	address 13 15	id
#
# T0	name 0 9	Vigoureux
#
# T1	firstnames 10 18	françois
#
# T2	activity 19 26	vig↑on↓
#
# T3	address 29 37	marolles
#
# T0	name 0 6	Huguet
#
# T1	firstnames 7 12	Louis
#
# T2	activity 13 20	Vig↑on↓
#
# T3	address 23 25	id
#
# T0	name 0 7	Coudrau
#
# T1	firstnames 8 21	aug↑te↓ andré
#
# T2	activity 22 29	vig↑on↓
#
# T3	address 32 36	idem
#
# T0	name 0 8	Guillot,
#
# T1	firstnames 9 15	Pierre
#
# T2	activity 16 22	Cultiv
#
# T3	address 25 33	marolles
#
# T0	name 0 5	Bonne
#
# T1	firstnames 6 13	hercule
#
# T2	activity 14 23	serrurier
#
# T3	address 26 28	id
#
# T0	name 0 7	Guillot
#
# T1	firstnames 8 14	Pierre
#
# T2	activity 15 21	cultiv
#
# T3	address 24 28	idem
#
# T0	name 0 5	Bonne
#
# T1	firstnames 6 13	hercule
#
# T2	activity 14 23	serrurier
#
# T3	address 26 28	id
#
# T0	name 0 7	Beaulh,
#
# T1	firstnames 13 18	ant↑e
#
# T2	activity 20 27	vig↑on↓
#
# T3	address 30 32	id
#
# T4	familystatus 8 12	V↑e↓
#
# T0	name 0 23	Le Prince de neufchâtel
#
# T1	name 25 33	Vauguyon
#
# T2	activity 34 51	maire de marolles
#
# T0	name 0 6	Guérin
#
# T1	firstnames 7 13	Joseph
#
# T2	activity 19 26	vig↑on↓
#
# T3	address 29 31	id
#
# T4	familystatus 14 18	fils
#
# T0	name 0 9	Vigoureux
#
# T1	firstnames 10 17	Gabriel
#
# T2	activity 18 31	fab↑t↓ de bas
#
# T3	address 34 36	id
#
# T0	name 0 9	Vigoureux
#
# T1	firstnames 10 17	Gabriel
#
# T2	activity 18 31	fab↑t↓ de bas
#
# T3	address 34 36	id
#
# T0	name 0 9	Vigoureux
#
# T1	firstnames 10 21	Jean→ant↑e↓
#
# T2	activity 22 31	militaire
#
# T0	name 0 6	Goulas
#
# T1	firstnames 7 20	eugène arsène
#
# T0	name 0 8	Salanson
#
# T1	name 9 20	et consorts
#
# T0	name 0 4	Pair
#
# T1	firstnames 5 11	lazare
#
# T0	name 0 7	Mabilat
#
# T1	firstnames 8 13	simon
#
# T0	name 0 6	l'Etat
#
# T0	name 0 6	Ripaux
#
# T1	firstnames 7 23	Jean rené victor
#
# T0	name 0 6	Radice
#
# T1	firstnames 7 13	angélo
#
# T0	name 0 7	Mauduit
#
# T1	firstnames 8 20	louis romain
#
# T0	name 0 7	Poinsot
#
# T1	firstnames 8 14	pierre
#
# T0	name 5 10	véron
#
# T1	firstnames 21 26	Julie
#
# T2	familystatus 0 4	d↑e↓
#
# T3	birthname 15 20	Labbé
#
# T0	name 0 4	Sève
#
# T1	firstnames 5 12	antoine
#
# T0	name 0 6	Pretet
#
# T1	firstnames 7 26	Jean B↑te↓ théodore
#
# T0	name 0 7	Lorquin
#
# T1	firstnames 8 15	casimir
#
# T0	name 0 8	Rignault
#
# T1	firstnames 9 23	Jacques victor
#
# T0	name 5 10	véron
#
# T1	firstnames 21 26	Julie
#
# T2	familystatus 0 4	d↑e↓
#
# T3	birthname 15 20	Labbé
#
# T0	name 0 4	Witz
#
# T1	firstnames 5 12	vincent
#
# T0	name 0 8	Philippe
#
# T1	firstnames 9 26	charles alexandre
#
# T0	name 0 6	Hureau
#
# T1	firstnames 7 32	alfred anatole tranquille
#
# T0	name 0 8	Lemasson
#
# T1	firstnames 9 16	hilaire
#
# T0	name 0 4	Piot
#
# T1	firstnames 5 9	edme
#
# T0	name 0 9	Jeanneret
#
# T1	firstnames 10 23	Jean Baptiste
#
# T0	name 0 6	Viroux
#
# T1	firstnames 7 19	Jules Joseph
#
# T0	name 0 6	Imhoff
#
# T1	firstnames 7 14	leopold
#
# T0	name 0 8	Salanson
#
# T1	name 9 20	et consorts
#
# T0	name 0 8	Wacquant
#
# T1	firstnames 9 19	Jean B↑te↓
#
# T0	name 0 9	Delaporte
#
# T1	firstnames 10 23	felix aug↑te↓
#
# T0	name 0 9	Delaporte
#
# T1	firstnames 10 23	félix aug↑te↓
#
# T0	name 0 7	Saintin
#
# T1	firstnames 8 12	Cuny
#
# T0	name 0 7	Saintin
#
# T1	firstnames 8 12	Cuny
#
# T0	name 0 8	Desilles
#
# T1	firstnames 9 28	pierre V↑e↓ léonard
#
# T0	name 0 8	Desilles
#
# T1	firstnames 9 28	pierre V↑e↓ léonard
#
# T0	name 0 8	Desilles
#
# T1	firstnames 9 28	pierre V↑e↓ léonard
#
# T0	name 0 8	Desilles
#
# T1	firstnames 9 28	pierre V↑e↓ léonard
#
# T0	name 0 7	Malvaux
#
# T1	firstnames 8 14	pierre
#
# T0	name 0 7	Malvaux
#
# T1	firstnames 8 14	pierre
#
# T0	name 0 8	Ramelert
#
# T1	firstnames 9 13	Côme
#
# T0	name 0 7	Malvaux
#
# T1	firstnames 8 14	pierre
#
# T0	name 0 7	Platard
#
# T1	firstnames 8 18	jean louis
#
# T0	name 0 8	Plataret
#
# T1	firstnames 9 18	Jeanlouis
#
# T0	name 0 7	Viviard
#
# T1	firstnames 8 21	Jean françois
#
# T0	name 0 24	Commune (La) de Fontenay
#
# T0	name 0 8	Mainguet
#
# T1	firstnames 9 20	Jean Victor
#
# T0	name 0 10	Barthelemy
#
# T1	firstnames 11 18	Charles
#
# T2	address 22 27	Paris
#
# T3	name 28 34	Boucot
#
# T4	firstnames 35 55	pierre Etienne Louis
#
# T0	name 0 6	Boucot
#
# T1	firstnames 7 27	pierre Etienne Louis
#
# T0	name 0 6	Bouchu
#
# T1	firstnames 7 21	Charles Joseph
#
# T0	name 0 8	Bergeron
#
# T1	firstnames 9 21	Louis Claude
#
# T0	name 0 8	Barillon
#
# T1	firstnames 9 16	nicolas
#
# T0	name 0 10	Barthelemy
#
# T1	firstnames 11 18	Charles
#
# T2	address 21 26	Paris
#
# T0	name 0 7	Motteau
#
# T1	firstnames 8 20	Claude Spire
#
# T0	name 0 7	Deville
#
# T1	firstnames 8 24	françois deutier
#
# T0	name 0 5	Neron
#
# T1	firstnames 6 11	Denis
#
# T0	name 0 7	Thibaud
#
# T1	firstnames 8 20	Jean charles
#
# T0	name 0 6	Gueriu
#
# T1	firstnames 7 21	Ch↑ls↓ Saschal
#
# T0	name 0 5	Frelé
#
# T1	familystatus 6 19	les héritiers
#
# T0	name 0 8	Gauthier
#
# T1	firstnames 9 21	louis ch↑es↓
#
# T2	address 32 40	Varennes
#
# T0	name 0 7	Motteau
#
# T1	firstnames 8 14	F↑ois↓
#
# T2	address 17 24	perigny
#
# T0	name 0 8	Gauthier
#
# T1	firstnames 18 31	louis charles
#
# T2	address 34 42	Varennes
#
# T0	name 0 9	Delaroche
#
# T1	firstnames 10 19	sebastien
#
# T0	name 0 7	Motteau
#
# T1	firstnames 8 15	Etienne
#
# T2	familystatus 16 23	Le père
#
# T0	name 0 7	Foucaut
#
# T1	firstnames 8 16	françois
#
# T0	name 0 7	Motteau
#
# T1	firstnames 8 20	F↑ois↓ henry
#
# T0	name 0 9	Delaroche
#
# T1	firstnames 10 18	augustin
#
# T0	name 0 5	audry
#
# T1	firstnames 6 21	toussaint p↑re↓
#
# T0	name 0 4	Noël
#
# T1	firstnames 5 18	louis laurent
#
# T0	name 0 8	Delanoue
#
# T1	firstnames 9 24	p↑re↓ toussaint
#
# T2	familystatus 25 29	V↑e↓
#
# T0	name 0 5	hallé
#
# T1	firstnames 6 21	B↑te↓ toussaint
#
# T0	name 0 7	Pigeron
#
# T0	name 0 6	Moreau
#
# T1	firstnames 7 11	noël
#
# T0	name 0 7	Vandard
#
# T1	firstnames 8 14	thomas
#
# T2	familystatus 15 19	V↑e↓
#
# T0	name 0 5	Baron
#
# T1	firstnames 6 17	p↑re↓ denis
#
# T0	name 0 5	auger
#
# T1	firstnames 6 20	nicolas joseph
#
# T0	name 0 7	Vodoyer
#
# T1	firstnames 8 18	jean marie
#
# T0	name 0 6	Minier
#
# T1	firstnames 7 16	Toussaint
#
# T0	name 0 6	Minier
#
# T1	firstnames 7 20	louis jacques
#
# T0	name 0 8	Chamblin
#
# T1	firstnames 9 17	philippe
#
# T0	name 0 8	Brigault
#
# T1	firstnames 9 14	louis
#
# T0	name 0 6	Cassin
#
# T0	name 0 4	adam
#
# T1	firstnames 5 18	jean françois
#
# T0	name 0 10	Montmarthe
#
# T1	firstnames 11 16	Ph↑e↓
#
# T2	familystatus 17 22	veuve
#
# T0	name 2 9	Saussay
#
# T1	title 0 1	M
#
# T2	familystatus 10 14	fils
#
# T0	name 0 6	Lameau
#
# T1	firstnames 12 20	saturnin
#
# T2	familystatus 7 11	V↑e↓
#
# T3	familystatus 21 27	h↑ers↓
#
# T0	name 5 18	Dhaussonville
#
# T1	title 0 4	M↑v↓
#
# T0	name 0 8	Bataille
#
# T1	firstnames 9 14	simon
#
# T0	name 0 8	Coiffier
#
# T1	firstnames 9 20	J↑n↓ F↑ois↓
#
# T0	name 0 7	Bastien
#
# T1	firstnames 8 15	Laurent
#
# T0	name 0 5	Duval
#
# T1	firstnames 6 14	sat↑nin↓
#
# T2	familystatus 15 20	veuve
#
# T0	name 0 8	Merillon
#
# T1	firstnames 9 22	J↑n↓ Sat↑nin↓
#
# T0	name 1 8	ancelet
#
# T1	firstnames 14 18	Jacq
#
# T2	familystatus 9 13	V↑e↓
#
# T3	name 21 29	Bataille
#
# T4	firstnames 30 42	J↑n↓ bap↑te↓
#
# T0	name 1 6	Vitry
#
# T1	firstnames 13 20	maurice
#
# T2	familystatus 7 12	veuve
#
# T3	name 22 30	Soudieux
#
# T4	firstnames 31 44	L↑is↓ J↑ques↓
#
# T0	name 0 8	Merillon
#
# T1	firstnames 9 21	J↑n↓ Sat↑in↓
#
# T0	name 0 8	Soudieux
#
# T1	firstnames 9 17	augustin
#
# T0	name 1 9	Carteron
#
# T1	name 11 17	Autray
#
# T2	firstnames 18 31	Vincent félix
#
# T0	name 0 9	N↑v↓ Cury
#
# T0	name 0 5	Cadot
#
# T1	firstnames 6 18	P↑re↓ F↑ois↓
#
# T2	address 19 24	font.
#
# T0	name 0 8	Coiffier
#
# T1	firstnames 9 28	J↑n↓ B↑te↓ seraphin
#
# T0	name 0 9	Hericourt
#
# T1	firstnames 10 15	Louis
#
# T0	name 1 7	Berger
#
# T1	firstnames 8 13	Louis
#
# T2	name 15 22	Foudaux
#
# T3	firstnames 23 36	F↑ou↓ Vincent
#
# T0	name 0 6	Margat
#
# T1	firstnames 7 14	Aug↑te↓
#
# T0	name 0 8	Barillet
#
# T1	firstnames 9 25	Antoine Saturnin
#
# T0	name 0 6	Lameau
#
# T1	firstnames 7 14	Achille
#
# T0	name 0 8	Mérillon
#
# T1	firstnames 9 22	Jean Saturnin
#
# T2	familystatus 23 28	V↑ve↓
#
# T0	name 0 9	Sourdieux
#
# T1	firstnames 10 15	Louis
#
# T2	familystatus 16 29	fils Breteuil
#
# T0	name 0 8	Mérillon
#
# T1	firstnames 9 14	Félix
#
# T0	name 0 10	Montmarthe
#
# T1	firstnames 11 35	Philippe Antoine→Nicolas
#
# T0	name 0 6	Lameau
#
# T1	firstnames 7 11	Jean
#
# T2	familystatus 14 27	fils→Saturnin
#
# T0	name 0 8	Soudieux
#
# T1	firstnames 9 21	Pierre Louis
#
# T0	name 0 7	Lesaint
#
# T1	firstnames 8 21	Jean Baptiste
#
# T0	name 0 9	Héricourt
#
# T1	firstnames 10 17	Germain
#
# T2	familystatus 19 32	fils→Cun❌❌urd
#
# T0	name 0 9	Héricourt
#
# T1	firstnames 10 19	Augustine
#
# T2	address 23 28	Paris
#
# T0	name 0 6	Berger
#
# T1	firstnames 7 15	Baptiste
#
# T0	name 0 6	Josset
#
# T1	firstnames 7 11	Jean
#
# T2	familystatus 12 17	Veuve
#
# T0	name 0 8	Pequesne
#
# T1	firstnames 9 21	Pierre Louis
#
# T0	name 0 9	Colombier
#
# T1	firstnames 10 22	jean germain
#
# T0	name 0 9	Colombier
#
# T1	firstnames 10 22	jean germain
#
# T0	name 0 8	Defresne
#
# T1	firstnames 9 27	J↑n↓ J↑ques↓ louis
#
# T0	name 0 7	Bouquet
#
# T1	firstnames 8 14	Cousin
#
# T0	name 0 8	Leprince
#
# T1	address 11 16	Vitry
#
# T2	name 18 23	Barre
#
# T3	firstnames 24 48	J↑n↓ louis david maurice
#
# T0	name 0 7	Sergent
#
# T1	firstnames 8 26	louis marie victor
#
# T0	name 0 7	sergent
#
# T1	firstnames 8 26	louis marie victor
#
# T0	name 0 10	Bourdillat
#
# T1	firstnames 11 15	Jean
#
# T0	name 0 7	Sergent
#
# T1	firstnames 8 28	marie denis alphonse
#
# T0	name 0 7	sergent
#
# T1	firstnames 8 28	marie denis alphonse
#
# T0	name 0 7	sergent
#
# T1	firstnames 8 28	marie denis alphonse
#
# T0	name 0 7	sergent
#
# T1	firstnames 8 28	marie denis alphonse
#
# T0	name 0 7	sergent
#
# T1	firstnames 8 28	marie denis alphonse
#
# T0	name 0 7	sergent
#
# T1	firstnames 8 28	marie denis alphonse
#
# T0	name 0 4	J↑n↓
#
# T1	firstnames 5 18	J↑ques↓ denis
#
# T2	name 19 27	Godefroy
#
# T3	firstnames 29 41	denis ch↑re↓
#
# T0	name 0 7	Massuet
#
# T1	firstnames 8 21	louis gaspard
#
# T0	name 0 4	adam
#
# T1	firstnames 5 17	J↑n↓ sulpice
#
# T2	familystatus 18 28	les h↑ers↓
#
# T3	name 30 36	fleury
#
# T4	firstnames 37 48	jean f↑ois↓
#
# T0	name 0 7	Praguet
#
# T1	firstnames 8 24	germain mathurin
#
# T0	name 0 8	Vaudoyer
#
# T1	firstnames 9 21	honoré louis
#
# T0	name 0 8	Gabillot
#
# T1	firstnames 9 23	claude lambert
#
# T0	name 0 18	Société de la gare
#
# T0	name 0 4	Enau
#
# T1	activity 5 16	nourrisseur
#
# T0	name 0 8	Bourgoin
#
# T1	activity 9 56	inspecteur→des portes de la chambre des→députés
#
# T0	name 0 6	L'Etat
#
# T0	name 0 8	Bourgoin
#
# T1	firstnames 9 19	inspecteur
#
# T0	name 0 6	Guidal
#
# T1	firstnames 7 11	paul
#
# T0	name 0 6	Guidal
#
# T1	firstnames 7 11	paul
#
# T0	name 0 7	Lefevre
#
# T0	name 0 7	Buisson
#
# T1	firstnames 8 14	pierre
#
# T0	name 0 5	Caron
#
# T0	name 0 7	Lefèvre
#
# T0	name 0 7	Buisson
#
# T1	firstnames 8 14	pierre
#
# T0	name 0 6	Leorüe
#
# T0	name 0 7	Delorme
#
# ...
#
# T0	name 0 7	Ancelet
#
# T1	firstnames 8 17	dominique
#
# T2	familystatus 18 22	fils
#
# T0	name 0 9	Héricourt
#
# T1	firstnames 10 26	françois Nicolas
#
# T0	name 0 6	Rameau
#
# T1	firstnames 7 21	auguste eugène
#
# T0	name 0 11	Guillemmiot
#
# T1	firstnames 12 16	Paul
#
# T0	name 0 17	Beuzeville désiré
#
# T1	firstnames 18 26	zéphirin
#
# T0	name 0 6	Naudet
#
# T1	firstnames 7 13	Victor
#
# T0	name 0 6	Rameau
#
# T1	firstnames 7 20	Jean françois
#
# T0	name 0 8	Misgault
#
# T1	firstnames 9 19	J↑n↓ B↑te↓
#
# T2	familystatus 20 24	fils
#
# T0	name 0 6	Lameau
#
# T1	firstnames 7 20	Pierre Joseph
#
# T0	name 0 5	Lapie
#
# T1	firstnames 6 16	Léon Louis
#
# T0	name 0 4	Rose
#
# T1	firstnames 5 17	louis alexis
#
# T0	name 0 9	Héricourt
#
# T1	firstnames 10 22	Louis Victor
#
# T0	name 0 8	Barillet
#
# T1	firstnames 9 16	Charles
#
# T2	familystatus 17 21	V↑e↓
#
# T0	name 0 7	Prévost
#
# T1	familystatus 8 12	V↑e↓
#
# T2	birthname 17 24	Saussay
#
# T0	name 0 4	Léon
#
# T1	firstnames 5 15	J↑n↓ B↑te↓
#
# T2	familystatus 16 20	V↑e↓
#
# T3	birthname 25 31	Rameau
#
# T0	name 0 6	Martin
#
# T1	firstnames 7 11	D↑e↓
#
# T0	name 0 6	Rameau
#
# T1	firstnames 7 19	louis Victor
#
# T0	name 0 8	Misgault
#
# T1	firstnames 9 14	louis
#
# T2	familystatus 15 21	mineur
#
# T0	name 0 8	Courtois
#
# T1	firstnames 9 14	Louis
#
# T2	familystatus 15 28	g↑dre↓ Mezard
#
# T0	name 0 5	André
#
# T1	firstnames 6 23	alexandre edouard
#
# T0	name 0 8	Lalégery
#
# T1	firstnames 9 21	Denis joseph
#
# T0	name 0 8	Lepoutre
#
# T1	firstnames 9 15	Joseph
#
# T0	name 0 8	Soudieux
#
# T1	firstnames 9 21	Louis Joseph
#
# T0	name 0 4	idem
#
# T1	name 6 14	Vauguyon
#
# T2	firstnames 16 33	maire→de marolles
#
# T0	name 0 6	habert
#
# T1	firstnames 7 14	Général
#
# T2	activity 7 14	Général
#
# T3	name 15 21	Dalton
#
# T4	firstnames 22 31	Bourgeois
#
# T5	address 34 42	marolles
#
# T0	name 0 23	Le Prince de Neufchâtel
#
# T1	name 25 33	Vauguyon
#
# T2	activity 35 52	maire→de marolles
#
# T0	name 0 23	Le Prince de→Neufchâtel
#
# T0	name 1 9	Vauguyon
#
# T1	activity 11 16	maire
#
# T2	name 18 22	idem
#
# T0	name 0 23	Le Prince de→neufchâtel
#
# T0	name 1 9	Vauguyon
#
# T1	activity 11 16	maire
#
# T2	name 18 22	idem
#
# T0	name 0 23	Le Prince de→neufchâtel
#
# T0	name 1 9	Vauguyon
#
# T1	activity 11 16	maire
#
# T2	name 18 22	idem
#
# T0	name 0 6	Guérin
#
# T1	firstnames 7 20	Jacq↑e↓ henry
#
# T2	activity 21 26	maçon
#
# T3	address 29 31	id
#
# T0	name 1 9	Vauguyon
#
# T1	activity 11 28	maire→de marolles
#
# T2	name 30 53	Le Prince de Neufchâtel
#
# T0	name 0 23	Le Prince de→neufchâtel
#
# T0	name 0 4	idem
#
# T1	name 6 14	Vauguyon
#
# T2	activity 16 33	maire→de marolles
#
# T0	name 0 7	Lefèvre
#
# T1	firstnames 8 14	Jaques
#
# T2	activity 15 22	vig↑on↓
#
# T3	activity 26 33	adjoint
#
# T0	name 0 23	Le Prince de→Neufchâtel
#
# T0	name 0 8	Berthier
#
# T1	title 9 29	Prince→de Neufchâtel
#
# T0	name 0 8	Debaisse
#
# T1	activity 9 14	maire
#
# T2	address 17 24	Santeny
#
# T0	name 0 6	Duclos
#
# T0	name 0 6	Pesson
#
# T1	firstnames 7 21	pierre georges
#
# T2	address 24 31	Santeny
#
# T0	name 0 6	Duclos
#
# T1	activity 7 21	maitre→de post
#
# T0	name 0 5	Néant
#
# T0	name 0 5	Néant
#
# T0	name 0 5	Néant
#
# T0	name 0 8	Berthier
#
# T1	firstnames 9 18	alexandre
#
# T0	name 0 8	Piedquin
#
# T1	firstnames 9 21	f↑ois↓ Marie
#
# T0	name 0 23	Le Prince de Neufchâtel
#
# T1	name 25 33	Vauguyon
#
# T0	name 0 4	Pigy
#
# T1	firstnames 5 11	pierre
#
# T0	name 0 23	Le Prince de Neufchâtel
#
# T1	name 25 33	Vauguyon
#
# T0	name 0 8	Berthier
#
# T0	name 0 23	Le Prince de Neufchâtel
#
# T1	name 25 33	Vauguyon
#
# T0	name 0 8	Berthier
#
# T0	name 0 6	Rameau
#
# T1	firstnames 7 19	Roch Quentin
#
# T0	name 0 8	Soudieux
#
# T1	firstnames 9 28	Saturnin di❌→mandre
#
# T0	name 0 8	Soudieux
#
# T1	firstnames 9 22	Louis jacques
#
# T2	familystatus 24 30	H↑ers↓
#
# T0	name 0 6	Josset
#
# T1	firstnames 7 21	françois marie
#
# T0	name 0 7	Ancelet
#
# T1	firstnames 8 15	nicolas
#
# T2	familystatus 29 34	Veuve
#
# T0	name 0 7	Ancelet
#
# T1	firstnames 8 26	Saturnin Dominique
#
# T0	name 0 7	Ancelet
#
# T1	firstnames 8 17	Alexandre
#
# T0	name 0 8	Foucault
#
# T1	firstnames 9 15	Pierre
#
# T0	name 0 7	Leblanc
#
# T1	firstnames 8 14	Victor
#
# T0	name 0 9	Dampierre
#
# T1	familystatus 11 19	Le Comte
#
# T0	name 0 7	Lesaint
#
# T1	firstnames 8 21	Jean Baptiste
#
# T0	name 0 8	Mérillon
#
# T1	firstnames 9 14	félix
#
# T0	name 0 8	Mérillon
#
# T1	firstnames 9 19	Jean Denis
#
# T2	familystatus 21 26	V↑ve↓
#
# T0	name 0 8	Mérillon
#
# T1	firstnames 9 18	Dominique
#
# T0	name 0 13	La Folleville
#
# T0	name 5 12	Dudouit
#
# T1	familystatus 0 4	V↑e↓
#
# T0	name 6 11	Radot
#
# T1	familystatus 0 5	h↑re↓
#
# T2	familystatus 0 5	h↑re↓
#
# T0	name 0 5	Bacot
#
# T0	name 0 7	Triosot
#
# T0	name 0 4	Levé
#
# T0	name 0 5	Tiere
#
# T0	name 0 5	Bacot
#
# T0	name 0 7	Rubigny
#
# T0	name 0 4	Levé
#
# T0	name 0 7	Triosot
#
# T0	name 0 6	Demont
#
# T0	name 0 7	Ragondé
#
# T1	firstnames 8 12	Paul
#
# T0	name 6 11	Radot
#
# T1	familystatus 0 5	h↑rs↓
#
# T0	name 0 10	Servatrier
#
# T0	name 0 6	Thiers
#
# T0	name 0 8	hospices
#
# T0	name 0 18	×Tiers± hôtel Dieu
#
# T1	name 20 38	Les Tiers hospices
#
# T0	name 0 5	Leroy
#
# T1	firstnames 6 10	J↑n↓
#
# T0	name 0 7	Renoult
#
# T0	name 0 12	Lafolleville
#
# T0	name 0 7	Ragondé
#
# T1	firstnames 8 12	Paul
#
# T0	name 0 5	Bacot
#
# T0	name 0 12	Les hospices
#
# T0	name 0 7	Ragondé
#
# T0	name 0 4	Nolo
#
# T1	firstnames 5 10	Louis
#
# T0	name 0 5	Petit
#
# T1	firstnames 6 11	P↑re↓
#
# T0	name 0 8	Gevaudan
#
# T0	name 0 6	Didier
#
# T1	firstnames 7 12	P↑re↓
#
# T0	name 0 10	Desmaisons
#
# T0	name 0 8	Gevaudan
#
# T0	name 0 17	dame de Chavagnac
#
# T0	name 0 6	havard
#
# T1	firstnames 7 21	F↑ois↓ J↑ques↓
#
# T0	name 0 5	Barra
#
# T1	firstnames 6 12	albert
#
# T0	name 0 6	Cheveh
#
# T0	name 0 8	Moulinoi
#
# T1	firstnames 15 21	Ant↑e↓
#
# T2	familystatus 9 14	V↑ve↓
#
# T0	name 0 8	Grondard
#
# T0	name 0 5	Petit
#
# T1	firstnames 6 10	J↑n↓
#
# T0	name 0 7	Pithois
#
# T1	firstnames 8 29	Jean baptiste charles
#
# T2	address 32 37	Paris
#
# T0	name 0 8	Léchopié
#
# T1	firstnames 9 18	hippolyte
#
# T2	address 21 26	ablon
#
# T0	name 0 10	Delaherche
#
# T1	firstnames 11 28	caroline adélaide
#
# T2	address 58 63	ablon
#
# T0	name 0 8	Sourdeau
#
# T1	firstnames 9 28	Jean antoine Joseph
#
# T2	address 31 36	athis
#
# T0	name 0 7	hédiard
#
# T1	firstnames 8 21	nicolas Louis
#
# T2	address 24 29	ablon
#
# T0	name 0 5	Simon
#
# T1	firstnames 6 19	claude Joseph
#
# T2	address 22 27	ablon
#
# T0	name 0 7	Leblanc
#
# T1	firstnames 8 19	Jean Joseph
#
# T2	address 38 43	ablon
#
# T3	familystatus 21 34	les héritiers
#
# T0	name 0 6	Quinos
#
# T1	firstnames 7 28	françois dit Lafrance
#
# T2	address 31 44	Choisy le roi
#
# T0	name 0 7	Leblanc
#
# T1	firstnames 8 19	Jean Joseph
#
# T2	address 38 40	id
#
# T3	familystatus 21 34	les héritiers
#
# T0	name 0 5	Morès
#
# T1	firstnames 6 21	auguste Georges
#
# T2	address 24 26	id
#
# T0	name 0 5	Rebel
#
# T1	firstnames 6 21	françois Damaze
#
# T2	address 24 29	Ablon
#
# T0	name 0 6	Arigon
#
# T1	firstnames 7 22	Louis Sébastien
#
# T2	address 25 27	id
#
# T0	name 0 8	Sourdeau
#
# T1	firstnames 9 28	Jean Antoine Joseph
#
# T2	address 31 36	athis
#
# T0	name 0 9	Pélissier
#
# T1	firstnames 10 22	pierre Louis
#
# T2	address 25 27	id
#
# T0	name 0 4	Marc
#
# T1	firstnames 5 17	Erasme Louis
#
# T2	address 44 49	ablon
#
# T3	title 18 23	veuve
#
# T4	birthname 27 36	Mouillard
#
# T0	name 0 8	Chrétien
#
# T1	firstnames 9 15	pierre
#
# T2	address 18 20	id
#
# T0	name 0 5	Galle
#
# T1	firstnames 6 11	Jules
#
# T2	activity 12 21	boulanger
#
# T3	address 24 26	id
#
# T0	name 0 6	Bayves
#
# T1	firstnames 7 28	Pierre auguste adrien
#
# T2	address 31 33	id
#
# T0	name 0 6	Ballot
#
# T1	firstnames 7 12	Louis
#
# T2	address 32 39	Corbeil
#
# T3	familystatus 13 29	gendre Desavoine
#
# T0	name 0 8	Damaison
#
# T1	firstnames 9 15	pierre
#
# T2	address 35 44	Champigny
#
# T3	familystatus 16 32	gendre Desavoine
#
# T0	name 0 7	Roussel
#
# T1	firstnames 8 25	ambroise françois
#
# T2	address 28 33	ablon
#
# T0	name 0 8	Jarielle
#
# T1	firstnames 9 16	Jacques
#
# T2	address 24 26	id
#
# T3	familystatus 17 21	aîné
#
# T0	name 0 8	Jarielle
#
# T1	firstnames 9 14	Louis
#
# T2	address 17 19	id
#
# T0	name 0 7	Delaune
#
# T1	firstnames 8 16	augustin
#
# T2	address 19 21	id
#
# T0	name 0 7	Delaune
#
# T1	firstnames 8 29	ange augustin adolphe
#
# T2	address 46 52	Alfort
#
# T3	familystatus 30 43	gendre Derain
#
# T0	name 0 6	Bayvet
#
# T1	firstnames 7 28	pierre auguste adrien
#
# T2	address 31 36	ablon
#
# T0	name 0 7	Leblanc
#
# T1	activity 8 17	bijoutier
#
# T2	address 20 25	Paris
#
# T0	name 0 6	Bayvet
#
# T1	firstnames 7 28	pierre auguste adrien
#
# T2	address 31 36	ablon
#
# T0	name 0 8	Patureau
#
# T1	firstnames 9 21	hubert marie
#
# T0	name 0 6	Flogny
#
# T1	firstnames 7 20	claude adrien
#
# T0	name 0 3	Doé
#
# T1	firstnames 4 19	albert philippe
#
# T0	name 0 5	Lucot
#
# T1	activity 6 11	maçon
#
# T0	name 0 4	Rome
#
# T1	firstnames 5 16	jean pierre
#
# T0	name 0 7	Grossed
#
# T1	firstnames 8 23	×pierre± amedée
#
# T2	name 27 33	Benoid
#
# T3	firstnames 34 47	pierre adrien
#
# T0	name 0 7	Lemaire
#
# T1	firstnames 8 21	Jean mathurin
#
# T0	name 0 14	de s↑te↓ croix
#
# T0	name 0 7	lemaire
#
# T1	firstnames 8 21	jean mathurin
#
# T0	name 0 8	Rousseau
#
# T1	firstnames 9 25	antoine françois
#
# T0	name 0 14	de S↑te↓ croix
#
# T0	name 0 8	Moygnard
#
# T1	firstnames 9 13	jacq
#
# T2	activity 14 18	agri
#
# T0	name 0 14	de S↑te↓ Croix
#
# T0	name 0 8	Patureau
#
# T1	firstnames 9 21	hubert marie
#
# T0	name 0 5	Barré
#
# T1	firstnames 6 24	louis marie Joseph
#
# T0	name 0 4	Blos
#
# T1	firstnames 5 11	Et↑ne↓
#
# T0	name 0 5	Huard
#
# T1	firstnames 6 11	J↑ue↓
#
# T0	name 0 7	Bouquet
#
# T0	name 0 5	houdé
#
# T1	firstnames 6 12	Joseph
#
# T0	name 0 6	Crétté
#
# T1	firstnames 7 19	J↑n↓ Tous↑t↓
#
# T0	name 0 8	Delanoue
#
# T1	familystatus 9 13	V↑e↓
#
# T0	name 0 7	Lemaire
#
# T1	firstnames 8 14	Et↑ne↓
#
# T0	name 0 8	Vaudoyer
#
# T1	firstnames 9 14	Régis
#
# T2	familystatus 15 19	père
#
# T0	name 0 8	Chapelle
#
# T1	firstnames 9 14	N↑as↓
#
# T0	name 0 7	Grognet
#
# T1	firstnames 8 14	Joseph
#
# T0	name 0 5	David
#
# T1	firstnames 6 16	J↑n↓ M↑ar↓
#
# T2	familystatus 17 28	Les enfants
#
# T0	name 0 8	Delanoue
#
# T1	firstnames 14 19	Cl↑d↓
#
# T2	familystatus 9 13	V↑e↓
#
# T0	name 0 8	Delanoue
#
# T1	familystatus 9 13	V↑e↓
#
# T0	name 0 7	Grenier
#
# T1	firstnames 8 15	Laurent
#
# T0	name 0 8	Vaudoyer
#
# T1	firstnames 9 21	Louis honoré
#
# T0	name 0 8	Morblant
#
# T1	familystatus 9 13	V↑e↓
#
# T0	name 0 7	Bernard
#
# T1	address 15 23	Beaumont
#
# T2	familystatus 8 12	V↑e↓
#
# T0	name 0 8	Vaudoyer
#
# T1	firstnames 9 18	Ls honoré
#
# T0	name 0 5	Barré
#
# T1	firstnames 6 11	Louis
#
# T0	name 0 10	Courtebral
#
# T1	firstnames 11 20	Philibert
#
# T0	name 0 8	Morblant
#
# T1	firstnames 14 26	J↑n↓ Bap↑te↓
#
# T2	familystatus 9 13	V↑e↓
#
# T0	name 0 8	Luisette
#
# T1	firstnames 9 24	st carlet barbe
#
# T0	name 0 8	Florimos
#
# T0	name 0 5	andré
#
# T1	firstnames 6 19	adelaïde J↑n↓
#
# T2	name 20 26	Biquet
#
# T3	firstnames 27 38	×alexandre±
#
# T0	name 0 8	Desloges
#
# T1	firstnames 9 20	noël f↑ois↓
#
# T0	name 0 7	Clavier
#
# T1	familystatus 8 36	gendre de la V↑e↓ monesuteau
#
# T0	name 0 10	moncouteau
#
# T1	firstnames 11 23	germain jean
#
# T0	name 0 10	moncouteau
#
# T1	firstnames 11 23	germain jean
#
# T0	name 0 5	Leroy
#
# T1	firstnames 6 19	louis nicolas
#
# T2	name 0 5	Leroy
#
# T3	firstnames 27 39	jean nicolas
#
# T4	familystatus 40 44	fils
#
# T0	name 0 6	Pillet
#
# T1	firstnames 7 19	claude denis
#
# T0	name 0 7	Leclerc
#
# T1	firstnames 8 19	p↑re↓ louis
#
# T0	name 0 10	Tournemire
#
# T1	activity 11 17	avocat
#
# T2	familystatus 18 24	h↑ers↓
#
# T0	name 0 6	Gallet
#
# T1	firstnames 7 19	jean tous↑t↓
#
# T0	name 0 8	Bourgoin
#
# T1	firstnames 9 14	p↑re↓
#
# T0	name 0 5	Pepin
#
# T1	firstnames 6 16	J↑n↓ B↑te↓
#
# T2	address 19 28	Villejuif
#
# T3	name 30 35	Menon
#
# T4	firstnames 36 47	louis roche
#
# T0	name 0 8	Luisette
#
# T1	firstnames 9 14	henry
#
# T2	familystatus 15 19	V↑e↓
#
# T0	name 0 7	Clavier
#
# T1	firstnames 8 16	françois
#
# T0	name 0 8	Chatenay
#
# T1	firstnames 9 24	J↑n↓ marie abel
#
# T0	name 0 5	Cally
#
# T1	address 13 17	ivry
#
# T2	familystatus 6 10	V↑e↓
#
# T3	name 19 25	fretté
#
# T4	firstnames 26 40	guillaume tell
#
# T0	name 0 9	Labouraux
#
# T1	firstnames 10 16	martin
#
# T0	name 0 8	Luisette
#
# T1	firstnames 9 14	henry
#
# T2	familystatus 15 19	V↑e↓
#
# T0	name 0 8	Luisette
#
# T1	firstnames 9 14	henry
#
# T2	familystatus 15 20	V↑e↓→
#
# T3	name 20 25	amiot
#
# T4	firstnames 26 41	louis alexandre
#
# T0	name 0 10	Moncouteau
#
# T1	firstnames 11 21	jean maris
#
# T0	name 0 7	Pigeron
#
# T0	name 0 5	Hallé
#
# T1	firstnames 6 19	louis germain
#
# T0	name 0 5	Salmé
#
# T1	firstnames 6 10	jean
#
# T0	name 0 8	Rousseau
#
# T1	firstnames 9 21	louis F↑ois↓
#
# T0	name 0 7	Morizot
#
# T1	firstnames 8 21	marie arnoult
#
# T0	name 0 5	Salmé
#
# T1	firstnames 6 10	jean
#
# T0	name 0 8	Delkayré
#
# T1	firstnames 9 13	jean
#
# T0	name 0 8	Delanoue
#
# T1	firstnames 9 22	pre toussains
#
# T0	name 0 8	Cabouset
#
# T1	firstnames 9 20	jean robert
#
# T0	name 0 5	Salmé
#
# T1	firstnames 6 10	jean
#
# T0	name 0 7	Morizot
#
# T1	firstnames 8 21	marie arnould
#
# T0	name 0 7	Bonneau
#
# T1	firstnames 8 20	louis B↑❌❌❌↓
#
# T0	name 0 5	Salmé
#
# T1	firstnames 6 10	jean
#
# T0	name 0 8	Mevothon
#
# T1	familystatus 9 19	les h↑ers↓
#
# T0	name 0 5	Cornu
#
# T1	firstnames 6 12	pierre
#
# T0	name 0 4	Trié
#
# T1	firstnames 5 14	philibert
#
# T0	name 0 8	Lavenant
#
# T1	firstnames 9 21	Louis f↑ois↓
#
# T0	name 0 11	Ples matins
#
# T1	firstnames 12 19	Scévola
#
# T0	name 0 4	Levé
#
# T1	firstnames 5 11	claude
#
# T0	name 0 18	Blain des cormiers
#
# T0	name 0 18	Cousin de mericard
#
# T1	familystatus 19 23	V↑e↓
#
# T0	name 0 7	Nouvial
#
# T1	firstnames 8 19	jean joseph
#
# T0	name 0 6	Renard
#
# T1	firstnames 7 21	ch↑es↓ nicolas
#
# T0	name 0 7	Nouvial
#
# T1	firstnames 8 19	jean joseph
#
# T0	name 0 18	Cousin dem ricourt
#
# T1	familystatus 19 23	V↑e↓
#
# T0	name 1 19	Blain des Cormiers
#
# T0	name 1 9	Balestre
#
# T1	address 12 18	Sceaux
#
# T0	name 0 5	Sevin
#
# T1	firstnames 6 18	Jean Achille
#
# T2	name 19 25	Couste
#
# T3	firstnames 26 36	p↑re↓ noël
#
# T0	name 0 8	Lavenant
#
# T1	firstnames 9 26	louis f↑ois↓ J↑n↓
#
# T0	name 0 8	Didouvre
#
# T1	firstnames 9 21	p↑re↓ f↑ois↓
#
# T0	name 0 8	Didouvre
#
# T1	firstnames 9 21	p↑re↓ f↑ois↓
#
# T0	name 0 6	sassin
#
# T1	firstnames 7 17	jean andré
#
# T0	name 0 7	Guézard
#
# T1	firstnames 8 19	noël f↑ois↓
#
# T0	name 0 7	Guézard
#
# T1	firstnames 8 19	noël f↑ois↓
#
# T0	name 0 7	Guézard
#
# T1	firstnames 8 19	noël f↑ois↓
#
# T0	name 0 6	Renard
#
# T1	firstnames 7 18	n↑as↓ ch↑e↓
#
# T0	name 0 7	Michaud
#
# T1	firstnames 8 18	J↑n↓ p↑re↓
#
# T0	name 0 8	Godefroy
#
# T1	firstnames 9 18	J F denis
#
# T2	name 20 26	Masson
#
# T3	firstnames 27 37	n↑as↓ J↑n↓
#
# T0	name 0 6	Mayeux
#
# T1	firstnames 7 14	nicolas
#
# T2	name 16 25	Deplanque
#
# T3	firstnames 26 32	Carriu
#
# T0	name 0 6	Mayeux
#
# T1	firstnames 7 14	nicolas
#
# T0	name 0 6	Sassin
#
# T1	firstnames 7 11	jean
#
# T0	name 0 6	Cousté
#
# T1	firstnames 7 16	p↑re noël
#
# T0	name 0 9	Chatelain
#
# T1	firstnames 10 15	ch↑e↓
#
# T2	name 17 23	Cousté
#
# T3	firstnames 24 34	p↑re↓ noël
#
# T0	name 0 8	Lavenant
#
# T1	firstnames 9 26	louis f↑ois↓ j↑n↓
#
# T2	name 28 45	hospices de Paris
#
# T0	name 0 6	sureau
#
# T1	firstnames 7 21	Emmanuel p↑re↓
#
# T2	name 23 29	Benard
#
# T3	firstnames 30 41	g↑me↓ h↑ne↓
#
# T0	name 0 6	Letrec
#
# T1	firstnames 7 18	Jean f↑ois↓
#
# T2	name 20 25	auvry
#
# T3	firstnames 26 44	ant↑e↓ blaise j↑n↓
#
# T0	name 0 7	Thibaut
#
# T1	firstnames 8 22	Joseph germain
#
# T2	name 24 41	Gouvernement (le)
#
# T0	name 0 9	Rentienne
#
# T1	firstnames 10 25	Clément Charles
#
# T2	familystatus 27 39	g↑dre↓→quésu
#
# T0	name 0 6	Benoit
#
# T1	firstnames 7 21	Louis François
#
# T2	familystatus 23 36	g↑dre↓→Rouyer
#
# T0	name 0 10	Loripherne
#
# T1	firstnames 22 28	Michel
#
# T2	name 0 10	Loripherne
#
# T3	firstnames 30 43	Louis Auguste
#
# T0	name 0 10	Basseville
#
# T1	firstnames 11 26	Pierre François
#
# T0	name 0 6	Benoit
#
# T1	firstnames 7 22	françois benoit
#
# T2	name 24 29	actar
#
# T3	firstnames 30 43	nicolas louis
#
# T4	address 45 50	Vanve
#
# T0	name 0 7	Charles
#
# T1	address 10 18	Bellevue
#
# T0	name 0 8	Bessault
#
# T1	firstnames 9 18	Toussaint
#
# T2	address 21 30	Champigny
#
# T0	name 0 5	Quéru
#
# T1	firstnames 6 21	Pierre François
#
# T0	name 0 9	Rentienne
#
# T1	firstnames 10 25	Ambroise Amédée
#
# T0	name 0 9	Rentienne
#
# T1	firstnames 10 15	henri
#
# T0	name 0 6	Bonval
#
# T1	firstnames 7 20	Pierre Michel
#
# T0	name 0 6	Quière
#
# T1	firstnames 7 19	Louis Alexis
#
# T2	familystatus 20 24	fils
#
# T3	name 25 32	Lèvnard
#
# T0	name 0 6	❌❌erci
#
# T1	firstnames 7 25	Barthelemy Bernard
#
# T0	name 0 6	Seguin
#
# T1	firstnames 7 15	Théodore
#
# T0	name 0 18	Société de la Gare
#
# T0	name 0 9	Lemonnier
#
# T1	firstnames 10 19	J↑n↓ Fois
#
# T0	name 0 10	Destouches
#
# T1	firstnames 11 18	auguste
#
# T0	name 0 7	Bertaut
#
# T1	firstnames 8 15	antoine
#
# T2	familystatus 16 21	veuve
#
# T0	name 0 9	Lemonnier
#
# T1	firstnames 10 15	Jn Fr
#
# T0	name 0 6	Masson
#
# T0	name 0 8	Thevenez
#
# T1	firstnames 9 21	Et↑e↓ ant↑e↓
#
# T0	name 0 11	Phillippitz
#
# T1	firstnames 12 20	Frédéric
#
# T0	name 0 6	Petzel
#
# T0	name 0 16	Sulian (Desanut)
#
# T1	firstnames 17 31	pierre Raymond
#
# T0	name 0 7	Pierlot
#
# T1	activity 8 16	banquier
#
# T2	address 19 24	Paris
#
# T0	name 0 8	Delamare
#
# T1	firstnames 9 17	Mathurin
#
# T2	activity 18 27	Bourgeois
#
# T0	name 0 7	Delauge
#
# T1	activity 8 17	Bourgeois
#
# T2	address 20 30	Petit-Brie

# %% [markdown]
# ## Unit tests

# %%
t = "Chaillou Louis frédéric"
reg = regex.search("Louis frédéric",t)
print(reg)
# Out:
# <regex.Match object; span=(9, 23), match='Louis frédéric'>

# %%
import glob

len(glob.glob(RES_PATH + '/*.txt'))
# Out:
# 483
