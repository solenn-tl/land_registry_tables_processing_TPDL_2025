# %% [markdown]
# # 01 - Create dataset for NER
#
# This notebook aims to create a dataset using NER annotation files (Brat Standoff) format to train a NER model.

# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "1" #Numéro GPU
print(os.environ["CUDA_VISIBLE_DEVICES"])
# Out:
# 1

# %%
import os, sys
from pathlib import Path

BASE = Path(os.path.dirname(os.path.realpath("__file__"))).resolve() # If not on GColab, BASE will be the directory of this notebook
DATASETS = Path('/home/STual/DAN-cadastre/data').resolve()
OUT_BASE = Path('/home/STual/DAN-cadastre/outputs/NER_inference').resolve()

print(sys.path)
print(BASE)
print(DATASETS)
print(OUT_BASE)
# Out:
# ['/usr/lib/python310.zip', '/usr/lib/python3.10', '/usr/lib/python3.10/lib-dynload', '', '/home/STual/DAN-cadastre/.venv_dan/lib/python3.10/site-packages']
# /home/STual/DAN-cadastre/scripts/NER
# /home/STual/DAN-cadastre/data
# /home/STual/DAN-cadastre/outputs/NER_inference

# %% [markdown]
# ### Parameters

# %%
MODEL_NAME = 'camembert_ner'
#camembert_ner
#pretrained_camembert_ner

# %%
import glob
import re
import json
import pandas as pd
import config
import os
from pathlib import Path

config.SPLIT_SEED = 42 # Random seed used in train/dev/test. Do not change it if you want to recreate the paper results.
config.DEBUG = False # If true, text versions of the spacy datasets will be saved along with the .spacy files.

# %% [markdown]
# ## Load data

# %%
DATA = DATASETS / "NER/NER_dataset"

# Retrieve files (Brat Standoff annotations)
txts = sorted(glob.glob(f"{DATA}/*.txt"))
anns = sorted(glob.glob(f"{DATA}/*.ann"))

assert len(txts) == len(anns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 DATA = DATASETS / "NER/NER_dataset"
#       3 # Retrieve files (Brat Standoff annotations)
#       4 txts = sorted(glob.glob(f"{DATA}/*.txt"))
#
# NameError: name 'DATASETS' is not defined

# %%
# Re-structure annotations
id_ = []
text_ocr = []
brat = []
for i in range(0,len(txts)):
    name = txts[i].replace(str(DATA) + "/","")
    name = name.replace('.txt',"")
    id_.append(name)
    with open(txts[i], 'r', encoding="utf-8") as file:
        txt = file.read()
        text_ocr.append(txt)
    with open(anns[i], 'r', encoding="utf-8") as file:
        ann = file.readlines()
        entities = []
        for elem in ann:
            ls1 = elem.split('\t')
            ls2 = ls1[1].split(' ')
            entities.append([ls1[0],ls2[0],ls1[2][:-1],int(ls2[1]),int(ls2[2])])
        entities.insert(0,txt)
        brat.append(entities)

# %%
gold_reference = pd.DataFrame(id_,columns=["id"])
gold_reference["text_ocr"] = text_ocr
gold_reference["brat"] = brat
gold_reference
# Out:
#                                         id  \
# 0     001f99ca-b851-4b23-864d-563288dfba1f
# 1     0048e1d8-e348-4fa3-bc5c-10a8daaf1800
# 2     004ac7cc-9030-47b1-9136-bb5f8ea15ffa
# 3     007458b4-e647-47c1-9a46-a0527566e668
# 4     0075e078-e13c-4be0-8f6d-9382087da197
# ...                                    ...
# 2620  ff842312-b51f-4e7e-9e99-05ab7f2a52f8
# 2621  ff91ad3f-fda0-46b6-b7e1-1811f425fde1
# 2622  ffa866a3-a5ae-46b0-8f04-ca81f56fcc1d
# 2623  ffc91c4a-816b-4874-9e29-935749159300
# 2624  ffdfe55a-7d21-4e36-a9c7-9ddd071a2f19
#
#                                        text_ocr  \
# 0      Le Prince de neufchâtel→×Vauguyon maire±
# 1                             Queru P↑re↓ marie
# 2                                 Penain julien
# 3                   Maignan françois→à marolles
# 4                Nul ×Bourdillat pierre gilles±
# ...                                         ...
# 2620                    Mérillon saturnin veuve
# 2621                             Raban philippe
# 2622  Defresne honoré frédéric dit Bizet, Vitry
# 2623                     Montebello la Duchesse
# 2624    Lefèvre Jacques→Vig↑on↓ et adjoint à id
#
#                                                    brat
# 0     [Le Prince de neufchâtel→×Vauguyon maire±, [T0...
# 1     [Queru P↑re↓ marie, [T0, name, Queru, 0, 5], [...
# 2     [Penain julien, [T0, name, Penain, 0, 6], [T1,...
# 3     [Maignan françois→à marolles, [T0, name, Maign...
# 4     [Nul ×Bourdillat pierre gilles±, [T0, name, Nu...
# ...                                                 ...
# 2620  [Mérillon saturnin veuve, [T0, name, Mérillon,...
# 2621  [Raban philippe, [T0, name, Raban, 0, 5], [T1,...
# 2622  [Defresne honoré frédéric dit Bizet, Vitry, [T...
# 2623  [Montebello la Duchesse, [T0, name, Montebello...
# 2624  [Lefèvre Jacques→Vig↑on↓ et adjoint à id, [T0,...
#
# [2625 rows x 3 columns]

# %%
# Filter the annotations (drop duplicates)
gold_reference_valid = gold_reference.drop_duplicates(subset=["text_ocr"])
tmp  = ["ETS"] * len(gold_reference_valid)
gold_reference_valid["book"] = tmp
gold_reference_valid = gold_reference_valid[["brat","book"]] # TODO for the final dataset (without duplicated owners) : replace book default value by register reference
# Out:
# /tmp/ipykernel_330680/3697045028.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gold_reference_valid["book"] = tmp

# %%
# Print an example
gold_reference.iloc[1512]
# Out:
# id                       8f80f546-9a27-4ec9-8db1-8bdb2eb25c29
# text_ocr                          Guérin Louis→voiturier à id
# brat        [Guérin Louis→voiturier à id, [T0, name, Guéri...
# Name: 1512, dtype: object

# %% [markdown]
# ## 1.1 Create train/val/test subsets

# %%
import numpy as np
from sklearn.model_selection import train_test_split

train_tmp_df, test_df = train_test_split(
    gold_reference_valid, test_size=0.2, random_state=config.SPLIT_SEED)

train_df, val_df = train_test_split(
    train_tmp_df, test_size=0.1, random_state=config.SPLIT_SEED)

# %%
len(train_df), len(val_df), len(test_df)
# Out:
# (1534, 171, 427)

# %%
train = train_df.to_numpy()
val = val_df.to_numpy()
test = test_df.to_numpy()

# %%
from util_io import save_dataset_io

RES = OUT_BASE / f"m2-experiment_1_prepared_dataset_ref_io_{MODEL_NAME}"
if not os.path.exists(RES):
    os.makedirs(RES)
NAMES = ["train","dev","test"]

datasets = [train, val, test]
save_dataset_io(RES, datasets, NAMES, suffix=len(train))
# Out:
# 0
# Dodun de Keroman, le comte
# ['I-name', 'I-name', 'I-title', 'I-title'] [[0, 5], [5, 16], [18, 20], [20, 26]]
# 1
# Pillet Jean
# ['I-name', 'I-firstnames'] [[0, 6], [7, 11]]
# 2
# thomas→Bonfils V↑e↑ Bourg à Brie
# ['I-name', 'I-firstnames', 'I-address', 'I-familystatus'] [[7, 14], [0, 6], [28, 32], [15, 19]]
# 3
# Gachet à Paris
# ['I-name', 'I-address'] [[0, 6], [9, 14]]
# 4
# Macréau J↑n↓ B↑te↓→militaire
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-title'] [[0, 7], [8, 12], [12, 18], [19, 28]]
# 5
# Veillard Augustin→Berger à Valenton
# ['I-name', 'I-firstnames', 'I-activity', 'I-address'] [[0, 8], [9, 17], [18, 24], [27, 35]]
# 6
# Le Prince de Neufchâtel→×Vauguyon maire→de marolles±
# ['I-name', 'I-name', 'I-name', 'I-activity', 'I-activity'] [[0, 2], [2, 23], [25, 33], [34, 42], [42, 51]]
# 7
# Livernet Etienne
# ['I-name', 'I-firstnames'] [[0, 8], [9, 16]]
# 8
# Lecouteure pierre Marthe
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 10], [11, 17], [17, 24]]
# 9
# Nul ×Bourdillat pierre gilles±
# ['I-name', 'I-name', 'I-firstnames', 'I-firstnames'] [[0, 3], [5, 15], [16, 22], [22, 29]]
# 10
# Vienos V↑e↓ J↑n↓ louis, fils Jean bapt↑e↓→à vinc
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-address', 'I-familystatus'] [[0, 6], [12, 16], [16, 22], [44, 48], [7, 11]]
# 11
# Soudieux Pierre Louis
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 15], [15, 21]]
# 12
# Geffrier henri louis
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 14], [14, 20]]
# 13
# Bèquemont adolphe
# ['I-name', 'I-firstnames'] [[0, 9], [10, 17]]
# 14
# Galland françois→vig↑on↓ à id
# ['I-name', 'I-firstnames', 'I-activity', 'I-address'] [[0, 7], [8, 16], [17, 24], [27, 29]]
# 15
# ×Tiere aug↑te↓ athanase±→×Lannes±→Nul
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-name', 'I-name'] [[1, 6], [7, 14], [14, 23], [26, 32], [34, 37]]
# 16
# Veron V↑e↓
# ['I-name', 'I-familystatus'] [[0, 5], [6, 10]]
# 17
# Tribouillard Pierre→V↑e↓
# ['I-name', 'I-firstnames', 'I-familystatus'] [[0, 12], [13, 19], [20, 24]]
# 18
# Tiere aug↑te↓ athanase→×Lannes (L de→montebello)±
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-name', 'I-name'] [[0, 5], [6, 13], [13, 22], [24, 30], [30, 48]]
# 19
# Gauthier louis ch↑es↓ ×louis±→à Varennes
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-address'] [[0, 8], [9, 14], [14, 21], [32, 40]]
# 20
# hideline Louis
# ['I-name', 'I-firstnames'] [[0, 8], [9, 14]]
# 21
# fouilloux id
# ['I-name', 'I-firstnames'] [[0, 9], [10, 12]]
# 22
# Anastasie
# ['I-name'] [[0, 9]]
# 23
# Berthier
# ['I-name'] [[0, 8]]
# 24
# Leroy, fils de Clement
# ['I-name', 'I-familystatus', 'I-familystatus'] [[0, 5], [7, 11], [11, 22]]
# 25
# Pascallet Jean Bte Claude
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 9], [10, 14], [14, 25]]
# 26
# Cuchet auguste Marius
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 14], [14, 21]]
# 27
# Chanterelle Nicolas
# ['I-name', 'I-firstnames'] [[0, 11], [12, 19]]
# 28
# Issard fils a bry
# ['I-name', 'I-address', 'I-familystatus'] [[0, 6], [14, 17], [7, 11]]
# 29
# Delettre ernest
# ['I-name', 'I-firstnames'] [[0, 8], [9, 15]]
# 30
# Lemaitre, veuve
# ['I-name', 'I-familystatus'] [[0, 8], [10, 15]]
# 31
# Chatelain ch↑e↓→×Cousté p↑re↓ noël±
# ['I-name', 'I-firstnames', 'I-name', 'I-firstnames', 'I-firstnames'] [[0, 9], [10, 15], [17, 23], [24, 29], [29, 34]]
# 32
# Ancelot Nicolas J↑h↓
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 15], [15, 20]]
# 33
# Blocus henri
# ['I-name', 'I-firstnames'] [[0, 6], [7, 12]]
# 34
# Larmée J D
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 8], [8, 10]]
# 35
# Voie publique
# ['I-name', 'I-name'] [[0, 4], [4, 13]]
# 36
# Maton Pierre Jean Basile, Vitry
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-address'] [[0, 5], [6, 12], [12, 24], [26, 31]]
# 37
# Vienos V↑e↓ Pierre louis le jeune
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-familystatus', 'I-familystatus'] [[0, 6], [7, 11], [11, 24], [25, 27], [27, 33]]
# 38
# Dudouit
# ['I-name'] [[0, 7]]
# 39
# Rameau Jean françois
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 11], [11, 20]]
# 40
# Chatelain ch↑es↓ D↑t↓ brisset
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 9], [10, 16], [16, 29]]
# 41
# Delaune augustin à id
# ['I-name', 'I-firstnames', 'I-address'] [[0, 7], [8, 16], [19, 21]]
# 42
# Pichard Esther aubD. La reine
# ['I-name', 'I-firstnames', 'I-familystatus', 'I-familystatus'] [[0, 7], [8, 14], [17, 20], [20, 29]]
# 43
# Chalopin batelier
# ['I-name', 'I-activity'] [[0, 8], [9, 17]]
# 44
# Desnyau F↑re↓ Louis
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 13], [13, 19]]
# 45
# Cochet N↑as↓ fils rue de Paris 9
# ['I-name', 'I-firstnames', 'I-address', 'I-address', 'I-familystatus'] [[0, 6], [7, 12], [18, 21], [21, 32], [13, 17]]
# 46
# Roses
# ['I-name'] [[0, 5]]
# 47
# Fourré Louison→Vig↑ron↓ à Sucy
# ['I-name', 'I-firstnames', 'I-activity', 'I-address'] [[0, 6], [7, 14], [15, 23], [26, 30]]
# 48
# Delanoue p↑re↓ toussaint V↑e↓
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-familystatus'] [[0, 8], [9, 14], [14, 24], [25, 29]]
# 49
# Decamp marie alois
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 12], [12, 18]]
# 50
# Tellier pierre françois Cult↑v↓→à ablon
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-activity', 'I-address'] [[0, 7], [8, 14], [14, 23], [24, 31], [34, 39]]
# 51
# C↑ie↓ des chemins de fer de l'est
# ['I-name', 'I-name'] [[0, 5], [5, 33]]
# 52
# Vigoureux Jean→antoine militaire
# ['I-name', 'I-firstnames', 'I-activity'] [[0, 9], [10, 22], [23, 32]]
# 53
# Ferrière
# ['I-name'] [[0, 8]]
# 54
# Lecollant Veuve Pierre→à Limeil
# ['I-name', 'I-firstnames', 'I-address', 'I-familystatus'] [[0, 9], [16, 22], [25, 31], [10, 15]]
# 55
# Duchamps→pierre
# ['I-name', 'I-firstnames'] [[0, 8], [9, 15]]
# 56
# Galland pierre→a paris
# ['I-name', 'I-firstnames', 'I-address'] [[0, 7], [8, 14], [17, 22]]
# 57
# Sian
# ['I-name'] [[0, 4]]
# 58
# Caillet J↑n↓ Joseph
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 12], [12, 19]]
# 59
# Lebon Joseph
# ['I-name', 'I-firstnames'] [[0, 5], [6, 12]]
# 60
# Durube alexandre
# ['I-name', 'I-firstnames'] [[0, 6], [7, 16]]
# 61
# Gouvernement (le)
# ['I-name', 'I-name'] [[0, 12], [12, 17]]
# 62
# Bizet mathieu V↑e↓
# ['I-name', 'I-firstnames', 'I-familystatus'] [[0, 5], [6, 13], [14, 18]]
# 63
# Mazarot V↑e↓ Pierre
# ['I-name', 'I-firstnames', 'I-familystatus'] [[0, 7], [13, 19], [8, 12]]
# 64
# Thibout Joseph→bourgeois à paris
# ['I-name', 'I-firstnames', 'I-activity', 'I-address'] [[0, 7], [8, 14], [15, 24], [27, 32]]
# 65
# Lecoq g↑me↓ f↑ois↓ V↑e↓
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-familystatus'] [[0, 5], [6, 11], [11, 18], [19, 23]]
# 66
# Barillet paul désiré
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 13], [13, 20]]
# 67
# Fontaine, V↑e↓
# ['I-name', 'I-familystatus'] [[0, 8], [10, 14]]
# 68
# Cochet Georges
# ['I-name', 'I-firstnames'] [[0, 6], [7, 14]]
# 69
# Prunios Jean, gendre moreau→rue du chemin vert
# ['I-name', 'I-firstnames', 'I-address', 'I-address', 'I-familystatus', 'I-familystatus'] [[0, 7], [8, 12], [28, 31], [31, 46], [14, 20], [20, 27]]
# 70
# Tartet Veuve
# ['I-name', 'I-familystatus'] [[0, 6], [7, 12]]
# 71
# appey
# ['I-name'] [[0, 5]]
# 72
# Masson
# ['I-name'] [[0, 6]]
# 73
# Samson J↑n↓ B↑te↓→×Simon Louis±→Vig↑on↓
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-name', 'I-firstnames', 'I-activity'] [[0, 6], [7, 11], [11, 17], [19, 24], [25, 30], [32, 39]]
# 74
# Bonnelet p↑re↓
# ['I-name', 'I-firstnames'] [[0, 8], [9, 14]]
# 75
# Thévenard Louis adrien
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 9], [10, 15], [15, 22]]
# 76
# Sergent louis marie victor
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 13], [13, 26]]
# 77
# Doby augustin françois joseph
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 4], [5, 13], [13, 29]]
# 78
# Barreau G↑me↓ a Valenton
# ['I-name', 'I-firstnames', 'I-address'] [[0, 7], [8, 13], [16, 24]]
# 79
# Alfortville la C↑ne↓ (non imposable)
# ['I-name', 'I-name'] [[0, 11], [11, 20]]
# 80
# Guérin Joseph pere→vig↑on↓ à id
# ['I-name', 'I-firstnames', 'I-activity', 'I-address', 'I-familystatus'] [[0, 6], [7, 13], [19, 26], [29, 31], [14, 18]]
# 81
# Leclerc Claude félix
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 14], [14, 20]]
# 82
# Masareau P↑re↓
# ['I-name', 'I-firstnames'] [[0, 8], [9, 14]]
# 83
# Jeanneret Jean Baptiste
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 9], [10, 14], [14, 23]]
# 84
# Dodun de Kéroman agathe v↑ve↓→Moussac
# ['I-name', 'I-name', 'I-firstnames', 'I-familystatus', 'I-name'] [[0, 5], [5, 16], [17, 23], [24, 28], [30, 37]]
# 85
# Cornu pierre
# ['I-name', 'I-firstnames'] [[0, 5], [6, 12]]
# 86
# Coiffier charles armand
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 16], [16, 23]]
# 87
# Gueriu Ch↑ls↓ Saschal
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 13], [13, 21]]
# 88
# Letrec Jean f↑ois↓→×auvry ant↑e↓ blaise j↑n↓±
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 11], [11, 18], [20, 25], [26, 32], [32, 44]]
# 89
# Héricourt louis gabriel
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 9], [10, 15], [15, 23]]
# 90
# Cochet N↑as↓ Aug↑te↓
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 12], [12, 20]]
# 91
# ×eau±→Mazarot V↑e↓ Pierre→vig↑on↓ à id
# ['I-name', 'I-activity', 'I-address', 'I-familystatus'] [[6, 13], [26, 33], [36, 38], [14, 18]]
# 92
# de Nicolaï Le marquis
# ['I-name', 'I-name', 'I-title', 'I-title'] [[0, 2], [2, 10], [11, 13], [13, 21]]
# 93
# Lachasse claude Antoine→à Montreuil
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-address'] [[0, 8], [9, 15], [15, 23], [26, 35]]
# 94
# Capron H↑ers↓
# ['I-name', 'I-familystatus'] [[0, 6], [7, 13]]
# 95
# Guérin Joseph, fils→vig↑on↓ à idem
# ['I-name', 'I-firstnames', 'I-activity', 'I-address', 'I-familystatus'] [[0, 6], [7, 13], [20, 27], [30, 34], [15, 19]]
# 96
# Vitry françois et consorts
# ['I-name', 'I-firstnames', 'I-name', 'I-name'] [[0, 5], [6, 14], [15, 17], [17, 26]]
# 97
# Vitry Joseph Emmanuel V↑e↓
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-familystatus'] [[0, 5], [6, 12], [12, 21], [22, 26]]
# 98
# Touzelin marie julien
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 14], [14, 21]]
# 99
# Lapic françois Bonaventure
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 5], [6, 14], [14, 26]]
# 100
# Petit J↑n↓
# ['I-name', 'I-firstnames'] [[0, 5], [6, 10]]
# 101
# ×Guignot H↑rs↓ VN→Matao v❌t❌❌ honoré a vn
# ['I-name', 'I-address', 'I-familystatus', 'I-name', 'I-firstnames', 'I-firstnames', 'I-address'] [[1, 8], [15, 17], [9, 14], [18, 23], [24, 29], [29, 36], [39, 41]]
# 102
# Quéru pierre françois
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 5], [6, 12], [12, 21]]
# 103
# Commune de marolles→occupé par M↑r↓ Le curé
# ['I-name', 'I-name', 'I-activity', 'I-activity', 'I-title'] [[0, 7], [7, 19], [36, 38], [38, 43], [31, 35]]
# 104
# Pessoux Pere
# ['I-name', 'I-familystatus'] [[0, 7], [8, 12]]
# 105
# Morizot marie arnoult
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 13], [13, 21]]
# 106
# Joussard Jean louis
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 13], [13, 19]]
# 107
# Langlois Mathieu veuve
# ['I-name', 'I-firstnames', 'I-familystatus'] [[0, 8], [9, 16], [17, 22]]
# 108
# Baton mercier
# ['I-name', 'I-name'] [[0, 5], [5, 13]]
# 109
# Baloche bruneau
# ['I-name', 'I-firstnames'] [[0, 7], [8, 15]]
# 110
# l'Hospice de charenton
# ['I-name', 'I-name'] [[2, 9], [9, 22]]
# 111
# Cuinier
# ['I-name'] [[0, 7]]
# 112
# Samson→v↑on↓
# ['I-name', 'I-activity'] [[0, 6], [7, 12]]
# 113
# huard Joseph
# ['I-name', 'I-firstnames'] [[0, 5], [6, 12]]
# 114
# id→id→Rousselet Louis Joseph
# ['I-name', 'I-name', 'I-name', 'I-firstnames', 'I-firstnames'] [[0, 2], [0, 2], [6, 15], [16, 21], [21, 28]]
# 115
# Thioust louis victor à Vincennes
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-address'] [[0, 7], [8, 13], [13, 20], [23, 32]]
# 116
# Beuzeville thimothée fils
# ['I-name', 'I-firstnames', 'I-familystatus'] [[0, 10], [11, 20], [21, 25]]
# 117
# Louisser J↑n↓ J↑ques↓
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 13], [13, 21]]
# 118
# Hyon pierre louis
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 4], [5, 11], [11, 17]]
# 119
# Prinbel
# ['I-name'] [[0, 7]]
# 120
# Beuzeville charles, dit→Michon
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 10], [11, 18], [18, 30]]
# 121
# ×Lepine veuve acquereurs± Provost
# ['I-name', 'I-familystatus', 'I-name', 'I-activity'] [[1, 7], [8, 13], [26, 33], [14, 24]]
# 122
# Méry pierre Jean
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 4], [5, 11], [11, 16]]
# 123
# Le Grain ↑Joseph↓ leonard
# ['I-name', 'I-name', 'I-firstnames', 'I-firstnames'] [[0, 2], [2, 9], [9, 17], [17, 25]]
# 124
# Collignon
# ['I-name'] [[0, 9]]
# 125
# idem→×Vauguyon→maire de marolles±
# ['I-name', 'I-name', 'I-activity', 'I-activity'] [[0, 4], [6, 14], [15, 20], [20, 32]]
# 126
# Montmartre f↑çoise↓
# ['I-name', 'I-firstnames'] [[0, 10], [11, 19]]
# 127
# Vigoureux Gabriel→fab↑t↓ de bar à id
# ['I-name', 'I-firstnames', 'I-activity', 'I-activity', 'I-address'] [[0, 9], [10, 17], [18, 24], [24, 31], [34, 36]]
# 128
# Moloy J↑es↓ Jardinier→à Sucy
# ['I-name', 'I-firstnames', 'I-activity', 'I-address'] [[0, 5], [6, 11], [12, 21], [24, 28]]
# 129
# Chatelain ch↑u↓ d↑t↓ brisset
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 9], [10, 15], [15, 28]]
# 130
# Tourneur Barthel→my→vig↑on↓ à id
# ['I-name', 'I-firstnames', 'I-activity', 'I-address'] [[0, 8], [9, 19], [20, 27], [30, 32]]
# 131
# Bonne hercule→serrurier
# ['I-name', 'I-firstnames', 'I-activity'] [[0, 5], [6, 13], [14, 23]]
# 132
# huguet Louis→vig↑on↓ à id
# ['I-name', 'I-firstnames', 'I-activity', 'I-address'] [[0, 6], [7, 12], [13, 20], [23, 25]]
# 133
# Louvet Jean Bap↑te↓→la V↑ve↓ Cul↑v↓à mons
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-activity', 'I-address', 'I-familystatus'] [[0, 6], [7, 11], [11, 19], [29, 35], [37, 41], [23, 27]]
# 134
# Martin Simon
# ['I-name', 'I-firstnames'] [[0, 6], [7, 12]]
# 135
# Fountain thomas taylord
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 15], [15, 23]]
# 136
# Guay jacques fils
# ['I-name', 'I-firstnames', 'I-familystatus'] [[0, 4], [5, 12], [13, 17]]
# 137
# Bécheret Jean B↑te↓ fils
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-familystatus'] [[0, 8], [9, 13], [13, 19], [20, 24]]
# 138
# Delanoue g↑ain↓
# ['I-name', 'I-firstnames'] [[0, 8], [9, 15]]
# 139
# Serize à id
# ['I-name', 'I-address'] [[0, 6], [9, 11]]
# 140
# Padet alfred
# ['I-name', 'I-firstnames'] [[0, 5], [6, 12]]
# 141
# Minot Veuve
# ['I-name', 'I-familystatus'] [[0, 5], [6, 11]]
# 142
# Piedquin f↑ois↓ marie→Charon à brie-comte robert
# ['I-name', 'I-name', 'I-firstnames', 'I-firstnames', 'I-activity', 'I-address', 'I-address'] [[0, 8], [8, 9], [9, 15], [15, 21], [22, 28], [31, 35], [35, 48]]
# 143
# Boulogne antoine
# ['I-name', 'I-firstnames'] [[0, 8], [9, 16]]
# 144
# Valignon Philippe
# ['I-name', 'I-firstnames'] [[0, 8], [9, 17]]
# 145
# Sevin François, loc de→la Veuve Ravignes
# ['I-name', 'I-firstnames', 'I-familystatus', 'I-name', 'I-familystatus'] [[0, 5], [6, 14], [16, 19], [32, 40], [26, 31]]
# 146
# Potel jean Crisostôme
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 5], [6, 10], [10, 21]]
# 147
# hospices
# ['I-name'] [[0, 8]]
# 148
# Cochet Jean Marc mathieu→×Bourdilliat pierre gilles
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 11], [11, 24], [26, 37], [38, 44], [44, 51]]
# 149
# Le Prince de→neufchâtel
# ['I-name', 'I-name'] [[0, 2], [2, 23]]
# 150
# fauguer ×les héritiers±→f↑ois↓ ×joseph±
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-familystatus', 'I-familystatus'] [[0, 7], [24, 30], [30, 39], [9, 12], [12, 22]]
# 151
# Barrey Pierre→Garde Champètre
# ['I-name', 'I-firstnames', 'I-activity', 'I-activity'] [[0, 6], [7, 13], [14, 19], [19, 29]]
# 152
# Perrin fois→×Marty à Paris±
# ['I-name', 'I-name', 'I-address', 'I-name', 'I-address'] [[0, 6], [6, 11], [21, 26], [13, 18], [21, 26]]
# 153
# moncouteau germain jean
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 10], [11, 18], [18, 23]]
# 154
# Coiffier pierre hervé
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 15], [15, 21]]
# 155
# Maintrieux f↑ois↓
# ['I-name', 'I-firstnames'] [[0, 10], [11, 17]]
# 156
# Thibaud Jean charles
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 12], [12, 20]]
# 157
# Hablot Bernard
# ['I-name', 'I-firstnames'] [[0, 6], [7, 14]]
# 158
# Michaud Germain
# ['I-name', 'I-firstnames'] [[0, 7], [8, 15]]
# 159
# Dodun de Keroman, le Comte
# ['I-name', 'I-name', 'I-title', 'I-title'] [[0, 5], [5, 16], [18, 20], [20, 26]]
# 160
# Martin Maréchal
# ['I-name', 'I-firstnames'] [[0, 6], [7, 15]]
# 161
# Bataille claude françois
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 15], [15, 24]]
# 162
# Guérin V↑e↓ Laurent→vig↑on↓ à id
# ['I-name', 'I-firstnames', 'I-activity', 'I-address', 'I-familystatus'] [[0, 6], [12, 19], [20, 27], [30, 32], [7, 11]]
# 163
# Ragondé
# ['I-name'] [[0, 7]]
# 164
# Gerando (de)
# ['I-name', 'I-name'] [[0, 7], [7, 12]]
# 165
# Cheret alphonse
# ['I-name', 'I-firstnames'] [[0, 6], [7, 15]]
# 166
# Boulmier françois id
# ['I-name', 'I-firstnames', 'I-address'] [[0, 8], [9, 17], [18, 20]]
# 167
# Gévaudan
# ['I-name'] [[0, 8]]
# 168
# Le Prince de Neufchâtel→×Vauguyon, maire→de marolles±
# ['I-name', 'I-name', 'I-name', 'I-activity', 'I-activity'] [[0, 2], [2, 23], [25, 33], [35, 43], [43, 52]]
# 169
# V↑e↓ Lecolant al↑ cl↑de↓
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-familystatus'] [[5, 13], [14, 17], [17, 24], [0, 4]]
# 170
# Leroy louis georges
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 5], [6, 11], [11, 19]]
# 171
# Hue alexandre
# ['I-name', 'I-firstnames'] [[0, 3], [4, 13]]
# 172
# Lameau D↑que↓
# ['I-name', 'I-firstnames'] [[0, 6], [7, 13]]
# 173
# Laizier Jacques
# ['I-name', 'I-firstnames'] [[0, 7], [8, 15]]
# 174
# Gauthier ×M↑lle↓±→louis charles à Varennes
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-address'] [[0, 8], [18, 23], [23, 31], [34, 42]]
# 175
# Polack Joseph
# ['I-name', 'I-firstnames'] [[0, 6], [7, 13]]
# 176
# Commune→de marolles
# ['I-name', 'I-name'] [[0, 10], [10, 19]]
# 177
# Héricourt françois maurice
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 9], [10, 18], [18, 26]]
# 178
# Le Prince de neufchâtel→×Vauguyon→maire de marolles±
# ['I-name', 'I-name', 'I-name', 'I-activity', 'I-activity'] [[0, 2], [2, 23], [25, 33], [34, 39], [39, 51]]
# 179
# habert→général
# ['I-name', 'I-activity'] [[0, 6], [7, 14]]
# 180
# Corbes alfred eugène
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 13], [13, 20]]
# 181
# ×J↑n↓ B↑te↓±→Samson J↑n↓ B↑te↓→×simon antoine±→vig à marolles
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-activity', 'I-address', 'I-name', 'I-firstnames'] [[13, 19], [1, 5], [5, 11], [47, 50], [53, 61], [32, 37], [38, 45]]
# 182
# Bonne hercule
# ['I-name', 'I-firstnames'] [[0, 5], [6, 13]]
# 183
# Leorüe
# ['I-name'] [[0, 6]]
# 184
# Pierlot→Banquier à Paris
# ['I-name', 'I-activity', 'I-address'] [[0, 7], [8, 16], [19, 24]]
# 185
# id id id
# ['I-name', 'I-firstnames'] [[0, 2], [0, 2]]
# 186
# Villagier
# ['I-name'] [[0, 9]]
# 187
# Guérin Jacq henry→maçon à id
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-activity', 'I-address'] [[0, 6], [7, 11], [11, 17], [18, 23], [26, 28]]
# 188
# Anjain auguste joseph
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 14], [14, 21]]
# 189
# Poinsot pierre
# ['I-name', 'I-firstnames'] [[0, 7], [8, 14]]
# 190
# Lefevre Jacques→adjoint du maire
# ['I-name', 'I-firstnames', 'I-activity', 'I-activity'] [[0, 7], [8, 15], [16, 23], [23, 32]]
# 191
# Dammartin
# ['I-name'] [[0, 9]]
# 192
# Chevreau Jean Pierre à Vincennes
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-address'] [[0, 8], [9, 13], [13, 20], [23, 32]]
# 193
# Grave françois henri
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 5], [6, 14], [14, 20]]
# 194
# Dameville Martin
# ['I-name', 'I-firstnames'] [[0, 9], [10, 16]]
# 195
# Moret et consors
# ['I-name', 'I-name', 'I-name'] [[0, 5], [6, 8], [8, 16]]
# 196
# Desnyau P↑re↓ andré
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 13], [13, 19]]
# 197
# Misgault J↑n↓ B↑te↓ fils louis
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-name', 'I-firstnames', 'I-familystatus'] [[0, 8], [9, 13], [13, 19], [0, 8], [25, 30], [20, 24]]
# 198
# Desnon Jean Poerre, à→montreuil
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-address'] [[0, 6], [7, 11], [11, 18], [22, 31]]
# 199
# Sauthier Jean père
# ['I-name', 'I-firstnames', 'I-familystatus'] [[0, 8], [9, 13], [14, 18]]
# 200
# Villerou
# ['I-name'] [[0, 8]]
# 201
# Coulombier J↑ques↓ H↑ers↓
# ['I-name', 'I-firstnames', 'I-familystatus'] [[0, 10], [11, 18], [19, 25]]
# 202
# Chandennies p↑re↓ f↑ois↓
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 11], [12, 17], [17, 24]]
# 203
# Reuzeville charles alexis
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 10], [11, 18], [18, 25]]
# 204
# Bazin Ph↑e↓
# ['I-name', 'I-firstnames'] [[0, 5], [6, 11]]
# 205
# Chatenay louis→théodore
# ['I-name', 'I-firstnames'] [[0, 8], [9, 23]]
# 206
# Piedquin f↑ois↓ Marie
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 15], [15, 21]]
# 207
# Guerin Joseph→fils
# ['I-name', 'I-firstnames', 'I-familystatus'] [[0, 6], [7, 13], [14, 18]]
# 208
# Lamotte V↑e↓
# ['I-name', 'I-familystatus'] [[0, 7], [8, 12]]
# 209
# Dreux mathieu
# ['I-name', 'I-firstnames'] [[0, 5], [6, 13]]
# 210
# Thevenez Et↑e↓ ant↑e↓
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 14], [14, 21]]
# 211
# Deunougeot françois xavier
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 10], [11, 19], [19, 26]]
# 212
# Piedquin, f↑ois↓ marie→Charon à Brie
# ['I-name', 'I-name', 'I-firstnames', 'I-firstnames', 'I-activity', 'I-address'] [[0, 8], [8, 9], [10, 16], [16, 22], [23, 29], [32, 36]]
# 213
# Chamblin philippe
# ['I-name', 'I-firstnames'] [[0, 8], [9, 17]]
# 214
# Beaupied Jean Jacques
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 13], [13, 21]]
# 215
# Bécharet Jean Pierre, g↑dre↓→Lamour, à Fontenay
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-address', 'I-familystatus'] [[0, 8], [9, 13], [13, 20], [39, 47], [22, 35]]
# 216
# Deu j↑n↓ B↑te↓ gendre mauciut
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-familystatus', 'I-familystatus'] [[0, 3], [4, 8], [8, 14], [15, 21], [21, 29]]
# 217
# Maréchal pierre
# ['I-name', 'I-firstnames'] [[0, 8], [9, 15]]
# 218
# Bronzac pierre
# ['I-name', 'I-firstnames'] [[0, 7], [8, 14]]
# 219
# Moulinet alphonse
# ['I-name', 'I-firstnames'] [[0, 8], [9, 17]]
# 220
# Luisette Claude
# ['I-name', 'I-firstnames'] [[0, 8], [9, 15]]
# 221
# Baclin Ch↑les↓ Vig↑on↓ VN
# ['I-name', 'I-firstnames', 'I-activity', 'I-address'] [[0, 6], [7, 14], [15, 22], [23, 25]]
# 222
# Gaston Jules édouard
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 12], [12, 20]]
# 223
# Mazarot Pierre→Cabareteir à id
# ['I-name', 'I-firstnames', 'I-activity', 'I-address'] [[0, 7], [8, 14], [15, 25], [28, 30]]
# 224
# Delanoue pre toussains
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 12], [12, 22]]
# 225
# Galland, auguste→vig↑on↓ à id
# ['I-name', 'I-name', 'I-firstnames', 'I-activity', 'I-address'] [[0, 7], [7, 8], [9, 16], [17, 24], [27, 29]]
# 226
# Demont
# ['I-name'] [[0, 6]]
# 227
# Deville françois deutier
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 16], [16, 24]]
# 228
# Varlet J↑ques↓
# ['I-name', 'I-firstnames'] [[0, 6], [7, 14]]
# 229
# Robin pierre
# ['I-name', 'I-firstnames'] [[0, 5], [6, 12]]
# 230
# Subtil Denis Pierre
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 12], [12, 19]]
# 231
# Mayeux nicolas
# ['I-name', 'I-firstnames'] [[0, 6], [7, 14]]
# 232
# Moreau Pierre→Pâtre à Grosbois
# ['I-name', 'I-firstnames', 'I-activity', 'I-address'] [[0, 6], [7, 13], [14, 19], [22, 30]]
# 233
# Barré Louis
# ['I-name', 'I-firstnames'] [[0, 5], [6, 11]]
# 234
# Montmarthe Philippe Antoine→Nicolas
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 10], [11, 19], [19, 35]]
# 235
# Convers edme ernest
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 12], [12, 19]]
# 236
# Coiffier ch↑es↓ ×Père± vincent
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-familystatus'] [[0, 8], [9, 15], [23, 30], [17, 21]]
# 237
# Boireau antoine
# ['I-name', 'I-firstnames'] [[0, 7], [8, 15]]
# 238
# Lebourlier n↑as↓ hector
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 10], [11, 16], [16, 23]]
# 239
# Lusselle V↑e↓ Cyr
# ['I-name', 'I-firstnames', 'I-familystatus'] [[0, 8], [14, 17], [9, 13]]
# 240
# fleury J. B↑te↓
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 9], [9, 15]]
# 241
# ×Charpentier± id
# ['I-name', 'I-name'] [[1, 12], [14, 16]]
# 242
# Lalégery Denis joseph
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 14], [14, 21]]
# 243
# Saussay Père
# ['I-name', 'I-familystatus'] [[0, 7], [8, 12]]
# 244
# Gallais Joseph
# ['I-name', 'I-firstnames'] [[0, 7], [8, 14]]
# 245
# Bachereau léopold arsène
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 9], [10, 17], [17, 24]]
# 246
# Lompageu P↑re↓ jean
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 14], [14, 19]]
# 247
# Guézard noël f↑ois↓
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 12], [12, 19]]
# 248
# V↑e↓ Godefroid
# ['I-name', 'I-familystatus'] [[5, 14], [0, 4]]
# 249
# Mouginot
# ['I-name'] [[0, 8]]
# 250
# J↑n↓ J↑ques↓ denis→Godefroy denis Ch↑re↓ J↑n↓
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-name', 'I-firstnames', 'I-firstnames'] [[0, 4], [5, 12], [12, 18], [19, 27], [28, 33], [33, 45]]
# 251
# Lapie Léon louis
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 5], [6, 10], [10, 16]]
# 252
# Massuet ↑cyr↓ J↑n↓ baptiste
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 13], [13, 27]]
# 253
# C↑ie↓ des ch↑mins↓ de fer de l'Est
# ['I-name', 'I-name'] [[0, 5], [5, 34]]
# 254
# Cotty
# ['I-name'] [[0, 5]]
# 255
# Doé albert philippe
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 3], [4, 10], [10, 19]]
# 256
# Dubois Petié Louis Charles André, Paris
# ['I-name', 'I-name', 'I-firstnames', 'I-firstnames', 'I-address'] [[0, 6], [6, 12], [13, 18], [18, 32], [34, 39]]
# 257
# Becquemont adolphe→(Didier à charenton pour→droit de passage)
# ['I-name', 'I-firstnames', 'I-name', 'I-address'] [[0, 10], [11, 18], [20, 26], [29, 38]]
# 258
# Mouscadet Pierre Grégoire→à Fontenay
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-address'] [[0, 9], [10, 16], [16, 25], [28, 36]]
# 259
# Motteau h↑ers↓→Germain
# ['I-name', 'I-familystatus'] [[0, 7], [8, 22]]
# 260
# Vilain Louis→vig
# ['I-name', 'I-firstnames', 'I-activity'] [[0, 6], [7, 12], [13, 16]]
# 261
# Vigoureux françois→vig↑on↓ à idem
# ['I-name', 'I-firstnames', 'I-activity', 'I-address'] [[0, 9], [10, 18], [19, 26], [29, 33]]
# 262
# Misgault louis mineur
# ['I-name', 'I-firstnames', 'I-familystatus'] [[0, 8], [9, 14], [15, 21]]
# 263
# Marinier francis barthélemy
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 16], [16, 27]]
# 264
# Coiffier Pierre Louis
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 15], [15, 21]]
# 265
# Boucot pierre Etienne Louis
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 13], [13, 27]]
# 266
# Goyard Gervais det Brunot
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 14], [14, 25]]
# 267
# Archambault pavel nicolas
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 11], [12, 17], [17, 25]]
# 268
# ×Saillon fait cour±→×Duchamps serrurier au Kremlin±
# ['I-name', 'I-name', 'I-name', 'I-activity', 'I-address'] [[1, 8], [8, 18], [21, 29], [30, 39], [43, 50]]
# 269
# Pierre Pierre
# ['I-name', 'I-firstnames'] [[0, 6], [0, 6]]
# 270
# Chevreau (h↑ers↓ françois aug↑n↓)
# ['I-name', 'I-familystatus', 'I-familystatus'] [[0, 8], [10, 16], [16, 32]]
# 271
# Muris Paul Laurent
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 5], [6, 10], [10, 18]]
# 272
# Guerin Joseph, jean→Vig↑on↓ à id
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-activity', 'I-address'] [[0, 6], [7, 13], [13, 19], [20, 27], [30, 32]]
# 273
# Costy Jean Marc Tailleur→de pierre à ablon
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-activity', 'I-activity', 'I-address'] [[0, 5], [6, 10], [10, 15], [16, 27], [27, 34], [37, 42]]
# 274
# Bongent
# ['I-name'] [[0, 7]]
# 275
# Chatenet Rémy
# ['I-name', 'I-firstnames'] [[0, 8], [9, 13]]
# 276
# N↑v↓ Cury
# ['I-name', 'I-name'] [[0, 4], [4, 9]]
# 277
# Mitauls Jean, route de Charenton
# ['I-name', 'I-firstnames', 'I-address', 'I-address'] [[0, 7], [8, 12], [14, 19], [19, 32]]
# 278
# Benoit alex↑dre↓
# ['I-name', 'I-firstnames'] [[0, 6], [7, 16]]
# 279
# Ancelet Alexandre
# ['I-name', 'I-firstnames'] [[0, 7], [8, 17]]
# 280
# Ancelle à Evreux→Bennet V↑e↓
# ['I-name', 'I-address', 'I-name', 'I-familystatus'] [[0, 7], [10, 16], [17, 23], [24, 28]]
# 281
# ×Vauguyon→maire±
# ['I-name', 'I-activity'] [[1, 9], [10, 15]]
# 282
# Léglise J↑n↓ pierre
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 12], [12, 19]]
# 283
# ×Forgé±→St Arnoulx
# ['I-name', 'I-name', 'I-name'] [[1, 6], [8, 10], [10, 18]]
# 284
# Moulinoi V↑ve↓ Ant↑e↓
# ['I-name', 'I-firstnames', 'I-familystatus'] [[0, 8], [15, 21], [9, 14]]
# 285
# Duclos J B↑te↓ L.
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 8], [8, 17]]
# 286
# Coiffier f↑ois↓ dit séraphin
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 15], [15, 28]]
# 287
# Bordier pierre
# ['I-name', 'I-firstnames'] [[0, 7], [8, 14]]
# 288
# Rameau louis Victor
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 12], [12, 19]]
# 289
# Dabé claude
# ['I-name', 'I-firstnames'] [[0, 4], [5, 11]]
# 290
# Travailleur émile
# ['I-name', 'I-firstnames'] [[0, 11], [12, 17]]
# 291
# Prieur aimé J↑n↓ b↑te↓
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 11], [11, 22]]
# 292
# Gallais Julien
# ['I-name', 'I-firstnames'] [[0, 7], [8, 14]]
# 293
# huart joseph
# ['I-name', 'I-firstnames'] [[0, 5], [6, 12]]
# 294
# Royer Jean louis, route de→charenton
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-address', 'I-address'] [[0, 5], [6, 10], [10, 16], [18, 23], [23, 36]]
# 295
# Coudrai aug↑te↓ andré→vig↑on↓ à marolles
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-activity', 'I-address'] [[0, 7], [8, 15], [15, 21], [22, 29], [32, 40]]
# 296
# Buchy pierre gustave
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 5], [6, 12], [12, 20]]
# 297
# Lecomte charles vincent
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 15], [15, 23]]
# 298
# Galland antoine→romain V↑on↓
# ['I-name', 'I-firstnames', 'I-activity'] [[0, 7], [8, 22], [23, 28]]
# 299
# Héricourt Germain, fils→Cun❌❌urd
# ['I-name', 'I-firstnames', 'I-familystatus'] [[0, 9], [10, 17], [19, 32]]
# 300
# Amiot J↑n↓ florentin à p. frambourg
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-address', 'I-address'] [[0, 5], [6, 10], [10, 20], [23, 25], [25, 35]]
# 301
# Fountaine thomas taylor
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 9], [10, 16], [16, 23]]
# 302
# Dancourt
# ['I-name'] [[0, 8]]
# 303
# Leclerc p↑re↓ louis
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 13], [13, 19]]
# 304
# Barrey Pierre→garde champêtre
# ['I-name', 'I-firstnames', 'I-activity', 'I-activity'] [[0, 6], [7, 13], [14, 19], [19, 29]]
# 305
# gaudoil
# ['I-name'] [[0, 7]]
# 306
# Gratté×y± rue montgolfier
# ['I-name', 'I-address', 'I-address'] [[0, 6], [10, 13], [13, 25]]
# 307
# Touzelin marie Julien
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 14], [14, 21]]
# 308
# Bachelier
# ['I-name'] [[0, 9]]
# 309
# Mortier claude
# ['I-name', 'I-firstnames'] [[0, 7], [8, 14]]
# 310
# Barreau Guillaume
# ['I-name', 'I-firstnames'] [[8, 17], [8, 17]]
# 311
# Chaillou pierre julien
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 15], [15, 22]]
# 312
# Basire guill↑e↓ Veuve
# ['I-name', 'I-firstnames', 'I-familystatus'] [[0, 6], [7, 15], [16, 21]]
# 313
# Vaudoyer Régis père
# ['I-name', 'I-firstnames', 'I-familystatus'] [[0, 8], [9, 14], [15, 19]]
# 314
# Basset Philippe, V↑e↓, yères
# ['I-name', 'I-firstnames', 'I-address', 'I-familystatus'] [[0, 6], [7, 15], [23, 28], [17, 21]]
# 315
# fouilloux j↑ean↓ id
# ['I-name', 'I-firstnames'] [[0, 9], [10, 16]]
# 316
# Merillon J↑n↓
# ['I-name', 'I-firstnames'] [[0, 8], [9, 13]]
# 317
# Perous
# ['I-name'] [[0, 6]]
# 318
# Girard pierre françois
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 13], [13, 22]]
# 319
# Didouvre p↑re↓ f↑ois↓
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 14], [14, 21]]
# 320
# ancelet J↑n↓ louis ant↑e↓
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 12], [12, 25]]
# 321
# Giot Veuve
# ['I-name', 'I-familystatus'] [[0, 4], [5, 10]]
# 322
# Becquerelle Jean François
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 11], [12, 16], [16, 25]]
# 323
# Delaporte Louis félix aug↑te↓
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 9], [10, 15], [15, 29]]
# 324
# Mérillon auguste veuve
# ['I-name', 'I-firstnames', 'I-title'] [[0, 8], [9, 16], [17, 22]]
# 325
# Guérin Joseph père→Vig↑on↓ à id
# ['I-name', 'I-firstnames', 'I-activity', 'I-address', 'I-familystatus'] [[0, 6], [7, 13], [19, 26], [29, 31], [14, 18]]
# 326
# Camot ×Gervaix± Pierre
# ['I-name', 'I-name', 'I-firstnames'] [[7, 14], [0, 5], [16, 22]]
# 327
# Lameau louis jules
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 12], [12, 18]]
# 328
# Romanet frederic V↑e↓
# ['I-name', 'I-firstnames', 'I-familystatus'] [[0, 7], [8, 16], [17, 21]]
# 329
# Diéterlé J↑n↓ frédéric
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 13], [13, 22]]
# 330
# C↑ie↓ des che↑ins↓ de fer de l'Est
# ['I-name', 'I-name'] [[0, 5], [5, 34]]
# 331
# Poles Léon augustin
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 5], [6, 10], [10, 19]]
# 332
# houdé jean hilaire
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 5], [6, 10], [10, 18]]
# 333
# Gauthier Veuve
# ['I-name', 'I-familystatus'] [[0, 8], [9, 14]]
# 334
# Pescheux germain p↑re↓
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 16], [16, 22]]
# 335
# Vienoz pierre Philippe Spire
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 13], [13, 28]]
# 336
# Thévenoi jean louis père g↑dre↓ bizon, vitry
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-address', 'I-familystatus', 'I-familystatus', 'I-familystatus'] [[0, 8], [9, 13], [13, 19], [39, 44], [20, 24], [25, 31], [31, 37]]
# 337
# Joinville (Commune de)
# ['I-name', 'I-name'] [[0, 9], [9, 22]]
# 338
# hédelin J↑n↓ corentin
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 12], [12, 21]]
# 339
# Ivry la Commune
# ['I-name', 'I-name'] [[0, 4], [4, 15]]
# 340
# Gautier Charles aimé à→Périgny
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-address'] [[0, 7], [8, 15], [15, 20], [23, 30]]
# 341
# Le Cocq Jacques
# ['I-name', 'I-name', 'I-firstnames'] [[0, 2], [2, 7], [8, 15]]
# 342
# Guillemmiot Paul
# ['I-name', 'I-firstnames'] [[0, 11], [12, 16]]
# 343
# Barillet eugène auguste
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 15], [15, 23]]
# 344
# Basset Germain
# ['I-name', 'I-firstnames'] [[0, 6], [7, 14]]
# 345
# Royer Jean louis mathieu id
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-address'] [[0, 5], [6, 10], [10, 24], [25, 27]]
# 346
# Héricourt Pierre Saturnin
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 9], [10, 16], [16, 25]]
# 347
# queru Jean louis
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 5], [6, 10], [10, 16]]
# 348
# Fontaine françois J↑h↓
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 17], [17, 22]]
# 349
# Baron N↑as↓
# ['I-name', 'I-firstnames'] [[0, 5], [6, 11]]
# 350
# Ponçart
# ['I-name'] [[0, 7]]
# 351
# Ancelet louis auguste et Rethers henri
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-name', 'I-firstnames'] [[0, 7], [8, 13], [13, 21], [25, 32], [33, 38]]
# 352
# Moulinot V↑ve↓ Guill.
# ['I-name', 'I-firstnames', 'I-familystatus'] [[0, 8], [15, 21], [9, 14]]
# 353
# Viénos J↑n↓ f↑ois↓
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 11], [11, 18]]
# 354
# Desmaisons
# ['I-name'] [[0, 10]]
# 355
# Chaillou pierre Julien
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 15], [15, 22]]
# 356
# Soudieux adolphe laurent
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 16], [16, 24]]
# 357
# Mouscadet pierre louis
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 9], [10, 16], [16, 22]]
# 358
# Chevalier martin
# ['I-name', 'I-firstnames'] [[0, 9], [10, 16]]
# 359
# Fleury pierre, traiteur, route→de charenton
# ['I-name', 'I-firstnames', 'I-activity', 'I-address', 'I-address'] [[0, 6], [7, 13], [15, 23], [25, 33], [33, 43]]
# 360
# Ancelot nicolas, dit ancelon→Veuve
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-familystatus'] [[0, 7], [8, 15], [15, 28], [29, 34]]
# 361
# Galland Louis N↑as↓
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 13], [13, 19]]
# 362
# Guillain Pierre françois
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 15], [15, 24]]
# 363
# Quinos françois dit Lafrance à→Choisy le roi
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-address', 'I-address'] [[0, 6], [7, 15], [15, 28], [31, 37], [37, 44]]
# 364
# Romanet frederic V↑e↓→×Marquis J↑n↓ b↑te↓±
# ['I-name', 'I-firstnames', 'I-familystatus', 'I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 16], [17, 21], [23, 30], [31, 35], [35, 41]]
# 365
# Doublié Veuve
# ['I-name', 'I-familystatus'] [[0, 7], [8, 13]]
# 366
# Corbier émile Joseph
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 13], [13, 20]]
# 367
# Sève antoine
# ['I-name', 'I-firstnames'] [[0, 4], [5, 12]]
# 368
# Vitry, Guillaume, à vinc
# ['I-name', 'I-firstnames', 'I-address'] [[0, 5], [7, 16], [20, 24]]
# 369
# audry toussaint p↑re↓
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 5], [6, 15], [15, 21]]
# 370
# Montmarthe V↑e↓ ant↑e↓
# ['I-name', 'I-firstnames', 'I-familystatus'] [[0, 10], [16, 22], [11, 15]]
# 371
# Muzard P↑re↓ marie rue du Liégat
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-address', 'I-address'] [[0, 6], [7, 12], [12, 18], [19, 22], [22, 32]]
# 372
# Leblanc bijoutier à Paris
# ['I-name', 'I-activity', 'I-address'] [[0, 7], [8, 17], [20, 25]]
# 373
# ferres louise désiré gertrude
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 13], [13, 29]]
# 374
# Dréaux Laurent, à Montreuil
# ['I-name', 'I-firstnames', 'I-address'] [[0, 6], [7, 14], [18, 27]]
# 375
# Bonne hercule→serrurier à id
# ['I-name', 'I-firstnames', 'I-activity', 'I-address'] [[0, 5], [6, 13], [14, 23], [26, 28]]
# 376
# Pradat Paul
# ['I-name', 'I-firstnames'] [[0, 6], [7, 11]]
# 377
# Guerin Joseph pere
# ['I-name', 'I-firstnames', 'I-title'] [[0, 6], [7, 13], [14, 18]]
# 378
# Jarrier Joseph
# ['I-name', 'I-firstnames'] [[0, 7], [8, 14]]
# 379
# Duchâteau Jean→maçon
# ['I-name', 'I-firstnames', 'I-activity'] [[0, 9], [10, 14], [15, 20]]
# 380
# Le Prince de neuchâtel→×Vauguyon→maire de Marolles±
# ['I-name', 'I-name', 'I-name', 'I-activity', 'I-activity'] [[0, 2], [2, 22], [24, 32], [33, 38], [38, 50]]
# 381
# Aubert marie
# ['I-name', 'I-firstnames'] [[0, 6], [7, 12]]
# 382
# Nachbroun Ignace
# ['I-name', 'I-firstnames'] [[0, 9], [10, 16]]
# 383
# Moreau François→terassier à id
# ['I-name', 'I-firstnames', 'I-activity', 'I-address'] [[0, 6], [7, 15], [16, 25], [28, 30]]
# 384
# Metivier Louis F↑re↓
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 14], [14, 20]]
# 385
# Bouillet hippolyte
# ['I-name', 'I-firstnames'] [[0, 8], [9, 18]]
# 386
# Ancelet nicolas J↑h↓
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 15], [15, 20]]
# 387
# David victor évariste
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 5], [6, 12], [12, 21]]
# 388
# Freret Pierre Jean marie à S↑t↓ Mandé
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-address', 'I-address'] [[0, 6], [7, 13], [13, 24], [27, 31], [31, 37]]
# 389
# Saussary fils
# ['I-name', 'I-familystatus'] [[0, 8], [9, 13]]
# 390
# Courtaigne françois
# ['I-name', 'I-firstnames'] [[0, 10], [11, 19]]
# 391
# Pouittet ❌↑an↓ michel VN→raffineur
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-activity', 'I-address'] [[0, 8], [9, 14], [14, 21], [25, 34], [22, 24]]
# 392
# ferrière Louis
# ['I-name', 'I-firstnames'] [[0, 8], [9, 14]]
# 393
# Jolly hippolite
# ['I-name', 'I-firstnames'] [[0, 5], [6, 15]]
# 394
# Brodin charles guillaume
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 14], [14, 24]]
# 395
# Clémencet charlotte aimée d↑elle↓
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-title'] [[0, 9], [10, 19], [19, 25], [26, 32]]
# 396
# Chamiot propser
# ['I-name', 'I-firstnames'] [[0, 7], [8, 15]]
# 397
# Galland Louis→nicolas
# ['I-name', 'I-firstnames'] [[0, 7], [8, 21]]
# 398
# Leroy sauveur gabriel
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 5], [6, 13], [13, 21]]
# 399
# Phillippitz Frédéric
# ['I-name', 'I-firstnames'] [[0, 11], [12, 20]]
# 400
# Pillet And↑e↓ J↑❌❌❌↓ marie rue du four 16
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-address', 'I-address'] [[0, 6], [7, 13], [13, 26], [27, 30], [30, 41]]
# 401
# Blos Et↑ne↓
# ['I-name', 'I-firstnames'] [[0, 4], [5, 11]]
# 402
# Collin Jean B↑te↓
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 11], [11, 17]]
# 403
# Galland Louis N↑as↓→Vig↑on↓ à id
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-activity', 'I-address'] [[0, 7], [8, 13], [13, 19], [20, 27], [30, 32]]
# 404
# Benoist Veuve→Jean
# ['I-name', 'I-firstnames', 'I-familystatus'] [[0, 7], [14, 18], [8, 13]]
# 405
# Desnoyers
# ['I-name'] [[0, 9]]
# 406
# Gauthier Louis→à Valenton
# ['I-name', 'I-firstnames', 'I-address'] [[0, 8], [9, 14], [17, 25]]
# 407
# Milcent Philippe J↑ques↓ louis
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 16], [16, 30]]
# 408
# Rameau Roch Quentin
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 11], [11, 19]]
# 409
# huart D↑ire↓
# ['I-name', 'I-firstnames'] [[0, 5], [6, 12]]
# 410
# Caluivé (de) nestor jean marie
# ['I-name', 'I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [7, 12], [13, 19], [19, 30]]
# 411
# ×Savart françois nicolas±
# ['I-name', 'I-firstnames', 'I-firstnames'] [[1, 7], [8, 16], [16, 24]]
# 412
# hallé f n↑as↓ j↑n↓
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 5], [6, 7], [7, 18]]
# 413
# Aubry michel
# ['I-name', 'I-firstnames'] [[0, 5], [6, 12]]
# 414
# Michin auguste
# ['I-name', 'I-firstnames'] [[0, 6], [7, 14]]
# 415
# Leroy Jean
# ['I-name', 'I-firstnames'] [[0, 5], [6, 10]]
# 416
# Berger Louis
# ['I-name', 'I-name', 'I-firstnames'] [[0, 6], [6, 7], [7, 12]]
# 417
# Chamarande Etienne
# ['I-name', 'I-firstnames'] [[0, 10], [11, 18]]
# 418
# Lameau V↑e↓ Sat↑in↓
# ['I-name', 'I-firstnames', 'I-familystatus'] [[0, 6], [12, 19], [7, 11]]
# 419
# Vaudoyer Louis honoré
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 14], [14, 21]]
# 420
# Barré louis marie Joseph
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 5], [6, 11], [11, 24]]
# 421
# Debaisse maire→à Santeny
# ['I-name', 'I-activity', 'I-address'] [[0, 8], [9, 14], [17, 24]]
# 422
# Chemin nicolas Etienne
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 14], [14, 22]]
# 423
# Josset Jean Veuve
# ['I-name', 'I-firstnames', 'I-familystatus'] [[0, 6], [7, 11], [12, 17]]
# 424
# Lemaire pierre joseph
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 14], [14, 21]]
# 425
# Rague V↑ve↓ toujaud
# ['I-name', 'I-familystatus'] [[0, 5], [6, 11]]
# 426
# Gerande (de)
# ['I-name', 'I-name'] [[0, 7], [7, 12]]
# 427
# Cretté hector jeune
# ['I-name', 'I-firstnames', 'I-familystatus'] [[0, 6], [7, 13], [14, 19]]
# 428
# Jouette J↑n↓ Marie
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 12], [12, 18]]
# 429
# Charton antoine à vinc
# ['I-name', 'I-firstnames', 'I-address'] [[0, 7], [8, 15], [18, 22]]
# 430
# Caudy mathias
# ['I-name', 'I-firstnames'] [[0, 5], [6, 13]]
# 431
# Jolly
# ['I-name'] [[0, 5]]
# 432
# Vecollant Claude→a Villeneuve
# ['I-name', 'I-firstnames', 'I-address'] [[0, 9], [10, 16], [19, 29]]
# 433
# Galland Julien
# ['I-name', 'I-firstnames'] [[0, 7], [8, 14]]
# 434
# Cassen de Ciablice augustin marie sylvain→Paris
# ['I-name', 'I-name', 'I-firstnames', 'I-firstnames', 'I-address'] [[0, 6], [6, 18], [19, 27], [27, 41], [42, 47]]
# 435
# Pierre loth
# ['I-name', 'I-firstnames'] [[0, 6], [7, 11]]
# 436
# Ancelet louis auguste
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 13], [13, 21]]
# 437
# Dyé Edme à Paris rue Royer Collard
# ['I-name', 'I-firstnames', 'I-address', 'I-address'] [[0, 3], [4, 8], [11, 16], [16, 34]]
# 438
# David philippe Vig↑ron↓→à Sucy
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-address'] [[0, 5], [6, 14], [14, 23], [26, 30]]
# 439
# Guerin Joseph→pere
# ['I-name', 'I-firstnames', 'I-familystatus'] [[0, 6], [7, 13], [14, 18]]
# 440
# Galland ↑françois↓ ×auguste±→vig↑on↓ à id
# ['I-name', 'I-firstnames', 'I-activity', 'I-address', 'I-name', 'I-firstnames'] [[0, 7], [8, 18], [29, 36], [39, 41], [0, 7], [20, 27]]
# 441
# Desilles pierre V↑e↓ léonard
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 15], [15, 28]]
# 442
# Misgault Jean Louis
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 13], [13, 19]]
# 443
# Marmontel Veuve
# ['I-name', 'I-familystatus'] [[0, 9], [10, 15]]
# 444
# Charpentier Louis
# ['I-name', 'I-firstnames'] [[0, 11], [12, 17]]
# 445
# Grangé
# ['I-name'] [[0, 6]]
# 446
# Mortier Vincent noël
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 15], [15, 20]]
# 447
# Gobert Marc Désiré
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 11], [11, 18]]
# 448
# Bedeau pierre→à Villecresne
# ['I-name', 'I-firstnames', 'I-address'] [[0, 6], [7, 13], [16, 27]]
# 449
# andré louis→Rivière→×pierre±→et Emile victor
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-name', 'I-firstnames'] [[12, 19], [0, 5], [5, 11], [32, 37], [38, 44]]
# 450
# Perrier Pierre
# ['I-name', 'I-firstnames'] [[0, 7], [8, 14]]
# 451
# Leprâse  J↑n↓ Sebastien→Vig↑on↓ à Sucy
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-activity', 'I-address'] [[0, 7], [9, 13], [13, 23], [24, 31], [34, 38]]
# 452
# Esterbes G↑n↓ f↑on↓→fontenay
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-address'] [[0, 8], [9, 13], [13, 19], [20, 28]]
# 453
# Fleury J. B↑te↓→m↑d↓ de mouton à id
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-activity', 'I-activity', 'I-address'] [[0, 6], [7, 9], [9, 15], [16, 20], [20, 30], [33, 35]]
# 454
# Jarielle Jacques aîné à id
# ['I-name', 'I-firstnames', 'I-address', 'I-familystatus'] [[0, 8], [9, 16], [24, 26], [17, 21]]
# 455
# feuillet nicolas Thomas V↑e↓
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-familystatus'] [[0, 8], [9, 16], [16, 23], [24, 28]]
# 456
# Bourdillat, J↑n↓ F↑ois↓
# ['I-name', 'I-name', 'I-firstnames', 'I-firstnames'] [[0, 10], [10, 11], [12, 16], [16, 23]]
# 457
# Mayeux p↑re↓ f↑ois↓
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 12], [12, 19]]
# 458
# Marcellis pierre→ursin
# ['I-name', 'I-firstnames'] [[0, 9], [10, 22]]
# 459
# Dodun de Kéoman agathe veuve→Moussac
# ['I-name', 'I-name', 'I-firstnames', 'I-familystatus', 'I-name'] [[0, 5], [5, 15], [16, 22], [23, 28], [29, 36]]
# 460
# Degarne jean
# ['I-name', 'I-firstnames'] [[0, 7], [8, 12]]
# 461
# Coudrot
# ['I-name'] [[0, 7]]
# 462
# Baloche p↑re↓ Ruffin
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 13], [13, 20]]
# 463
# Jarrier Joseph ­V↑on↓ ×fermier±→à Oravel
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-activity', 'I-activity', 'I-address'] [[0, 7], [8, 14], [14, 15], [23, 30], [16, 21], [34, 40]]
# 464
# Conard V↑ve↓
# ['I-name', 'I-familystatus'] [[0, 6], [7, 12]]
# 465
# Cousin dem ricourt V↑e↓
# ['I-name', 'I-name', 'I-familystatus'] [[0, 6], [6, 18], [19, 23]]
# 466
# Moncouteau jean maris
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 10], [11, 15], [15, 21]]
# 467
# Lucot maçon
# ['I-name', 'I-activity'] [[0, 5], [6, 11]]
# 468
# Clavier françois
# ['I-name', 'I-firstnames'] [[0, 7], [8, 16]]
# 469
# Béraut pierre
# ['I-name', 'I-firstnames'] [[0, 6], [7, 13]]
# 470
# Rousseau antoine françois
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 16], [16, 25]]
# 471
# Lamy Jean Louis denis Félix
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 4], [5, 9], [9, 27]]
# 472
# Chazeaud françois
# ['I-name', 'I-firstnames'] [[0, 8], [9, 17]]
# 473
# Sevin jean achille
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 5], [6, 10], [10, 18]]
# 474
# Bourgoin inspecteur
# ['I-name', 'I-firstnames'] [[0, 8], [9, 19]]
# 475
# Mazarot Pierre
# ['I-name', 'I-firstnames'] [[0, 7], [8, 14]]
# 476
# Mérillon
# ['I-name'] [[0, 8]]
# 477
# Dameville Mathieu
# ['I-name', 'I-firstnames'] [[0, 9], [10, 17]]
# 478
# Javon J.B↑te↓ homme de loi à Paris
# ['I-name', 'I-firstnames', 'I-activity', 'I-activity', 'I-address'] [[0, 5], [6, 12], [14, 19], [19, 26], [29, 34]]
# 479
# Leroy denis ant↑ne↓ m↑tre↓ maçon
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-activity', 'I-activity'] [[0, 5], [6, 11], [11, 19], [20, 26], [26, 32]]
# 480
# Meneux ch↑es↓ nicolas
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 13], [13, 21]]
# 481
# Pillet
# ['I-name'] [[0, 6]]
# 482
# Touzin pierre fils
# ['I-name', 'I-firstnames', 'I-familystatus'] [[0, 6], [7, 13], [14, 18]]
# 483
# Petit N↑as↓
# ['I-name', 'I-firstnames'] [[0, 5], [6, 11]]
# 484
# Lefevre jacques
# ['I-name', 'I-firstnames'] [[0, 7], [8, 15]]
# 485
# Boisseau p↑re↓ Etienne
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 14], [14, 22]]
# 486
# Petit Ch↑es↓
# ['I-name', 'I-name', 'I-firstnames'] [[0, 5], [5, 6], [6, 12]]
# 487
# Serize id
# ['I-name', 'I-address'] [[0, 6], [7, 9]]
# 488
# Galle Jules boulanger à id
# ['I-name', 'I-firstnames', 'I-activity', 'I-address'] [[0, 5], [6, 11], [12, 21], [24, 26]]
# 489
# Piquet François→militaire
# ['I-name', 'I-firstnames', 'I-activity'] [[0, 6], [7, 15], [16, 25]]
# 490
# Rameau auguste eugène
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 14], [14, 21]]
# 491
# Perrin, Constant
# ['I-name', 'I-name', 'I-firstnames'] [[0, 6], [6, 7], [8, 16]]
# 492
# Chanevas à arcueil
# ['I-name', 'I-address'] [[0, 8], [11, 18]]
# 493
# id id
# ['I-name', 'I-firstnames'] [[0, 2], [0, 2]]
# 494
# Plaisant félix
# ['I-name', 'I-firstnames'] [[0, 8], [9, 14]]
# 495
# Persicot adrien
# ['I-name', 'I-firstnames'] [[0, 8], [9, 15]]
# 496
# Silvestre ×idem± marie anne
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 9], [17, 22], [22, 27]]
# 497
# Contour Gabriel le jeune, à→francvilliers
# ['I-name', 'I-firstnames', 'I-address', 'I-familystatus', 'I-familystatus'] [[0, 7], [8, 15], [28, 41], [16, 18], [18, 24]]
# 498
# Blanzac françois félix
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 16], [16, 22]]
# 499
# geaudoil
# ['I-name'] [[0, 8]]
# 500
# Mozeau ant↑ne↓ Louis
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 14], [14, 20]]
# ...
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 14], [14, 24]]
# 270
# Vigoureux Jean
# ['I-name', 'I-firstnames'] [[0, 9], [10, 14]]
# 271
# Buré J-B↑te↓ Thibaut culti périgny
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-activity', 'I-address'] [[0, 4], [5, 6], [6, 20], [21, 26], [27, 34]]
# 272
# Quéru Pierre françois
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 5], [6, 12], [12, 21]]
# 273
# Boulenois
# ['I-name'] [[0, 9]]
# 274
# Soudieux Ch↑es↓ Louis
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 15], [15, 21]]
# 275
# Mazarot Pierre→Cabaretier à id
# ['I-name', 'I-firstnames', 'I-activity', 'I-address'] [[0, 7], [8, 14], [15, 25], [28, 30]]
# 276
# Salvet louis
# ['I-name', 'I-firstnames'] [[0, 6], [7, 12]]
# 277
# Soulier V↑e↓ Georges→à marolles
# ['I-name', 'I-firstnames', 'I-address', 'I-familystatus'] [[0, 7], [13, 20], [23, 31], [8, 12]]
# 278
# Mackels henri
# ['I-name', 'I-firstnames'] [[0, 7], [8, 13]]
# 279
# Coignet f↑ois↓
# ['I-name', 'I-firstnames'] [[0, 7], [8, 14]]
# 280
# Barillet louis jules
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 14], [14, 20]]
# 281
# Picard Ernest
# ['I-name', 'I-firstnames'] [[0, 6], [7, 13]]
# 282
# Jolivet J↑n↓ B↑te↓
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 12], [12, 18]]
# 283
# Héricourt Grégoire à→Fontenay
# ['I-name', 'I-firstnames', 'I-address'] [[0, 9], [10, 18], [21, 29]]
# 284
# Costy Jean Bapt↑e↓→tailleur de pierre Vil le Roy
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-activity', 'I-activity', 'I-familystatus', 'I-familystatus'] [[0, 5], [6, 10], [10, 17], [19, 27], [27, 37], [38, 41], [41, 48]]
# 285
# Pitou Pierre fils à fontenay
# ['I-name', 'I-firstnames', 'I-address', 'I-familystatus'] [[0, 5], [6, 12], [20, 28], [13, 17]]
# 286
# houzeau louis constant
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 13], [13, 22]]
# 287
# Gachet J↑n↓ Ch↑les↓→Gendre le maire
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-familystatus', 'I-familystatus'] [[0, 6], [7, 11], [11, 19], [20, 26], [26, 35]]
# 288
# Cambray
# ['I-name'] [[0, 7]]
# 289
# Minier Toussaint
# ['I-name', 'I-firstnames'] [[0, 6], [7, 16]]
# 290
# Detinte JUlien v↑e↓→Cousin
# ['I-name', 'I-firstnames', 'I-familystatus', 'I-name'] [[0, 7], [8, 14], [15, 19], [20, 26]]
# 291
# Crette Eugène
# ['I-name', 'I-firstnames'] [[0, 6], [7, 13]]
# 292
# Luisette henry V↑e↓→amiot louis alexandre
# ['I-name', 'I-firstnames', 'I-familystatus', 'I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 14], [15, 20], [20, 25], [26, 31], [31, 41]]
# 293
# Leroy Clément
# ['I-name', 'I-firstnames'] [[0, 5], [6, 13]]
# 294
# Loripherne→×Loriferne Michel± Louis Auguste→id et Michel
# ['I-name', 'I-firstnames', 'I-name', 'I-firstnames', 'I-firstnames'] [[0, 10], [22, 28], [0, 10], [30, 35], [35, 43]]
# 295
# Huard J↑n↓
# ['I-name', 'I-firstnames'] [[0, 5], [6, 10]]
# 296
# Delaporte félix aug↑te↓
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 9], [10, 15], [15, 23]]
# 297
# Sellier J↑ques↓ Georges
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 15], [15, 23]]
# 298
# Bourdillat id
# ['I-name', 'I-firstnames'] [[0, 10], [11, 13]]
# 299
# Delor, V↑e↓ claude
# ['I-name', 'I-name', 'I-firstnames', 'I-familystatus'] [[0, 5], [5, 6], [12, 18], [7, 11]]
# 300
# Razurel auguste édouard
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 15], [15, 23]]
# 301
# Berault pieric n↑as↓
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 14], [14, 20]]
# 302
# Barrey pierre→garde champêtre
# ['I-name', 'I-firstnames', 'I-activity', 'I-activity'] [[0, 6], [7, 13], [14, 19], [19, 29]]
# 303
# Carré marcel
# ['I-name', 'I-firstnames'] [[0, 5], [6, 12]]
# 304
# Mentienne Louis Alexandre→fils, dit Beaulaid
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-familystatus'] [[0, 9], [10, 15], [15, 25], [26, 30]]
# 305
# Therese Louis
# ['I-name', 'I-firstnames'] [[0, 7], [8, 13]]
# 306
# Pigeron, Paris
# ['I-name', 'I-address'] [[0, 7], [9, 14]]
# 307
# Hureau alfred anatole tranquille
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 13], [13, 32]]
# 308
# Marbot (le Baron)
# ['I-name', 'I-familystatus', 'I-familystatus'] [[0, 6], [8, 10], [10, 16]]
# 309
# Ally Joseph Marie
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 4], [5, 11], [11, 17]]
# 310
# Leroy Antoine
# ['I-name', 'I-firstnames'] [[0, 5], [6, 13]]
# 311
# Les hospices dans Paris
# ['I-name', 'I-name', 'I-address'] [[0, 3], [3, 12], [18, 23]]
# 312
# Brumeau Etienne
# ['I-name', 'I-firstnames'] [[0, 7], [8, 15]]
# 313
# godefroy
# ['I-name'] [[0, 8]]
# 314
# Carré
# ['I-name'] [[0, 5]]
# 315
# Marc Erasme Louis veuve né→Mouillard anne à ablon
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-address', 'I-title', 'I-birthname'] [[0, 4], [5, 11], [11, 17], [44, 49], [18, 23], [27, 36]]
# 316
# Combe Jean Louis
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 5], [6, 10], [10, 16]]
# 317
# Amiot J↑n↓ florentin
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 5], [6, 10], [10, 20]]
# 318
# Darblay à Villejuif
# ['I-name', 'I-address'] [[0, 7], [10, 19]]
# 319
# Rameau P↑re↓ Edme
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 12], [12, 17]]
# 320
# Benoit françois benoit→×actar nicolas louis, Vanve±
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-name', 'I-firstnames', 'I-firstnames', 'I-address'] [[0, 6], [7, 15], [15, 22], [24, 29], [30, 37], [37, 43], [45, 50]]
# 321
# Arpentinier f↑ois↓
# ['I-name', 'I-firstnames'] [[0, 11], [12, 18]]
# 322
# Bérault Eugène
# ['I-name', 'I-firstnames'] [[0, 7], [8, 14]]
# 323
# Gallet, Jean F↑ois↓
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [8, 12], [12, 19]]
# 324
# Guillot Pierre→Cultiv à id
# ['I-name', 'I-firstnames', 'I-activity', 'I-address'] [[0, 7], [8, 14], [15, 21], [24, 26]]
# 325
# Guerin Louis antoine
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 12], [12, 20]]
# 326
# Breton Jean P↑re↓ vitrier
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-activity'] [[0, 6], [7, 11], [11, 16], [18, 25]]
# 327
# Blost
# ['I-name'] [[0, 5]]
# 328
# Delair alphonse augustin
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 15], [15, 24]]
# 329
# Pepin jacques claude
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 5], [6, 13], [13, 20]]
# 330
# V↑e↓ Blin
# ['I-name', 'I-familystatus'] [[5, 9], [0, 4]]
# 331
# Guillot, Pierre→Cultiv à marolles
# ['I-name', 'I-name', 'I-firstnames', 'I-activity', 'I-address'] [[0, 7], [7, 8], [9, 15], [16, 22], [25, 33]]
# 332
# Spire Nolos
# ['I-name', 'I-firstnames'] [[0, 5], [6, 11]]
# 333
# Ancelet Charles dominique
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 15], [15, 25]]
# 334
# David J↑n↓ M↑ar↓-Les enfants
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-familystatus', 'I-familystatus'] [[0, 5], [6, 10], [10, 16], [17, 20], [20, 28]]
# 335
# Leroy sauveure gabriel
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 5], [6, 14], [14, 22]]
# 336
# Metivier Louis P↑re↓
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 14], [14, 20]]
# 337
# Desterne V↑e↓ Et↑ne↓
# ['I-name', 'I-firstnames', 'I-familystatus'] [[0, 8], [14, 20], [9, 13]]
# 338
# Billot Michel
# ['I-name', 'I-firstnames'] [[0, 6], [7, 13]]
# 339
# Brigault louis
# ['I-name', 'I-firstnames'] [[0, 8], [9, 14]]
# 340
# Le Prince de Neuchâtel→×Vauguyon→Bourgeois, maire±
# ['I-name', 'I-name', 'I-name', 'I-activity', 'I-activity'] [[0, 2], [2, 22], [24, 32], [33, 42], [42, 49]]
# 341
# Fontaine henry Vig↑on↓ VN
# ['I-name', 'I-firstnames', 'I-activity', 'I-address'] [[0, 8], [9, 14], [15, 22], [23, 25]]
# 342
# Moret Jacques nicolas
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 5], [6, 13], [13, 21]]
# 343
# Rameau louis honoré
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 12], [12, 19]]
# 344
# Cretté J↑n↓ Touss↑t↓
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 11], [11, 20]]
# 345
# Beriault J↑n↓ L↑is↓
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 13], [13, 19]]
# 346
# Desnyau Et↑e↓ f↑ois↓
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 13], [13, 20]]
# 347
# Pequesne Pierre Louis
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 15], [15, 21]]
# 348
# Vitry J↑e↓ f↑ois↓
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 5], [6, 10], [10, 17]]
# 349
# Thièry V↑e↓ Jean→antoine
# ['I-name', 'I-firstnames', 'I-familystatus'] [[0, 6], [12, 24], [7, 11]]
# 350
# Leroy louis nicolas→×Leroy jean nicolas fils±
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-name', 'I-firstnames', 'I-firstnames', 'I-familystatus'] [[0, 5], [6, 11], [11, 19], [0, 5], [27, 31], [31, 39], [40, 44]]
# 351
# Biard raphaël julien
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 5], [6, 13], [13, 20]]
# 352
# dame De Chavagnac
# ['I-name', 'I-name'] [[0, 4], [4, 17]]
# 353
# Martin D↑e↓
# ['I-name', 'I-firstnames'] [[0, 6], [7, 11]]
# 354
# Delanoue les→heritiers à Versailles
# ['I-name', 'I-address', 'I-familystatus'] [[0, 8], [25, 35], [9, 22]]
# 355
# Guérin Joseph pere→vig à id
# ['I-name', 'I-firstnames', 'I-activity', 'I-address', 'I-familystatus'] [[0, 6], [7, 13], [19, 22], [25, 27], [14, 18]]
# 356
# Soudieux Saturnin di❌→mandre
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 17], [17, 28]]
# 357
# Wilcke Louis Chrétien→à Belleville
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-address'] [[0, 6], [7, 12], [12, 21], [24, 34]]
# 358
# de Nicolaï id
# ['I-name', 'I-name', 'I-title'] [[0, 2], [2, 10], [11, 13]]
# 359
# Mezard sat↑in↓
# ['I-name', 'I-firstnames'] [[0, 6], [7, 14]]
# 360
# Martin
# ['I-name'] [[0, 6]]
# 361
# Moulin nicolas
# ['I-name', 'I-firstnames'] [[0, 6], [7, 14]]
# 362
# Lameau Pierre Joseph
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 13], [13, 20]]
# 363
# Milcent Jean Pierre
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 12], [12, 19]]
# 364
# Bouton, Charles Louis→fab, m↑d↓ à Paris
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-activity', 'I-activity', 'I-address'] [[0, 6], [8, 15], [15, 21], [22, 25], [25, 31], [34, 39]]
# 365
# Cochet
# ['I-name'] [[0, 6]]
# 366
# Roussel ambroise françois à ablon
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-address'] [[0, 7], [8, 16], [16, 25], [28, 33]]
# 367
# Vigoureux Gabriel→×Guérin Joseph fils±
# ['I-name', 'I-firstnames', 'I-name', 'I-firstnames', 'I-familystatus'] [[0, 9], [10, 17], [19, 25], [26, 32], [33, 37]]
# 368
# Boulot isidore
# ['I-name', 'I-firstnames'] [[0, 6], [7, 14]]
# 369
# Lameau Sat↑nin↓ veuve
# ['I-name', 'I-firstnames', 'I-familystatus'] [[0, 6], [7, 15], [16, 21]]
# 370
# Hatrel ernest
# ['I-name', 'I-firstnames'] [[0, 6], [7, 13]]
# 371
# Nouvial jean joseph
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 12], [12, 19]]
# 372
# Gillet Due Claude
# ['I-name', 'I-name', 'I-firstnames'] [[0, 6], [6, 10], [11, 17]]
# 373
# Motteau F↑ois↓ a perigny
# ['I-name', 'I-firstnames', 'I-address'] [[0, 7], [8, 14], [17, 24]]
# 374
# Gabillot louis lambert
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 14], [14, 22]]
# 375
# Baron p↑re↓ denis
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 5], [6, 11], [11, 17]]
# 376
# Delkayré jean
# ['I-name', 'I-firstnames'] [[0, 8], [9, 13]]
# 377
# Sellier F↑s↓ marie
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 12], [12, 18]]
# 378
# Ancelet charles dominique
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 15], [15, 25]]
# 379
# L'Etat
# ['I-name'] [[0, 6]]
# 380
# Malvaux pierre
# ['I-name', 'I-firstnames'] [[0, 7], [8, 14]]
# 381
# Degrain J↑n↓ Louis
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 12], [12, 18]]
# 382
# Lameau Passie J↑h↓ achille
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 13], [13, 26]]
# 383
# Gabillot claude lambert
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 15], [15, 23]]
# 384
# Foulon Veuve
# ['I-name', 'I-familystatus'] [[0, 6], [7, 12]]
# 385
# Besval Jean françois antoine
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 11], [11, 28]]
# 386
# Lameau Jean Saturnin
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 11], [11, 20]]
# 387
# Romanes fréderic V↑e↓
# ['I-name', 'I-firstnames', 'I-familystatus'] [[0, 7], [8, 16], [17, 21]]
# 388
# Guérin Louis ant↑e↓→vigneron à id
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-activity', 'I-address'] [[0, 6], [7, 12], [12, 19], [20, 28], [31, 33]]
# 389
# Collignon Eugène
# ['I-name', 'I-firstnames'] [[0, 9], [10, 16]]
# 390
# Ancelet ×f↑ois↓ V↑e↓± nicolas
# ['I-name', 'I-firstnames', 'I-familystatus', 'I-name'] [[0, 7], [9, 15], [16, 20], [22, 29]]
# 391
# Delanoue J↑n↓ B↑te↓ toussaint
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 13], [13, 29]]
# 392
# Godefroy J F denis→×Masson n↑as↓ J↑n↓±
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 10], [10, 18], [20, 26], [27, 32], [32, 37]]
# 393
# Mercier Denis
# ['I-name', 'I-firstnames'] [[0, 7], [8, 13]]
# 394
# Fournier athanase à Prescy
# ['I-name', 'I-firstnames', 'I-address'] [[0, 8], [9, 17], [20, 26]]
# 395
# Vigoureux Jean→ant↑e↓ militaire
# ['I-name', 'I-firstnames', 'I-activity'] [[0, 9], [10, 21], [22, 31]]
# 396
# Morizot louis antoine
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 13], [13, 21]]
# 397
# Grangé antoine→aubergiste à ablon
# ['I-name', 'I-firstnames', 'I-activity', 'I-address'] [[0, 6], [7, 14], [15, 25], [28, 33]]
# 398
# Mentienne Louis gervais
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 9], [10, 15], [15, 23]]
# 399
# Jolly Jean Louis
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 5], [6, 10], [10, 16]]
# 400
# Labouraux martin
# ['I-name', 'I-firstnames'] [[0, 9], [10, 16]]
# 401
# Brunat marie madeleine
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 12], [12, 22]]
# 402
# Prunios Jean, gendre moreau→id
# ['I-name', 'I-firstnames', 'I-address', 'I-familystatus', 'I-familystatus'] [[0, 7], [8, 12], [28, 30], [14, 20], [20, 27]]
# 403
# Auboin
# ['I-name'] [[0, 6]]
# 404
# Mérillon félix
# ['I-name', 'I-firstnames'] [[0, 8], [9, 14]]
# 405
# Berthier alexandre
# ['I-name', 'I-firstnames'] [[0, 8], [9, 18]]
# 406
# Berger Ambroise magloire
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 15], [15, 24]]
# 407
# Pélissier pierre Louis à id
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-address'] [[0, 9], [10, 16], [16, 22], [25, 27]]
# 408
# David françois bernard
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 5], [6, 14], [14, 22]]
# 409
# Massuet louis michel
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 13], [13, 20]]
# 410
# Philippe charles alexandre
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 16], [16, 26]]
# 411
# Guérin J↑es↓ henry→maçon
# ['I-name', 'I-firstnames', 'I-firstnames', 'I-activity'] [[0, 6], [7, 12], [12, 18], [19, 24]]
# 412
# Motheau h↑ers↓ Germain→et Consors à marolles
# ['I-name', 'I-familystatus', 'I-familystatus', 'I-name', 'I-name', 'I-address'] [[0, 7], [8, 14], [14, 22], [23, 25], [25, 33], [36, 44]]
# 413
# Larmée J↑n↓ B↑te↓
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 6], [7, 11], [11, 17]]
# 414
# idem→×Vauguyon, maire→de marolles±
# ['I-name', 'I-name', 'I-firstnames', 'I-firstnames'] [[0, 4], [6, 14], [16, 24], [24, 33]]
# 415
# Lagoutte nég
# ['I-name', 'I-firstnames'] [[0, 8], [9, 12]]
# 416
# Delaville Leroux
# ['I-name', 'I-firstnames'] [[0, 9], [10, 16]]
# 417
# Franckairt
# ['I-name'] [[0, 10]]
# 418
# Petit pierre F↑ois↓
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 5], [6, 12], [12, 19]]
# 419
# sergent louis marie victor
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 7], [8, 13], [13, 26]]
# 420
# Huignard mélanie félicité
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 16], [16, 25]]
# 421
# ×huten±
# ['I-name'] [[1, 6]]
# 422
# Silan
# ['I-name'] [[0, 5]]
# 423
# Laboreau, martin→veuve
# ['I-name', 'I-name', 'I-firstnames', 'I-familystatus'] [[0, 8], [8, 9], [10, 16], [17, 22]]
# 424
# Piedquin f↑ois↓ marie
# ['I-name', 'I-firstnames', 'I-firstnames'] [[0, 8], [9, 15], [15, 21]]
# 425
# Lefevre
# ['I-name'] [[0, 7]]
# 426
# Tourneur Barthélémy→V↑on↓
# ['I-name', 'I-firstnames', 'I-activity'] [[0, 8], [9, 19], [20, 25]]
# Map: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 427/427 [00:00<00:00, 20778.82 examples/s]
# Saving the dataset (1/1 shards): 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████| 1534/1534 [00:00<00:00, 338367.73 examples/s]
# Saving the dataset (1/1 shards): 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████| 171/171 [00:00<00:00, 46746.14 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████| 427/427 [00:00<00:00, 119024.91 examples/s]

# %% [markdown]
# ## 2. Dataset description

# %%
from collections import Counter

def entities_per_entries(df):
    entities = []
    for ix, row in df.iterrows():
        txt = row[0][0]
        ann = row[0][1:]
        ents = []
        for elem in ann:
            ents.append(elem[1])
        entities.append(ents)
    return entities

# %%
all_entities = entities_per_entries(gold_reference_valid)
train_entities = entities_per_entries(train_df)
val_entities = entities_per_entries(val_df)
test_entities = entities_per_entries(test_df)
# Out:
# /tmp/ipykernel_330680/3498329068.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   txt = row[0][0]
# /tmp/ipykernel_330680/3498329068.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ann = row[0][1:]

# %% [markdown]
# ### 2.1 Patterns

# %%
def get_patterns_count(entities):
    # Convert each list to a tuple for counting
    list_as_tuples = [tuple(sublist) for sublist in entities]
    
    # Count occurrences of each tuple
    counts = Counter(list_as_tuples)
    
    # Sort by count in descending order
    sorted_counts = sorted(counts.items(), key=lambda x: x[1], reverse=True)
    
    # Print the results
    for unique_list, count in sorted_counts:
        print(f"{list(unique_list)}: {count}")

# %%
all_entities_pat = get_patterns_count(all_entities)
# Out:
# ['name', 'firstnames']: 1057
# ['name']: 217
# ['name', 'firstnames', 'activity', 'address']: 134
# ['name', 'firstnames', 'address']: 128
# ['name', 'firstnames', 'familystatus']: 126
# ['name', 'familystatus']: 73
# ['name', 'firstnames', 'activity']: 46
# ['name', 'address']: 32
# ['name', 'firstnames', 'name', 'firstnames']: 31
# ['name', 'firstnames', 'address', 'familystatus']: 30
# ['name', 'activity']: 19
# ['name', 'firstnames', 'activity', 'address', 'familystatus']: 18
# ['name', 'firstnames', 'title']: 17
# ['name', 'name']: 16
# ['name', 'name', 'activity']: 13
# ['name', 'title']: 11
# ['name', 'firstnames', 'name']: 10
# ['name', 'firstnames', 'familystatus', 'name']: 10
# ['name', 'name', 'firstnames']: 9
# ['name', 'address', 'familystatus']: 9
# ['name', 'firstnames', 'familystatus', 'name', 'firstnames']: 7
# ['name', 'activity', 'address']: 6
# ['name', 'activity', 'name']: 6
# ['name', 'firstnames', 'familystatus', 'birthname']: 5
# ['name', 'firstnames', 'name', 'firstnames', 'familystatus']: 4
# ['name', 'familystatus', 'birthname']: 4
# ['name', 'firstnames', 'familystatus', 'familystatus']: 4
# ['name', 'firstnames', 'address', 'name', 'firstnames']: 4
# ['name', 'firstnames', 'name', 'firstnames', 'activity', 'address']: 3
# ['name', 'activity', 'address', 'familystatus']: 3
# ['name', 'firstnames', 'activity', 'familystatus']: 3
# ['name', 'firstnames', 'name', 'address']: 3
# ['name', 'address', 'name', 'firstnames']: 2
# ['name', 'firstnames', 'activity', 'address', 'name', 'firstnames']: 2
# ['name', 'firstnames', 'name', 'title']: 2
# ['name', 'name', 'activity', 'address']: 2
# ['name', 'address', 'name', 'address']: 2
# ['name', 'firstnames', 'name', 'firstnames', 'activity']: 2
# ['name', 'familystatus', 'name', 'firstnames']: 2
# ['name', 'address', 'title']: 2
# ['name', 'firstnames', 'familystatus', 'name', 'firstnames', 'familystatus']: 2
# ['name', 'title', 'familystatus']: 2
# ['name', 'firstnames', 'activity', 'activity', 'address']: 2
# ['name', 'firstnames', 'name', 'firstnames', 'title']: 1
# ['name', 'firstnames', 'name', 'name']: 1
# ['name', 'name', 'firstnames', 'address', 'familystatus']: 1
# ['name', 'name', 'address']: 1
# ['name', 'name', 'name', 'firstnames']: 1
# ['name', 'familystatus', 'name', 'familystatus']: 1
# ['name', 'address', 'title', 'familystatus', 'birthname']: 1
# ['name', 'firstnames', 'name', 'familystatus']: 1
# ['name', 'address', 'familystatus', 'name', 'firstnames']: 1
# ['name', 'firstnames', 'address', 'name', 'firstnames', 'address']: 1
# ['name', 'firstnames', 'address', 'familystatus', 'familystatus']: 1
# ['name', 'firstnames', 'address', 'title']: 1
# ['name', 'activity', 'title']: 1
# ['name', 'title', 'name']: 1
# ['name', 'firstnames', 'birthname']: 1
# ['name', 'firstnames', 'name', 'firstnames', 'name', 'firstnames']: 1
# ['name', 'address', 'name', 'activity']: 1
# ['name', 'title', 'title']: 1
# ['name', 'firstnames', 'activity', 'address', 'familystatus', 'name']: 1
# ['name', 'address', 'familystatus', 'name']: 1
# ['name', 'firstnames', 'name', 'firstnames', 'activity', 'activity', 'activity', 'address']: 1
# ['name', 'firstnames', 'activity', 'activity']: 1
# ['name', 'firstnames', 'address', 'familystatus', 'name', 'address']: 1
# ['name', 'familystatus', 'name', 'title']: 1
# ['name', 'address', 'familystatus', 'name', 'firstnames', 'address']: 1
# ['name', 'firstnames', 'firstnames', 'familystatus']: 1
# ['name', 'address', 'name', 'familystatus']: 1
# ['name', 'firstnames', 'name', 'firstnames', 'name']: 1
# ['name', 'name', 'name']: 1
# ['name', 'name', 'activity', 'activity']: 1
# ['name', 'firstnames', 'name', 'firstnames', 'activity', 'address', 'address', 'familystatus']: 1
# ['name', 'firstnames', 'familystatus', 'name', 'familystatus']: 1
# ['name', 'title', 'birthname']: 1
# ['name', 'firstnames', 'name', 'firstnames', 'address']: 1
# ['name', 'firstnames', 'activity', 'name', 'firstnames', 'address']: 1
# ['name', 'firstnames', 'familystatus', 'name', 'title']: 1
# ['name', 'familystatus', 'name', 'address']: 1
# ['name', 'familystatus', 'familystatus']: 1
# ['name', 'name', 'firstnames', 'activity', 'address']: 1
# ['name', 'firstnames', 'title', 'title']: 1
# ['name', 'familystatus', 'name']: 1
# ['name', 'familystatus', 'name', 'activity', 'address']: 1
# ['name', 'familystatus', 'name', 'address', 'familystatus']: 1
# ['name', 'address', 'address', 'name']: 1
# ['name', 'firstnames', 'activity', 'address', 'address', 'familystatus']: 1
# ['name', 'firstnames', 'address', 'title', 'birthname']: 1
# ['name', 'name', 'firstnames', 'name', 'firstnames', 'familystatus']: 1
# ['name', 'activity', 'familystatus']: 1
# ['name', 'firstnames', 'name', 'address', 'name', 'firstnames', 'name']: 1
# ['name', 'firstnames', 'activity', 'address', 'name', 'firstnames', 'name', 'firstnames']: 1
# ['name', 'firstnames', 'title', 'familystatus']: 1
# ['name', 'familystatus', 'name', 'activity']: 1

# %%
all_entities_pat = get_patterns_count(train_entities)
# Out:
# ['name', 'firstnames']: 745
# ['name']: 168
# ['name', 'firstnames', 'address']: 101
# ['name', 'firstnames', 'activity', 'address']: 95
# ['name', 'firstnames', 'familystatus']: 94
# ['name', 'familystatus']: 54
# ['name', 'firstnames', 'activity']: 31
# ['name', 'firstnames', 'name', 'firstnames']: 23
# ['name', 'firstnames', 'address', 'familystatus']: 21
# ['name', 'address']: 21
# ['name', 'activity']: 16
# ['name', 'firstnames', 'activity', 'address', 'familystatus']: 12
# ['name', 'firstnames', 'title']: 11
# ['name', 'name']: 10
# ['name', 'title']: 9
# ['name', 'name', 'activity']: 9
# ['name', 'firstnames', 'name']: 9
# ['name', 'name', 'firstnames']: 7
# ['name', 'firstnames', 'familystatus', 'name']: 7
# ['name', 'firstnames', 'familystatus', 'name', 'firstnames']: 6
# ['name', 'address', 'familystatus']: 5
# ['name', 'activity', 'address']: 5
# ['name', 'activity', 'name']: 5
# ['name', 'firstnames', 'familystatus', 'familystatus']: 4
# ['name', 'firstnames', 'familystatus', 'birthname']: 4
# ['name', 'activity', 'address', 'familystatus']: 3
# ['name', 'firstnames', 'address', 'name', 'firstnames']: 3
# ['name', 'familystatus', 'birthname']: 3
# ['name', 'firstnames', 'name', 'firstnames', 'activity']: 2
# ['name', 'address', 'name', 'address']: 2
# ['name', 'firstnames', 'activity', 'address', 'name', 'firstnames']: 2
# ['name', 'name', 'activity', 'address']: 2
# ['name', 'firstnames', 'activity', 'activity', 'address']: 2
# ['name', 'address', 'title']: 2
# ['name', 'firstnames', 'familystatus', 'name', 'firstnames', 'familystatus']: 2
# ['name', 'familystatus', 'name', 'firstnames']: 2
# ['name', 'firstnames', 'name', 'name']: 1
# ['name', 'address', 'familystatus', 'name', 'firstnames', 'address']: 1
# ['name', 'activity', 'title']: 1
# ['name', 'name', 'name', 'firstnames']: 1
# ['name', 'familystatus', 'name', 'activity']: 1
# ['name', 'firstnames', 'familystatus', 'name', 'familystatus']: 1
# ['name', 'firstnames', 'name', 'firstnames', 'familystatus']: 1
# ['name', 'firstnames', 'firstnames', 'familystatus']: 1
# ['name', 'firstnames', 'name', 'address']: 1
# ['name', 'address', 'name', 'familystatus']: 1
# ['name', 'firstnames', 'address', 'familystatus', 'familystatus']: 1
# ['name', 'activity', 'familystatus']: 1
# ['name', 'firstnames', 'name', 'firstnames', 'activity', 'address']: 1
# ['name', 'firstnames', 'activity', 'address', 'familystatus', 'name']: 1
# ['name', 'address', 'title', 'familystatus', 'birthname']: 1
# ['name', 'firstnames', 'name', 'firstnames', 'title']: 1
# ['name', 'firstnames', 'title', 'familystatus']: 1
# ['name', 'name', 'firstnames', 'name', 'firstnames', 'familystatus']: 1
# ['name', 'firstnames', 'name', 'firstnames', 'name', 'firstnames']: 1
# ['name', 'firstnames', 'familystatus', 'name', 'title']: 1
# ['name', 'address', 'familystatus', 'name', 'firstnames']: 1
# ['name', 'firstnames', 'name', 'familystatus']: 1
# ['name', 'firstnames', 'activity', 'activity']: 1
# ['name', 'firstnames', 'name', 'address', 'name', 'firstnames', 'name']: 1
# ['name', 'firstnames', 'name', 'firstnames', 'name']: 1
# ['name', 'firstnames', 'title', 'title']: 1
# ['name', 'address', 'name', 'firstnames']: 1
# ['name', 'familystatus', 'name', 'familystatus']: 1
# ['name', 'address', 'familystatus', 'name']: 1
# ['name', 'familystatus', 'familystatus']: 1
# ['name', 'name', 'firstnames', 'activity', 'address']: 1
# ['name', 'familystatus', 'name']: 1
# ['name', 'title', 'name']: 1
# ['name', 'address', 'address', 'name']: 1
# ['name', 'firstnames', 'name', 'firstnames', 'activity', 'activity', 'activity', 'address']: 1
# ['name', 'firstnames', 'name', 'title']: 1
# ['name', 'name', 'name']: 1

# %%
all_entities_pat = get_patterns_count(val_entities)
# Out:
# ['name', 'firstnames']: 96
# ['name', 'firstnames', 'activity', 'address']: 14
# ['name']: 10
# ['name', 'firstnames', 'familystatus']: 9
# ['name', 'firstnames', 'address']: 8
# ['name', 'familystatus']: 5
# ['name', 'firstnames', 'activity', 'address', 'familystatus']: 3
# ['name', 'firstnames', 'name', 'firstnames']: 3
# ['name', 'firstnames', 'activity']: 3
# ['name', 'firstnames', 'title']: 2
# ['name', 'address']: 2
# ['name', 'name']: 2
# ['name', 'name', 'firstnames']: 1
# ['name', 'firstnames', 'address', 'familystatus', 'name', 'address']: 1
# ['name', 'firstnames', 'name']: 1
# ['name', 'firstnames', 'activity', 'familystatus']: 1
# ['name', 'address', 'name', 'firstnames']: 1
# ['name', 'title', 'title']: 1
# ['name', 'firstnames', 'name', 'firstnames', 'familystatus']: 1
# ['name', 'familystatus', 'name', 'address', 'familystatus']: 1
# ['name', 'activity', 'address']: 1
# ['name', 'firstnames', 'familystatus', 'birthname']: 1
# ['name', 'familystatus', 'name', 'title']: 1
# ['name', 'activity']: 1
# ['name', 'name', 'activity']: 1
# ['name', 'firstnames', 'address', 'familystatus']: 1

# %%
all_entities_pat = get_patterns_count(test_entities)
# Out:
# ['name', 'firstnames']: 216
# ['name']: 39
# ['name', 'firstnames', 'activity', 'address']: 25
# ['name', 'firstnames', 'familystatus']: 23
# ['name', 'firstnames', 'address']: 19
# ['name', 'familystatus']: 14
# ['name', 'firstnames', 'activity']: 12
# ['name', 'address']: 9
# ['name', 'firstnames', 'address', 'familystatus']: 8
# ['name', 'firstnames', 'name', 'firstnames']: 5
# ['name', 'firstnames', 'title']: 4
# ['name', 'name']: 4
# ['name', 'address', 'familystatus']: 4
# ['name', 'name', 'activity']: 3
# ['name', 'firstnames', 'familystatus', 'name']: 3
# ['name', 'firstnames', 'activity', 'address', 'familystatus']: 3
# ['name', 'firstnames', 'name', 'address']: 2
# ['name', 'activity']: 2
# ['name', 'title']: 2
# ['name', 'firstnames', 'name', 'firstnames', 'activity', 'address']: 2
# ['name', 'firstnames', 'activity', 'familystatus']: 2
# ['name', 'title', 'familystatus']: 2
# ['name', 'firstnames', 'name', 'firstnames', 'familystatus']: 2
# ['name', 'firstnames', 'activity', 'address', 'name', 'firstnames', 'name', 'firstnames']: 1
# ['name', 'familystatus', 'name', 'activity', 'address']: 1
# ['name', 'firstnames', 'activity', 'address', 'address', 'familystatus']: 1
# ['name', 'name', 'activity', 'activity']: 1
# ['name', 'activity', 'name']: 1
# ['name', 'firstnames', 'name', 'firstnames', 'activity', 'address', 'address', 'familystatus']: 1
# ['name', 'firstnames', 'name', 'title']: 1
# ['name', 'firstnames', 'activity', 'name', 'firstnames', 'address']: 1
# ['name', 'firstnames', 'address', 'name', 'firstnames', 'address']: 1
# ['name', 'address', 'name', 'activity']: 1
# ['name', 'name', 'firstnames', 'address', 'familystatus']: 1
# ['name', 'firstnames', 'address', 'name', 'firstnames']: 1
# ['name', 'name', 'address']: 1
# ['name', 'title', 'birthname']: 1
# ['name', 'familystatus', 'birthname']: 1
# ['name', 'firstnames', 'address', 'title']: 1
# ['name', 'firstnames', 'birthname']: 1
# ['name', 'firstnames', 'familystatus', 'name', 'firstnames']: 1
# ['name', 'firstnames', 'address', 'title', 'birthname']: 1
# ['name', 'firstnames', 'name', 'firstnames', 'address']: 1
# ['name', 'familystatus', 'name', 'address']: 1
# ['name', 'name', 'firstnames']: 1

# %% [markdown]
# ### 2.2 Entities

# %%
def count_by_entities_types(entities):
    # Flatten the list of lists into a single list
    flattened_list = [item for sublist in entities for item in sublist]
    
    # Count occurrences of each value
    value_counts = Counter(flattened_list)
    
    # Sort by descending order of count
    sorted_value_counts = sorted(value_counts.items(), key=lambda x: x[1], reverse=True)
    
    # Print the results
    for value, count in sorted_value_counts:
        print(f"{value}: {count}")

# %%
count_by_entities_types(all_entities)
# Out:
# name: 2310
# firstnames: 1763
# address: 416
# familystatus: 339
# activity: 279
# title: 48
# birthname: 13

# %%
count_by_entities_types(train_entities)
# Out:
# name: 1661
# firstnames: 1256
# address: 294
# familystatus: 246
# activity: 197
# title: 31
# birthname: 8

# %%
count_by_entities_types(val_entities)
# Out:
# name: 184
# firstnames: 150
# address: 33
# familystatus: 25
# activity: 24
# title: 5
# birthname: 1

# %%
count_by_entities_types(test_entities)
# Out:
# name: 465
# firstnames: 357
# address: 89
# familystatus: 68
# activity: 58
# title: 12
# birthname: 4
